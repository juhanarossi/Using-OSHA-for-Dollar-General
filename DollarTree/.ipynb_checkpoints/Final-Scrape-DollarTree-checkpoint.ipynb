# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlencode
import urllib.parse
from copy import copy

# %% [markdown]
# # Scrape index

# %%
# Define some functions to help scrape the index

def get_osha_url(query, start_date_str, end_date_str):
    
    results_per_page = 1000
    start_date = pd.to_datetime(start_date_str)
    end_date = pd.to_datetime(end_date_str)

    # make params dictionary
    base_url = f"https://www.osha.gov/ords/imis/establishment.search"
    params = {
        'establishment': '+'.join(query.split()),
        'state': "all",
        'officetype': "all",
        'office': "all",
        'sitezip': 100000,
        'startmonth': start_date.month,
        'startday': start_date.day,
        'startyear': start_date.year,
        'endmonth': end_date.month,
        'endday': end_date.day,
        'endyear': end_date.year,
        'p_case': "all",
        'p_sort': 12,
        'p_desc': "DESC",
        'p_direction': "Prev",
        'p_show': results_per_page,
        'p_violations_exist': "yes"
    }

    return base_url + '?' + urlencode(params)

def get_index_table(osha_url):
    return pd.read_html(osha_url)[2]

# %%
queries = [
    ('Dollar Tree', '2012-12-19', '2022-12-19'),
    ('Dollar Tree', '2010-01-01', '2012-12-18'),
    ('Family Dollar', '2016-01-01', '2022-12-19')
]

# %%
activities_df = []
for query in queries:
    
    # break the query into 3 variables, and pass those to get_osha_url
    establishment, start, end = query   
    osha_url = get_osha_url(establishment, start, end)
    print(osha_url)
    
    # get the index table from the osha url, drop a junk column    
    index_df_for_this_query = get_index_table(osha_url)
    index_df_for_this_query = index_df_for_this_query.drop(columns=['Unnamed: 0', '#'])
    
    # tack on the query parameters to the table
    index_df_for_this_query['query'] = establishment
    index_df_for_this_query['query_start'] = start
    index_df_for_this_query['query_end'] = end
    
    # print to verify that pagination isn't a problem 
    # IMPORTANT: 👀 look at these values to make sure we don't need to paginate     
    print(f"found {len(index_df_for_this_query)} results for {query}\n")

    # append to dataframe
    activities_df.append(index_df_for_this_query)
    
# combine the queries
activities_df = pd.concat(activities_df)
activities_df.to_csv('Dec22_activities_df.csv', index=False)
activities_df
# Out:
# https://www.osha.gov/ords/imis/establishment.search?establishment=Dollar%2BTree&state=all&officetype=all&office=all&sitezip=100000&startmonth=12&startday=19&startyear=2012&endmonth=12&endday=19&endyear=2022&p_case=all&p_sort=12&p_desc=DESC&p_direction=Prev&p_show=1000&p_violations_exist=yes
# found 382 results for ('Dollar Tree', '2012-12-19', '2022-12-19')
#
# https://www.osha.gov/ords/imis/establishment.search?establishment=Dollar%2BTree&state=all&officetype=all&office=all&sitezip=100000&startmonth=1&startday=1&startyear=2010&endmonth=12&endday=18&endyear=2012&p_case=all&p_sort=12&p_desc=DESC&p_direction=Prev&p_show=1000&p_violations_exist=yes
# found 46 results for ('Dollar Tree', '2010-01-01', '2012-12-18')
#
# https://www.osha.gov/ords/imis/establishment.search?establishment=Family%2BDollar&state=all&officetype=all&office=all&sitezip=100000&startmonth=1&startday=1&startyear=2016&endmonth=12&endday=19&endyear=2022&p_case=all&p_sort=12&p_desc=DESC&p_direction=Prev&p_show=1000&p_violations_exist=yes
# found 99 results for ('Family Dollar', '2016-01-01', '2022-12-19')
#        Activity      Opened      RID  St       Type        Sc     SIC   NAICS  \
# 0   1616331.015  08/22/2022   453720  NC  Complaint   Partial  5331.0  452990
# 1   1618010.015  08/10/2022   316400  WV  Complaint   Partial     NaN  452319
# 2   1612868.015  08/05/2022   953210  NV   Referral   Partial     NaN  452319
# 3   1611611.015  08/01/2022  1054111  OR  Complaint   Partial  5331.0  452990
# 4   1610668.015  07/27/2022  1054111  OR  Complaint   Partial  5331.0  452990
# ..          ...         ...      ...  ..        ...       ...     ...     ...
# 94  1184357.015  10/18/2016   355124  VA  Complaint   Partial     NaN  452990
# 95  1173557.015  08/24/2016   627100  AR  Complaint   Partial     NaN  493110
# 96  1168125.015  08/05/2016   419400  MS  Complaint   Partial     NaN  452112
# 97  1144592.015  04/29/2016   215800  NY   Referral  Complete     NaN  493110
# 98  1133313.015  03/16/2016   112300  RI  Complaint   Partial     NaN  452990
#
#     Vio                          Establishment Name          query  \
# 0     6           152579 - Dollar Tree Stores, Inc.    Dollar Tree
# 1     1                     Dollar Tree Stores, Inc    Dollar Tree
# 2     1              Dollar Tree Stores, Inc. #1224    Dollar Tree
# 3     5          317731000 - Dollar Tree Stores Inc    Dollar Tree
# 4     1          317730993 - Dollar Tree Stores Inc    Dollar Tree
# ..  ...                                         ...            ...
# 94    1                               Family Dollar  Family Dollar
# 95    1           Family Dollar Distribution Center  Family Dollar
# 96    1                               Family Dollar  Family Dollar
# 97    4                 Family Dollar Services, Inc  Family Dollar
# 98    3  Family Dollar Stores Of Rhode Island, Inc.  Family Dollar
#
#    query_start   query_end
# 0   2012-12-19  2022-12-19
# 1   2012-12-19  2022-12-19
# 2   2012-12-19  2022-12-19
# 3   2012-12-19  2022-12-19
# 4   2012-12-19  2022-12-19
# ..         ...         ...
# 94  2016-01-01  2022-12-19
# 95  2016-01-01  2022-12-19
# 96  2016-01-01  2022-12-19
# 97  2016-01-01  2022-12-19
# 98  2016-01-01  2022-12-19
#
# [527 rows x 13 columns]

# %% [markdown]
# # Scrape individual activity pages

# %%
# Figure out how to scrape individual activity
def get_related_activity_table(url):
    tables = pd.read_html(url, match="Related Activity")
    return tables[0]

def get_violation_summary_table(url):
    tables = pd.read_html(url, match="Violation Summary")
    return tables[0]

def get_violation_items_table(url):
    tables = pd.read_html(url, match="Violation Items")
    return tables[0]

def get_investigated_inspection_table(url):
    tables = pd.read_html(url, match="Investigated Inspection")
    return tables[0]

def extract_key_value(tag):
    assert ':' in tag.text
    assert tag.find('strong')
    
    key = tag.text.split(':')[0].strip()
    value = tag.text.split(':')[1].strip()
    return key, value

def get_main_container(inspection_url):
    # get HTML from inspection page
    response = requests.get(inspection_url)
    html_doc = response.text
    soup = BeautifulSoup(html_doc, 'html.parser')

    # get main container (ignore footer/header/etc...)
    html_main_container = soup.find(id="maincontain")
    
    return html_main_container

def has_investigation_summary(html_main_container):
    h4s = html_main_container.find_all('h4')
    for h4 in h4s:
        if h4.text.strip() == "Investigation Summary":
            return True
    return False

def get_details(html_main_container):

    # Delete anything after "Investigation Summary H4"
    # we will scrape that stuff in a separate function
    h4s = html_main_container.find_all('h4')
    for h4 in h4s:
        if h4.text == "Investigation Summary":
            for e in h4.find_all_next():
                e.clear()
    
    # get details
    details = {}
    
    # get case status
    html_wells = html_main_container.find_all("div", class_="well")
    try:
        assert len(html_wells) == 2
        assert html_wells[0] == html_wells[1]
        case_status = html_wells[0]
        key, value = extract_key_value(case_status)                
    except:
        key = 'Case Status'
        value = 'ERROR'
        print("ERROR - couldn't scrape case status")
    details[key] = value
    
    # get remaining details
    html_spans = html_main_container.find_all("div", class_="span4")
    for span in html_spans:
        html_p_tags = span.find_all('p')
        if len(html_p_tags) == 0:
            columns_without_colon = 0
            key, value = extract_key_value(span)                
            details[key] = value
        else:
            for p_tag in html_p_tags:
                key, value = extract_key_value(p_tag)
                details[key] = value
    
    return details
    
def get_investigation_summary_details(html_main_container):
    # Delete anything after "Investigation Summary H4"
    # we will scrape that stuff in a separate function
    h4s = copy(html_main_container).find_all('h4')
    for h4 in h4s:
        if h4.text == "Investigation Summary":
            for e in h4.find_previous_siblings():
                e.decompose()

    details = {}

    spans = html_main_container.find_all('div', class_='span4')
    p_tags = html_main_container.find_all('p')
    spans_and_ptags = spans + p_tags
    
    details = {}
    notes_columns = 0
    for tag in spans_and_ptags:
        if ':' in tag.text and tag.find('strong'):
            key, value = extract_key_value(tag)
        else:
            notes_columns += 1
            key = f"investigation_summary_notes_{notes_columns}"
            value = tag.text
        details[key] = value
    
    return(details)

# %%
violation_summary_tables = []
violation_items_tables = []
related_activity_tables = []
details_dictionaries = []
investigated_inspections_table = []

for index, row in activities_df.reset_index(drop=True).iterrows():
    activity_code = row['Activity']
    url = f"https://www.osha.gov/ords/imis/establishment.inspection_detail?id={activity_code}"
    print(f"{index} of {len(activities_df)} - scraping {url}")

    violation_summary = get_violation_summary_table(url)
    violation_summary['activity_code'] = activity_code
    violation_summary_tables.append(violation_summary)
    
    violation_items = get_violation_items_table(url)
    violation_items['activity_code'] = activity_code
    violation_items_tables.append(violation_items)

    try:
        related_activity = get_related_activity_table(url)
        related_activity['activity_code'] = activity_code
        related_activity_tables.append(related_activity)
    except:
        print("ERROR - related activity table wasn't scraped")
        
    
    html = get_main_container(url)
    details = {}
    
    if has_investigation_summary(html):
        print("Has investigation summary")
        investigation_summary_details = get_investigation_summary_details(html)
        details.update(investigation_summary_details)
        
        investigated_inspections = get_investigated_inspection_table(url)
        investigated_inspections['activity_code'] = activity_code
        investigated_inspections_table.append(investigated_inspections)
        

    details.update(get_details(html))
    details['activity_code'] = activity_code    
    details_dictionaries.append(details)
# Out:
# 0 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1616331.015
# 1 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1618010.015
# 2 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1612868.015
# 3 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1611611.015
# 4 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1610668.015
# 5 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1609488.015
# 6 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1608368.015
# 7 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1608303.015
# 8 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1607656.015
# 9 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1606852.015
# 10 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1605793.015
# 11 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1604260.015
# 12 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1603155.015
# 13 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1600591.015
# 14 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1600299.015
# 15 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1599843.015
# 16 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1600383.015
# 17 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1600021.015
# 18 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1598846.015
# 19 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1607064.015
# 20 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1597674.015
# 21 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1597434.015
# ERROR - related activity table wasn't scraped
# 22 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1596670.015
# ERROR - related activity table wasn't scraped
# 23 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1596085.015
# 24 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1595473.015
# 25 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1601577.015
# 26 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1592254.015
# 27 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1592958.015
# 28 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1589562.015
# 29 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1590282.015
# 30 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1587972.015
# 31 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1586794.015
# 32 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1595108.015
# 33 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1580815.015
# 34 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1579408.015
# 35 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1577434.015
# 36 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1575351.015
# 37 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1574059.015
# Has investigation summary
# 38 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1571248.015
# 39 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1569923.015
# 40 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1568293.015
# 41 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1566768.015
# 42 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1566892.015
# 43 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1567732.015
# 44 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1563774.015
# 45 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1562499.015
# 46 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1558709.015
# 47 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1554234.015
# 48 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1553912.015
# 49 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1549799.015
# 50 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1549652.015
# 51 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1557108.015
# 52 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1547315.015
# 53 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1546323.015
# 54 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1546030.015
# 55 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1542587.015
# 56 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1540132.015
# 57 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1540075.015
# 58 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1539820.015
# 59 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1537367.015
# 60 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1537421.015
# 61 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1535320.015
# 62 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1532022.015
# 63 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1532505.015
# 64 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1530606.015
# 65 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1529043.015
# 66 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1526058.015
# 67 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1517161.015
# 68 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1516137.015
# 69 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1510493.015
# 70 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1505554.015
# 71 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1503555.015
# 72 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1501569.015
# 73 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1500406.015
# 74 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1500040.015
# 75 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1493953.015
# 76 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1493680.015
# 77 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1493669.015
# 78 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1489900.015
# 79 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1484134.015
# 80 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1484189.015
# 81 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1479001.015
# 82 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1476681.015
# 83 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1476491.015
# 84 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1475358.015
# 85 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1473721.015
# 86 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1470036.015
# 87 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1467899.015
# 88 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1468240.015
# ERROR - related activity table wasn't scraped
# 89 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1464979.015
# 90 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1464924.015
# 91 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1463783.015
# 92 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1464344.015
# 93 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1460827.015
# 94 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1467491.015
# 95 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1457133.015
# 96 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1454448.015
# 97 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1454236.015
# 98 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1453267.015
# 99 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1453278.015
# 100 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1453164.015
# 101 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1452137.015
# 102 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1452650.015
# 103 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1451149.015
# 104 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1452332.015
# 105 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1459848.015
# 106 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1448712.015
# 107 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1464549.015
# 108 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1448428.015
# 109 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1447228.015
# 110 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1447417.015
# 111 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1446800.015
# 112 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1446051.015
# 113 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1445218.015
# 114 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1443653.015
# 115 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1443300.015
# 116 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1443323.015
# 117 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1445436.015
# ERROR - related activity table wasn't scraped
# 118 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1442744.015
# 119 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1441668.015
# 120 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1439178.015
# 121 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1440331.015
# 122 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1438186.015
# 123 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1438745.015
# 124 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1436770.015
# 125 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1434100.015
# 126 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1432991.015
# 127 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1434769.015
# 128 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1433182.015
# 129 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1432347.015
# 130 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1432609.015
# 131 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1429028.015
# 132 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1431460.015
# 133 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1428448.015
# 134 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1427959.015
# 135 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1426493.015
# 136 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1430005.015
# 137 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1425738.015
# 138 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1419168.015
# 139 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1419463.015
# 140 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1419355.015
# 141 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1414649.015
# 142 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1415268.015
# 143 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1411428.015
# 144 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1408776.015
# 145 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1406066.015
# 146 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1405495.015
# 147 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1402986.015
# 148 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1399905.015
# 149 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1414139.015
# 150 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1398424.015
# 151 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1398141.015
# 152 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1396954.015
# 153 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1397146.015
# 154 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1396112.015
# 155 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1395047.015
# 156 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1393119.015
# 157 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1392698.015
# 158 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1392581.015
# 159 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1391852.015
# 160 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1392229.015
# 161 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1391524.015
# 162 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1391372.015
# 163 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1389876.015
# 164 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1389326.015
# 165 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1389880.015
# 166 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1386120.015
# 167 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1362039.015
# 168 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1379729.015
# Has investigation summary
# 169 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1378126.015
# 170 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1374186.015
# 171 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1365813.015
# 172 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1366312.015
# 173 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1364477.015
# 174 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1363963.015
# 175 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1364308.015
# 176 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1365021.015
# 177 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1366266.015
# 178 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1361948.015
# 179 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1361935.015
# 180 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1359722.015
# 181 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1357645.015
# 182 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1358113.015
# 183 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1358146.015
# 184 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1357511.015
# 185 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1356600.015
# 186 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1353484.015
# 187 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1353524.015
# 188 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1351299.015
# 189 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1350688.015
# 190 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1350112.015
# 191 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1346746.015
# 192 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1342814.015
# 193 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1336248.015
# 194 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1334723.015
# 195 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1330484.015
# 196 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1330070.015
# 197 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1330308.015
# 198 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1327441.015
# 199 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1326715.015
# 200 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1325188.015
# 201 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1320150.015
# 202 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1316256.015
# 203 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1312511.015
# 204 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1309701.015
# 205 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1308029.015
# 206 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1309164.015
# 207 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1321716.015
# 208 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1302979.015
# 209 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1302911.015
# 210 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1302291.015
# 211 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1299845.015
# 212 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1298402.015
# 213 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1293937.015
# 214 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1293367.015
# 215 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1292106.015
# 216 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1290825.015
# 217 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1285915.015
# 218 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1286103.015
# 219 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1283142.015
# 220 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1281516.015
# 221 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1281812.015
# 222 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1280766.015
# 223 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1279252.015
# 224 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1278349.015
# 225 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1276008.015
# Has investigation summary
# 226 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1277612.015
# 227 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1276469.015
# 228 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1274974.015
# Has investigation summary
# 229 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1272028.015
# 230 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1271229.015
# 231 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1270803.015
# 232 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1269761.015
# 233 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1268688.015
# 234 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1268180.015
# 235 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1266190.015
# 236 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1262996.015
# ERROR - related activity table wasn't scraped
# 237 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1261916.015
# 238 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1262725.015
# 239 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1259381.015
# 240 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1260384.015
# 241 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1252313.015
# 242 of 527 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1250847.015

# %%
violation_summary_df = pd.concat(violation_summary_tables)
violation_items_df = pd.concat(violation_items_tables)
related_activity_df = pd.concat(related_activity_tables)
investigated_inspections_df = pd.concat(investigated_inspections_table)
details_df = pd.DataFrame(details_dictionaries)

# %%
# !mkdir
# Out:
# mkdir: data: File exists

# %%
violation_summary_df.to_csv('Dec22DT_violation_summary_df.csv', index=False)
violation_items_df.to_csv('Dec22DT_violation_items_df.csv', index=False)
related_activity_df.to_csv('Dec22DT_related_activity_df.csv', index=False)
investigated_inspections_df.to_csv('Dec22DT_investigated_inspections_df.csv', index=False)
details_df.to_csv('Dec22DT_details_df.csv', index=False)
