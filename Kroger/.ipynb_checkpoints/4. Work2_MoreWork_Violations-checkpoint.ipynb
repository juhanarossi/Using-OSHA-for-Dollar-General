# %%
import pandas as pd

# %%
pd.options.display.max_colwidth = None
pd.options.display.max_columns = None

# %%
# !ls
# Out:
# 1. Final-Scrape-Kroger.ipynb           2. Joining_dfs_Violation_Summary.ipynb
# 1_activities_df.csv                    2_final_df.csv
# 1_details_df.csv                       3. Work2_MoreWork_Fines.ipynb
# 1_investigated_inspections_df.csv      3_CurrentFines.csv
# 1_related_activity_df.csv              3_InitialFines.csv
# 1_violation_items_df.csv               4. Work2_MoreWork_Violations.ipynb
# 1_violation_summary_df.csv

# %%
df = pd.read_csv("2_final_df.csv")

# %%
df
# Out:
#      Unnamed: 0      Activity      Opened     RID  St       Type       Sc  \
# 0             0  1.633901e+06  11/03/2022  854910  UT   Accident  Partial
# 1             1  1.633901e+06  11/03/2022  854910  UT   Accident  Partial
# 2             2  1.633901e+06  11/03/2022  854910  UT   Accident  Partial
# 3             3  1.633901e+06  11/03/2022  854910  UT   Accident  Partial
# 4             4  1.633901e+06  11/03/2022  854910  UT   Accident  Partial
# ..          ...           ...         ...     ...  ..        ...      ...
# 870         870  3.131540e+08  02/12/2010  522500  OH  Complaint  Partial
# 871         871  3.131540e+08  02/12/2010  522500  OH  Complaint  Partial
# 872         872  3.131540e+08  02/12/2010  522500  OH  Complaint  Partial
# 873         873  3.131540e+08  02/12/2010  522500  OH  Complaint  Partial
# 874         874  3.131540e+08  02/12/2010  522500  OH  Complaint  Partial
#
#       SIC_x  NAICS_x  Vio          Establishment Name   query query_start  \
# ...

# %%
df['year'] = pd.to_datetime(df['Open Date'], format='%m/%d/%Y')

# %%
df['simple_year'] = df['year'].dt.year

# %%
df.head(20)
# Out:
#     Unnamed: 0     Activity      Opened     RID  St       Type       Sc  \
# 0            0  1633901.015  11/03/2022  854910  UT   Accident  Partial
# 1            1  1633901.015  11/03/2022  854910  UT   Accident  Partial
# 2            2  1633901.015  11/03/2022  854910  UT   Accident  Partial
# 3            3  1633901.015  11/03/2022  854910  UT   Accident  Partial
# 4            4  1633901.015  11/03/2022  854910  UT   Accident  Partial
# 5            5  1621876.015  09/14/2022  626700  TX    Planned  Partial
# 6            6  1621876.015  09/14/2022  626700  TX    Planned  Partial
# 7            7  1621876.015  09/14/2022  626700  TX    Planned  Partial
# 8            8  1621876.015  09/14/2022  626700  TX    Planned  Partial
# 9            9  1621876.015  09/14/2022  626700  TX    Planned  Partial
# 10          10  1614916.015  08/16/2022  316400  WV   Referral  Partial
# 11          11  1614916.015  08/16/2022  316400  WV   Referral  Partial
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                                  int64
# Activity                                  float64
# Opened                                     object
# RID                                         int64
# St                                         object
# Type                                       object
# Sc                                         object
# SIC_x                                     float64
# NAICS_x                                     int64
# Vio                                         int64
# Establishment Name                         object
# query                                      object
# query_start                                object
# query_end                                  object
# Case Status                                object
# Inspection Nr                             float64
# Report ID                                   int64
# Open Date                                  object
# Site Address                               object
# ...

# %% [markdown]
# ### 1. For Current Violations

# %%
Current_Violation_df = df[df['Violations/Penalties'] == 'Current Violations']

# %%
Current_Violation_df.sample(20)
# Out:
#      Unnamed: 0      Activity      Opened     RID  St        Type        Sc  \
# 311         311  1.361023e+06  11/16/2018  452110  KY     Fat/Cat   Partial
# 206         206  1.456562e+06  01/17/2020  419400  MS    Referral   Partial
# 231         231  1.422077e+06  08/16/2019  552652  MI   Complaint   Partial
# 411         411  1.271292e+06  10/19/2017  522000  OH    Referral   Partial
# 526         526  1.153569e+06  06/09/2016  522000  OH   Complaint   Partial
# 86           86  1.556415e+06  10/06/2021  316400  WV   Complaint   Partial
# 691         691  3.154029e+08  12/02/2013  552652  MI     Planned  Complete
# 516         516  1.162466e+06  07/15/2016  355123  VA   Complaint   Partial
# 851         851  3.143333e+08  04/16/2010  627100  AR   Complaint   Partial
# 331         331  1.340796e+06  08/17/2018  452110  KY    Referral   Partial
# 201         201  1.473291e+06  04/27/2020  452110  KY   Complaint   Partial
# ...

# %%
Current_Violation_df['Total'] = Current_Violation_df['Total'].astype(int)
# Out:
# /var/folders/tn/ddzd66z517378n9c45psbsb00000gn/T/ipykernel_31888/1857983885.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Current_Violation_df['Total'] = Current_Violation_df['Total'].astype(int)

# %%
violations_df = Current_Violation_df.groupby('simple_year')['Total'].sum()

# %%
violations_df
# Out:
# simple_year
# 2010    28
# 2011    24
# 2012    15
# 2013    29
# 2014    21
# 2015    26
# 2016    21
# 2017    37
# 2018    50
# 2019    36
# 2020    19
# 2021    44
# 2022    14
# Name: Total, dtype: int64

# %%
new2_df = violations_df.to_frame(name='violations')

# %%
new2_df
# Out:
#              violations
# simple_year
# 2010                 28
# 2011                 24
# 2012                 15
# 2013                 29
# 2014                 21
# 2015                 26
# 2016                 21
# 2017                 37
# 2018                 50
# 2019                 36
# 2020                 19
# 2021                 44
# 2022                 14

# %%
new2_df.to_csv('4_CurrentViolations.csv')

# %% [markdown]
# ### 2. For Initial Violations

# %%
Initial_Violation_df = df[df['Violations/Penalties'] == 'Initial Violations']

# %%
Initial_Violation_df['Total'] = Initial_Violation_df['Total'].astype(int)
# Out:
# /var/folders/tn/ddzd66z517378n9c45psbsb00000gn/T/ipykernel_31888/3565745482.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Initial_Violation_df['Total'] = Initial_Violation_df['Total'].astype(int)

# %%
violations_df = Initial_Violation_df.groupby('simple_year')['Total'].sum()

# %%
violations_df
# Out:
# simple_year
# 2010    29
# 2011    24
# 2012    15
# 2013    29
# 2014    27
# 2015    31
# 2016    24
# 2017    38
# 2018    57
# 2019    39
# 2020    19
# 2021    45
# 2022    14
# Name: Total, dtype: int64

# %%
new2_df = violations_df.to_frame(name='violations')

# %%
new2_df
# Out:
#              violations
# simple_year
# 2010                 29
# 2011                 24
# 2012                 15
# 2013                 29
# 2014                 27
# 2015                 31
# 2016                 24
# 2017                 38
# 2018                 57
# 2019                 39
# 2020                 19
# 2021                 45
# 2022                 14

# %%
new2_df.to_csv('4_InitialViolations.csv')
