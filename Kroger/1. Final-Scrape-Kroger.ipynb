# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlencode
import urllib.parse
from copy import copy

# %% [markdown]
# # Scrape index

# %%
# Define some functions to help scrape the index

def get_osha_url(query, start_date_str, end_date_str):
    
    results_per_page = 1000
    start_date = pd.to_datetime(start_date_str)
    end_date = pd.to_datetime(end_date_str)

    # make params dictionary
    base_url = f"https://www.osha.gov/ords/imis/establishment.search"
    params = {
        'establishment': '+'.join(query.split()),
        'state': "all",
        'officetype': "all",
        'office': "all",
        'sitezip': 100000,
        'startmonth': start_date.month,
        'startday': start_date.day,
        'startyear': start_date.year,
        'endmonth': end_date.month,
        'endday': end_date.day,
        'endyear': end_date.year,
        'p_case': "all",
        'p_sort': 12,
        'p_desc': "DESC",
        'p_direction': "Prev",
        'p_show': results_per_page,
        'p_violations_exist': "yes"
    }

    return base_url + '?' + urlencode(params)

def get_index_table(osha_url):
    return pd.read_html(osha_url)[2]

# %%
queries = [
    ('Kroger', '2012-12-31', '2022-12-31'),
    ('Kroger', '2010-01-01', '2012-12-30')
]

# %%
activities_df = []
for query in queries:
    
    # break the query into 3 variables, and pass those to get_osha_url
    establishment, start, end = query   
    osha_url = get_osha_url(establishment, start, end)
    print(osha_url)
    
    # get the index table from the osha url, drop a junk column    
    index_df_for_this_query = get_index_table(osha_url)
    index_df_for_this_query = index_df_for_this_query.drop(columns=['Unnamed: 0', '#'])
    
    # tack on the query parameters to the table
    index_df_for_this_query['query'] = establishment
    index_df_for_this_query['query_start'] = start
    index_df_for_this_query['query_end'] = end
    
    # print to verify that pagination isn't a problem 
    # IMPORTANT: 👀 look at these values to make sure we don't need to paginate     
    print(f"found {len(index_df_for_this_query)} results for {query}\n")

    # append to dataframe
    activities_df.append(index_df_for_this_query)
    
# combine the queries
activities_df = pd.concat(activities_df)
activities_df.to_csv('1_activities_df.csv', index=False)
activities_df
# Out:
# https://www.osha.gov/ords/imis/establishment.search?establishment=Kroger&state=all&officetype=all&office=all&sitezip=100000&startmonth=12&startday=31&startyear=2012&endmonth=12&endday=31&endyear=2022&p_case=all&p_sort=12&p_desc=DESC&p_direction=Prev&p_show=1000&p_violations_exist=yes
# found 149 results for ('Kroger', '2012-12-31', '2022-12-31')
#
# https://www.osha.gov/ords/imis/establishment.search?establishment=Kroger&state=all&officetype=all&office=all&sitezip=100000&startmonth=1&startday=1&startyear=2010&endmonth=12&endday=30&endyear=2012&p_case=all&p_sort=12&p_desc=DESC&p_direction=Prev&p_show=1000&p_violations_exist=yes
# found 26 results for ('Kroger', '2010-01-01', '2012-12-30')
#         Activity      Opened     RID  St       Type        Sc     SIC   NAICS  \
# 0   1.633901e+06  11/03/2022  854910  UT   Accident   Partial     NaN  311812
# 1   1.621876e+06  09/14/2022  626700  TX    Planned   Partial     NaN  445110
# 2   1.614916e+06  08/16/2022  316400  WV   Referral   Partial     NaN  445110
# 3   1.613884e+06  08/09/2022  830600  CO  Complaint   Partial     NaN  424410
# 4   1.590209e+06  04/13/2022  854910  UT  Complaint   Partial     NaN  493110
# ..           ...         ...     ...  ..        ...       ...     ...     ...
# 21  3.143333e+08  04/16/2010  627100  AR  Complaint   Partial  5411.0  445110
# 22  3.120076e+08  04/09/2010  552652  MI    Planned  Complete  5411.0  445110
# 23  3.120384e+08  04/01/2010  552652  MI  Complaint   Partial  5411.0  445110
# 24  3.138321e+08  03/15/2010  551800  IN   Accident   Partial  5411.0  445110
# 25  3.131540e+08  02/12/2010  522500  OH  Complaint   Partial  5141.0  424410
#
#     Vio                 Establishment Name   query query_start   query_end
# 0     1                     The Kroger Co.  Kroger  2012-12-31  2022-12-31
# 1     1                  Kroger Texas L.P.  Kroger  2012-12-31  2022-12-31
# 2     2       Kroger Limited Partnership 1  Kroger  2012-12-31  2022-12-31
# 3     1                     The Kroger Co.  Kroger  2012-12-31  2022-12-31
# 4     1                     The Kroger Co.  Kroger  2012-12-31  2022-12-31
# ..  ...                                ...     ...         ...         ...
# 21    1                  Kroger Store #608  Kroger  2010-01-01  2012-12-30
# 22    9                     Kroger Co #709  Kroger  2010-01-01  2012-12-30
# 23    1                        Kroger #520  Kroger  2010-01-01  2012-12-30
# 24    3  Kroger Company D/B/A Kroger #J956  Kroger  2010-01-01  2012-12-30
# 25    1         Kroger Distribution Center  Kroger  2010-01-01  2012-12-30
#
# [175 rows x 13 columns]

# %% [markdown]
# # Scrape individual activity pages

# %%
# Figure out how to scrape individual activity
def get_related_activity_table(url):
    tables = pd.read_html(url, match="Related Activity")
    return tables[0]

def get_violation_summary_table(url):
    tables = pd.read_html(url, match="Violation Summary")
    return tables[0]

def get_violation_items_table(url):
    tables = pd.read_html(url, match="Violation Items")
    return tables[0]

def get_investigated_inspection_table(url):
    tables = pd.read_html(url, match="Investigated Inspection")
    return tables[0]

def extract_key_value(tag):
    assert ':' in tag.text
    assert tag.find('strong')
    
    key = tag.text.split(':')[0].strip()
    value = tag.text.split(':')[1].strip()
    return key, value

def get_main_container(inspection_url):
    # get HTML from inspection page
    response = requests.get(inspection_url)
    html_doc = response.text
    soup = BeautifulSoup(html_doc, 'html.parser')

    # get main container (ignore footer/header/etc...)
    html_main_container = soup.find(id="maincontain")
    
    return html_main_container

def has_investigation_summary(html_main_container):
    h4s = html_main_container.find_all('h4')
    for h4 in h4s:
        if h4.text.strip() == "Investigation Summary":
            return True
    return False

def get_details(html_main_container):

    # Delete anything after "Investigation Summary H4"
    # we will scrape that stuff in a separate function
    h4s = html_main_container.find_all('h4')
    for h4 in h4s:
        if h4.text == "Investigation Summary":
            for e in h4.find_all_next():
                e.clear()
    
    # get details
    details = {}
    
    # get case status
    html_wells = html_main_container.find_all("div", class_="well")
    try:
        assert len(html_wells) == 2
        assert html_wells[0] == html_wells[1]
        case_status = html_wells[0]
        key, value = extract_key_value(case_status)                
    except:
        key = 'Case Status'
        value = 'ERROR'
        print("ERROR - couldn't scrape case status")
    details[key] = value
    
    # get remaining details
    html_spans = html_main_container.find_all("div", class_="span4")
    for span in html_spans:
        html_p_tags = span.find_all('p')
        if len(html_p_tags) == 0:
            columns_without_colon = 0
            key, value = extract_key_value(span)                
            details[key] = value
        else:
            for p_tag in html_p_tags:
                key, value = extract_key_value(p_tag)
                details[key] = value
    
    return details
    
def get_investigation_summary_details(html_main_container):
    # Delete anything after "Investigation Summary H4"
    # we will scrape that stuff in a separate function
    h4s = copy(html_main_container).find_all('h4')
    for h4 in h4s:
        if h4.text == "Investigation Summary":
            for e in h4.find_previous_siblings():
                e.decompose()

    details = {}

    spans = html_main_container.find_all('div', class_='span4')
    p_tags = html_main_container.find_all('p')
    spans_and_ptags = spans + p_tags
    
    details = {}
    notes_columns = 0
    for tag in spans_and_ptags:
        if ':' in tag.text and tag.find('strong'):
            key, value = extract_key_value(tag)
        else:
            notes_columns += 1
            key = f"investigation_summary_notes_{notes_columns}"
            value = tag.text
        details[key] = value
    
    return(details)

# %%
violation_summary_tables = []
violation_items_tables = []
related_activity_tables = []
details_dictionaries = []
investigated_inspections_table = []

for index, row in activities_df.reset_index(drop=True).iterrows():
    activity_code = row['Activity']
    url = f"https://www.osha.gov/ords/imis/establishment.inspection_detail?id={activity_code}"
    print(f"{index} of {len(activities_df)} - scraping {url}")

    violation_summary = get_violation_summary_table(url)
    violation_summary['activity_code'] = activity_code
    violation_summary_tables.append(violation_summary)
    
    violation_items = get_violation_items_table(url)
    violation_items['activity_code'] = activity_code
    violation_items_tables.append(violation_items)

    try:
        related_activity = get_related_activity_table(url)
        related_activity['activity_code'] = activity_code
        related_activity_tables.append(related_activity)
    except:
        print("ERROR - related activity table wasn't scraped")
        
    
    html = get_main_container(url)
    details = {}
    
    if has_investigation_summary(html):
        print("Has investigation summary")
        investigation_summary_details = get_investigation_summary_details(html)
        details.update(investigation_summary_details)
        
        investigated_inspections = get_investigated_inspection_table(url)
        investigated_inspections['activity_code'] = activity_code
        investigated_inspections_table.append(investigated_inspections)
        

    details.update(get_details(html))
    details['activity_code'] = activity_code    
    details_dictionaries.append(details)
# Out:
# 0 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1633901.015
# 1 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1621876.015
# ERROR - related activity table wasn't scraped
# 2 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1614916.015
# 3 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1613884.015
# 4 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1590209.015
# 5 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1589516.015
# 6 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1585255.015
# 7 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1578451.015
# Has investigation summary
# 8 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1577632.015
# ERROR - related activity table wasn't scraped
# 9 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1573131.015
# Has investigation summary
# 10 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1574261.015
# Has investigation summary
# 11 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1563362.015
# 12 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1562806.015
# Has investigation summary
# 13 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1562838.015
# 14 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1560404.015
# 15 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1558597.015
# ERROR - related activity table wasn't scraped
# 16 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1557622.015
# 17 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1556415.015
# 18 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1554404.015
# 19 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1552894.015
# 20 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1551384.015
# Has investigation summary
# 21 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1550318.015
# 22 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1549314.015
# ERROR - related activity table wasn't scraped
# 23 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1545938.015
# ERROR - related activity table wasn't scraped
# 24 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1545533.015
# 25 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1544759.015
# 26 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1544772.015
# ERROR - related activity table wasn't scraped
# 27 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1536267.015
# 28 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1532761.015
# ERROR - related activity table wasn't scraped
# 29 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1528016.015
# 30 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1526785.015
# 31 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1525589.015
# 32 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1519797.015
# 33 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1512755.015
# 34 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1507859.015
# 35 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1507033.015
# 36 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1496945.015
# Has investigation summary
# 37 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1494405.015
# 38 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1493569.015
# 39 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1486257.015
# 40 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1473291.015
# 41 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1456562.015
# Has investigation summary
# 42 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1453170.015
# 43 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1444515.015
# ERROR - related activity table wasn't scraped
# 44 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1441027.015
# 45 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1434234.015
# 46 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1422077.015
# 47 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1421080.015
# 48 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1410948.015
# 49 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1408024.015
# Has investigation summary
# 50 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1404431.015
# 51 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1396920.015
# ERROR - related activity table wasn't scraped
# 52 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1386097.015
# 53 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1397761.015
# 54 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1380506.015
# ERROR - related activity table wasn't scraped
# 55 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1380723.015
# 56 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1381283.015
# 57 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1374129.015
# 58 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1370084.015
# 59 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1368405.015
# 60 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1366308.015
# Has investigation summary
# 61 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1363953.015
# ERROR - related activity table wasn't scraped
# 62 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1361023.015
# Has investigation summary
# 63 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1354041.015
# 64 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1343563.015
# 65 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1339383.015
# ERROR - related activity table wasn't scraped
# 66 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1340796.015
# 67 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1332422.015
# ERROR - related activity table wasn't scraped
# 68 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1329496.015
# 69 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1318908.015
# 70 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1316230.015
# 71 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1313366.015
# 72 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1310258.015
# 73 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1307396.015
# ERROR - related activity table wasn't scraped
# 74 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1303106.015
# ERROR - related activity table wasn't scraped
# 75 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1299019.015
# Has investigation summary
# 76 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1296382.015
# Has investigation summary
# 77 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1293864.015
# 78 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1316205.015
# Has investigation summary
# 79 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1291770.015
# ERROR - related activity table wasn't scraped
# 80 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1285710.015
# ERROR - related activity table wasn't scraped
# 81 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1279063.015
# 82 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1271292.015
# Has investigation summary
# 83 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1269207.015
# 84 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1266185.015
# 85 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1262839.015
# ERROR - related activity table wasn't scraped
# 86 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1255160.015
# 87 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1252881.015
# Has investigation summary
# 88 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1251119.015
# ERROR - related activity table wasn't scraped
# 89 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1249105.015
# ERROR - related activity table wasn't scraped
# 90 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1244199.015
# 91 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1229566.015
# Has investigation summary
# 92 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1224043.015
# ERROR - related activity table wasn't scraped
# 93 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1217422.015
# 94 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1214816.015
# 95 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1212659.015
# 96 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1207608.015
# 97 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1202976.015
# 98 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1202004.015
# 99 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1187762.015
# 100 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1175476.015
# 101 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1169579.015
# 102 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1165854.015
# 103 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1162466.015
# 104 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1153555.015
# 105 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1153569.015
# 106 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1149811.015
# 107 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1146983.015
# 108 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1137124.015
# ERROR - related activity table wasn't scraped
# 109 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1136329.015
# 110 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1126419.015
# ERROR - related activity table wasn't scraped
# 111 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1119686.015
# 112 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1101840.015
# 113 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1096288.015
# 114 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1096822.015
# 115 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1086068.015
# 116 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1083648.015
# 117 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1084923.015
# 118 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1066729.015
# 119 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1062465.015
# 120 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1060760.015
# Has investigation summary
# 121 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1049249.015
# 122 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1048224.015
# 123 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1041640.015
# 124 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1032053.015
# 125 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1021305.015
# 126 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1010513.015
# 127 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1005045.015
# 128 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1004397.015
# 129 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1003692.015
# 130 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=317456366.0
# ERROR - couldn't scrape case status
# 131 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=985567.015
# 132 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=981331.015
# 133 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=968250.015
# 134 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=316922863.0
# ERROR - couldn't scrape case status
# 135 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=315407148.0
# ERROR - couldn't scrape case status
# 136 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=955883.015
# 137 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=317512226.0
# ERROR - couldn't scrape case status
# 138 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=315402909.0
# ERROR - related activity table wasn't scraped
# ERROR - couldn't scrape case status
# 139 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=315373142.0
# ERROR - related activity table wasn't scraped
# ERROR - couldn't scrape case status
# 140 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=315403683.0
# ERROR - couldn't scrape case status
# 141 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=317212116.0
# ERROR - couldn't scrape case status
# 142 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=901386.015
# 143 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=890807.015
# 144 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=316550862.0
# ERROR - couldn't scrape case status
# 145 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=316546837.0
# ERROR - couldn't scrape case status
# 146 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=315398230.0
# ERROR - couldn't scrape case status
# 147 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=316597772.0
# ERROR - couldn't scrape case status
# 148 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=805841.015
# Has investigation summary
# 149 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=316852474.0
# ERROR - couldn't scrape case status
# 150 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=669699.015
# ERROR - related activity table wasn't scraped
# 151 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=316608942.0
# ERROR - couldn't scrape case status
# 152 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=536598.015
# 153 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=283858.015
# 154 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=315227959.0
# ERROR - couldn't scrape case status
# 155 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=315861765.0
# ERROR - related activity table wasn't scraped
# ERROR - couldn't scrape case status
# 156 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=316281492.0
# ERROR - couldn't scrape case status
# 157 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=315992701.0
# ERROR - couldn't scrape case status
# 158 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=315226076.0
# ERROR - related activity table wasn't scraped
# ERROR - couldn't scrape case status
# 159 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=315747634.0
# ERROR - couldn't scrape case status
# 160 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=314210774.0
# ERROR - couldn't scrape case status
# 161 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=315041590.0
# ERROR - couldn't scrape case status
# 162 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=315273573.0
# ERROR - couldn't scrape case status
# 163 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=314277005.0
# Has investigation summary
# ERROR - couldn't scrape case status
# 164 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=312079916.0
# ERROR - related activity table wasn't scraped
# ERROR - couldn't scrape case status
# 165 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=314590225.0
# ERROR - couldn't scrape case status
# 166 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=314847385.0
# ERROR - couldn't scrape case status
# 167 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=312924780.0
# ERROR - couldn't scrape case status
# 168 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=314648965.0
# ERROR - couldn't scrape case status
# 169 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=314100561.0
# ERROR - couldn't scrape case status
# 170 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=314333295.0
# ERROR - couldn't scrape case status
# 171 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=312007560.0
# ERROR - related activity table wasn't scraped
# ERROR - couldn't scrape case status
# 172 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=312038375.0
# ERROR - couldn't scrape case status
# 173 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=313832123.0
# Has investigation summary
# ERROR - couldn't scrape case status
# 174 of 175 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=313154023.0
# ERROR - couldn't scrape case status

# %%
violation_summary_df = pd.concat(violation_summary_tables)
violation_items_df = pd.concat(violation_items_tables)
related_activity_df = pd.concat(related_activity_tables)
investigated_inspections_df = pd.concat(investigated_inspections_table)
details_df = pd.DataFrame(details_dictionaries)

# %%
# !mkdir
# Out:
# usage: mkdir [-pv] [-m mode] directory_name ...

# %%
violation_summary_df.to_csv('1_violation_summary_df.csv', index=False)
violation_items_df.to_csv('1_violation_items_df.csv', index=False)
related_activity_df.to_csv('1_related_activity_df.csv', index=False)
investigated_inspections_df.to_csv('1_investigated_inspections_df.csv', index=False)
details_df.to_csv('1_details_df.csv', index=False)
