# %%
import pandas as pd

# %%
# !ls
# Out:
# Dec22Kro_TOTAL_CurrentPenalty.csv
# Fines_Kroger-AfterDropDuplicatestoEnd.ipynb
# Fines_Kroger-toDropDuplicates.ipynb

# %%
df = pd.read_csv("Dec22Kro_TOTAL_CurrentPenalty.csv")
df
# Out:
#      Unnamed: 0      Activity      Opened     RID  St       Type        Sc  \
# 0             0  1.621876e+06  09/14/2022  626700  TX    Planned   Partial
# 1             1  1.614916e+06  08/16/2022  316400  WV   Referral   Partial
# 2             2  1.613884e+06  08/09/2022  830600  CO  Complaint   Partial
# 3             3  1.590209e+06  04/13/2022  854910  UT  Complaint   Partial
# 4             4  1.589516e+06  04/12/2022  452110  KY  Complaint   Partial
# ..          ...           ...         ...     ...  ..        ...       ...
# 169         169  3.143333e+08  04/16/2010  627100  AR  Complaint   Partial
# 170         170  3.120076e+08  04/09/2010  552652  MI    Planned  Complete
# 171         171  3.120384e+08  04/01/2010  552652  MI  Complaint   Partial
# 172         172  3.138321e+08  03/15/2010  551800  IN   Accident   Partial
# 173         173  3.131540e+08  02/12/2010  522500  OH  Complaint   Partial
#
#       SIC_x  NAICS_x  Vio  ... Note        Planning Guide  \
# ...

# %%
df = df.drop_duplicates(['Activity'])
df
# Out:
#      Unnamed: 0      Activity      Opened     RID  St       Type        Sc  \
# 0             0  1.621876e+06  09/14/2022  626700  TX    Planned   Partial
# 1             1  1.614916e+06  08/16/2022  316400  WV   Referral   Partial
# 2             2  1.613884e+06  08/09/2022  830600  CO  Complaint   Partial
# 3             3  1.590209e+06  04/13/2022  854910  UT  Complaint   Partial
# 4             4  1.589516e+06  04/12/2022  452110  KY  Complaint   Partial
# ..          ...           ...         ...     ...  ..        ...       ...
# 169         169  3.143333e+08  04/16/2010  627100  AR  Complaint   Partial
# 170         170  3.120076e+08  04/09/2010  552652  MI    Planned  Complete
# 171         171  3.120384e+08  04/01/2010  552652  MI  Complaint   Partial
# 172         172  3.138321e+08  03/15/2010  551800  IN   Accident   Partial
# 173         173  3.131540e+08  02/12/2010  522500  OH  Complaint   Partial
#
#       SIC_x  NAICS_x  Vio  ... Note        Planning Guide  \
# ...

# %%
df.to_csv('Dec22Kro_toDropDuplicates.csv', index=False)
