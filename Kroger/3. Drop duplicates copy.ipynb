# %%
import pandas as pd

# %%
# !ls
# Out:
# 1. Final-Scrape-Kroger.ipynb           3. Drop duplicates copy.ipynb
# 1_activities_df.csv                    3. Work2_MoreWork_Fines.ipynb
# 1_details_df.csv                       3_CurrentFines.csv
# 1_investigated_inspections_df.csv      3_InitialFines.csv
# 1_related_activity_df.csv              4. Work2_MoreWork_Fines.ipynb
# 1_violation_items_df.csv               4. Work2_MoreWork_Violations.ipynb
# 1_violation_summary_df.csv             4_CurrentViolations.csv
# 2. Joining_dfs_Violation_Summary.ipynb 4_InitialViolations.csv
# 2_final_df.csv                         5. Work2_MoreWork_Violations.ipynb

# %%
df = pd.read_csv("2_final_df.csv")
df
# Out:
#      Unnamed: 0      Activity      Opened     RID  St       Type       Sc  \
# 0             0  1.633901e+06  11/03/2022  854910  UT   Accident  Partial
# 1             1  1.633901e+06  11/03/2022  854910  UT   Accident  Partial
# 2             2  1.633901e+06  11/03/2022  854910  UT   Accident  Partial
# 3             3  1.633901e+06  11/03/2022  854910  UT   Accident  Partial
# 4             4  1.633901e+06  11/03/2022  854910  UT   Accident  Partial
# ..          ...           ...         ...     ...  ..        ...      ...
# 870         870  3.131540e+08  02/12/2010  522500  OH  Complaint  Partial
# 871         871  3.131540e+08  02/12/2010  522500  OH  Complaint  Partial
# 872         872  3.131540e+08  02/12/2010  522500  OH  Complaint  Partial
# 873         873  3.131540e+08  02/12/2010  522500  OH  Complaint  Partial
# 874         874  3.131540e+08  02/12/2010  522500  OH  Complaint  Partial
#
#       SIC_x  NAICS_x  Vio  ... Note Planning Guide Violations/Penalties  \
# 0       NaN   311812    1  ...  NaN            NaN   Initial Violations
# 1       NaN   311812    1  ...  NaN            NaN   Current Violations
# 2       NaN   311812    1  ...  NaN            NaN      Initial Penalty
# 3       NaN   311812    1  ...  NaN            NaN      Current Penalty
# 4       NaN   311812    1  ...  NaN            NaN          FTA Penalty
# ..      ...      ...  ...  ...  ...            ...                  ...
# 870  5141.0   424410    1  ...  NaN            NaN   Initial Violations
# 871  5141.0   424410    1  ...  NaN            NaN   Current Violations
# 872  5141.0   424410    1  ...  NaN            NaN      Initial Penalty
# 873  5141.0   424410    1  ...  NaN            NaN      Current Penalty
# 874  5141.0   424410    1  ...  NaN            NaN          FTA Penalty
#
#     Serious Willful  Repeat   Other Unclass   Total activity_code_y
# 0         1     NaN     NaN     NaN     NaN       1    1.633901e+06
# 1         1     NaN     NaN     NaN     NaN       1    1.633901e+06
# 2    $4,500      $0      $0      $0      $0  $4,500    1.633901e+06
# 3    $2,250      $0      $0      $0      $0  $2,250    1.633901e+06
# 4        $0      $0      $0      $0      $0      $0    1.633901e+06
# ..      ...     ...     ...     ...     ...     ...             ...
# 870       1     NaN     NaN     NaN     NaN       1    3.131540e+08
# 871     NaN     NaN     NaN       1     NaN       1    3.131540e+08
# 872  $2,500      $0      $0      $0      $0  $2,500    3.131540e+08
# 873      $0      $0      $0  $2,000      $0  $2,000    3.131540e+08
# 874      $0      $0      $0      $0      $0      $0    3.131540e+08
#
# [875 rows x 49 columns]

# %%
Current_Penalty_df = df[df['Violations/Penalties'] == 'Current Penalty']
Current_Penalty_df = Current_Penalty_df.drop_duplicates(['Activity'])
Current_Penalty_df
# Out:
#      Unnamed: 0      Activity      Opened     RID  St       Type        Sc  \
# 3             3  1.633901e+06  11/03/2022  854910  UT   Accident   Partial
# 8             8  1.621876e+06  09/14/2022  626700  TX    Planned   Partial
# 13           13  1.614916e+06  08/16/2022  316400  WV   Referral   Partial
# 18           18  1.613884e+06  08/09/2022  830600  CO  Complaint   Partial
# 23           23  1.590209e+06  04/13/2022  854910  UT  Complaint   Partial
# ..          ...           ...         ...     ...  ..        ...       ...
# 853         853  3.143333e+08  04/16/2010  627100  AR  Complaint   Partial
# 858         858  3.120076e+08  04/09/2010  552652  MI    Planned  Complete
# 863         863  3.120384e+08  04/01/2010  552652  MI  Complaint   Partial
# 868         868  3.138321e+08  03/15/2010  551800  IN   Accident   Partial
# 873         873  3.131540e+08  02/12/2010  522500  OH  Complaint   Partial
#
#       SIC_x  NAICS_x  Vio  ... Note        Planning Guide  \
# 3       NaN   311812    1  ...  NaN                   NaN
# 8       NaN   445110    1  ...  NaN                   NaN
# 13      NaN   445110    2  ...  NaN                   NaN
# 18      NaN   424410    1  ...  NaN                   NaN
# 23      NaN   493110    1  ...  NaN                   NaN
# ..      ...      ...  ...  ...  ...                   ...
# 853  5411.0   445110    1  ...  NaN                   NaN
# 858  5411.0   445110    9  ...  NaN  Safety-Manufacturing
# 863  5411.0   445110    1  ...  NaN  Safety-Manufacturing
# 868  5411.0   445110    3  ...  NaN  Safety-Manufacturing
# 873  5141.0   424410    1  ...  NaN                   NaN
#
#     Violations/Penalties  Serious Willful  Repeat   Other Unclass    Total  \
# 3        Current Penalty   $2,250      $0      $0      $0      $0   $2,250
# 8        Current Penalty       $0      $0      $0  $2,796      $0   $2,796
# 13       Current Penalty  $24,862      $0      $0      $0      $0  $24,862
# 18       Current Penalty       $0      $0    $414      $0      $0     $414
# 23       Current Penalty   $2,250      $0      $0      $0      $0   $2,250
# ..                   ...      ...     ...     ...     ...     ...      ...
# 853      Current Penalty     $840      $0      $0      $0      $0     $840
# 858      Current Penalty   $1,300      $0      $0      $0      $0   $1,300
# 863      Current Penalty     $450      $0      $0      $0      $0     $450
# 868      Current Penalty   $7,000      $0      $0  $1,000      $0   $8,000
# 873      Current Penalty       $0      $0      $0  $2,000      $0   $2,000
#
#     activity_code_y
# 3      1.633901e+06
# 8      1.621876e+06
# 13     1.614916e+06
# 18     1.613884e+06
# 23     1.590209e+06
# ..              ...
# 853    3.143333e+08
# 858    3.120076e+08
# 863    3.120384e+08
# 868    3.138321e+08
# 873    3.131540e+08
#
# [175 rows x 49 columns]

# %%
Initial_Penalty_df = df[df['Violations/Penalties'] == 'Initial Penalty']
Initial_Penalty_df = Initial_Penalty_df.drop_duplicates(['Activity'])
Initial_Penalty_df
# Out:
#      Unnamed: 0      Activity      Opened     RID  St       Type        Sc  \
# 2             2  1.633901e+06  11/03/2022  854910  UT   Accident   Partial
# 7             7  1.621876e+06  09/14/2022  626700  TX    Planned   Partial
# 12           12  1.614916e+06  08/16/2022  316400  WV   Referral   Partial
# 17           17  1.613884e+06  08/09/2022  830600  CO  Complaint   Partial
# 22           22  1.590209e+06  04/13/2022  854910  UT  Complaint   Partial
# ..          ...           ...         ...     ...  ..        ...       ...
# 852         852  3.143333e+08  04/16/2010  627100  AR  Complaint   Partial
# 857         857  3.120076e+08  04/09/2010  552652  MI    Planned  Complete
# 862         862  3.120384e+08  04/01/2010  552652  MI  Complaint   Partial
# 867         867  3.138321e+08  03/15/2010  551800  IN   Accident   Partial
# 872         872  3.131540e+08  02/12/2010  522500  OH  Complaint   Partial
#
#       SIC_x  NAICS_x  Vio  ... Note        Planning Guide  \
# 2       NaN   311812    1  ...  NaN                   NaN
# 7       NaN   445110    1  ...  NaN                   NaN
# 12      NaN   445110    2  ...  NaN                   NaN
# 17      NaN   424410    1  ...  NaN                   NaN
# 22      NaN   493110    1  ...  NaN                   NaN
# ..      ...      ...  ...  ...  ...                   ...
# 852  5411.0   445110    1  ...  NaN                   NaN
# 857  5411.0   445110    9  ...  NaN  Safety-Manufacturing
# 862  5411.0   445110    1  ...  NaN  Safety-Manufacturing
# 867  5411.0   445110    3  ...  NaN  Safety-Manufacturing
# 872  5141.0   424410    1  ...  NaN                   NaN
#
#     Violations/Penalties  Serious Willful   Repeat   Other Unclass    Total  \
# 2        Initial Penalty   $4,500      $0       $0      $0      $0   $4,500
# 7        Initial Penalty   $4,661      $0       $0      $0      $0   $4,661
# 12       Initial Penalty  $24,862      $0       $0      $0      $0  $24,862
# 17       Initial Penalty       $0      $0     $414      $0      $0     $414
# 22       Initial Penalty   $4,500      $0       $0      $0      $0   $4,500
# ..                   ...      ...     ...      ...     ...     ...      ...
# 852      Initial Penalty   $1,400      $0       $0      $0      $0   $1,400
# 857      Initial Penalty   $3,250      $0       $0      $0      $0   $3,250
# 862      Initial Penalty     $450      $0       $0      $0      $0     $450
# 867      Initial Penalty   $3,500      $0  $12,500  $1,000      $0  $17,000
# 872      Initial Penalty   $2,500      $0       $0      $0      $0   $2,500
#
#     activity_code_y
# 2      1.633901e+06
# 7      1.621876e+06
# 12     1.614916e+06
# 17     1.613884e+06
# 22     1.590209e+06
# ..              ...
# 852    3.143333e+08
# 857    3.120076e+08
# 862    3.120384e+08
# 867    3.138321e+08
# 872    3.131540e+08
#
# [175 rows x 49 columns]

# %%
Current_Violations_df = df[df['Violations/Penalties'] == 'Current Violations']
Current_Violations_df = Current_Violations_df.drop_duplicates(['Activity'])
Current_Violations_df
# Out:
#      Unnamed: 0      Activity      Opened     RID  St       Type        Sc  \
# 1             1  1.633901e+06  11/03/2022  854910  UT   Accident   Partial
# 6             6  1.621876e+06  09/14/2022  626700  TX    Planned   Partial
# 11           11  1.614916e+06  08/16/2022  316400  WV   Referral   Partial
# 16           16  1.613884e+06  08/09/2022  830600  CO  Complaint   Partial
# 21           21  1.590209e+06  04/13/2022  854910  UT  Complaint   Partial
# ..          ...           ...         ...     ...  ..        ...       ...
# 851         851  3.143333e+08  04/16/2010  627100  AR  Complaint   Partial
# 856         856  3.120076e+08  04/09/2010  552652  MI    Planned  Complete
# 861         861  3.120384e+08  04/01/2010  552652  MI  Complaint   Partial
# 866         866  3.138321e+08  03/15/2010  551800  IN   Accident   Partial
# 871         871  3.131540e+08  02/12/2010  522500  OH  Complaint   Partial
#
#       SIC_x  NAICS_x  Vio  ... Note        Planning Guide  \
# 1       NaN   311812    1  ...  NaN                   NaN
# 6       NaN   445110    1  ...  NaN                   NaN
# 11      NaN   445110    2  ...  NaN                   NaN
# 16      NaN   424410    1  ...  NaN                   NaN
# 21      NaN   493110    1  ...  NaN                   NaN
# ..      ...      ...  ...  ...  ...                   ...
# 851  5411.0   445110    1  ...  NaN                   NaN
# 856  5411.0   445110    9  ...  NaN  Safety-Manufacturing
# 861  5411.0   445110    1  ...  NaN  Safety-Manufacturing
# 866  5411.0   445110    3  ...  NaN  Safety-Manufacturing
# 871  5141.0   424410    1  ...  NaN                   NaN
#
#     Violations/Penalties Serious Willful  Repeat  Other Unclass Total  \
# 1     Current Violations       1     NaN     NaN    NaN     NaN     1
# 6     Current Violations     NaN     NaN     NaN      1     NaN     1
# 11    Current Violations       2     NaN     NaN    NaN     NaN     2
# 16    Current Violations     NaN     NaN       1    NaN     NaN     1
# 21    Current Violations       1     NaN     NaN    NaN     NaN     1
# ..                   ...     ...     ...     ...    ...     ...   ...
# 851   Current Violations       1     NaN     NaN    NaN     NaN     1
# 856   Current Violations       4     NaN     NaN      5     NaN     9
# 861   Current Violations       1     NaN     NaN    NaN     NaN     1
# 866   Current Violations       2     NaN     NaN      1     NaN     3
# 871   Current Violations     NaN     NaN     NaN      1     NaN     1
#
#     activity_code_y
# 1      1.633901e+06
# 6      1.621876e+06
# 11     1.614916e+06
# 16     1.613884e+06
# 21     1.590209e+06
# ..              ...
# 851    3.143333e+08
# 856    3.120076e+08
# 861    3.120384e+08
# 866    3.138321e+08
# 871    3.131540e+08
#
# [175 rows x 49 columns]

# %%
Initial_Violations_df = df[df['Violations/Penalties'] == 'Initial Violations']
Initial_Violations_df = Initial_Violations_df.drop_duplicates(['Activity'])
Initial_Violations_df
# Out:
#      Unnamed: 0      Activity      Opened     RID  St       Type        Sc  \
# 0             0  1.633901e+06  11/03/2022  854910  UT   Accident   Partial
# 5             5  1.621876e+06  09/14/2022  626700  TX    Planned   Partial
# 10           10  1.614916e+06  08/16/2022  316400  WV   Referral   Partial
# 15           15  1.613884e+06  08/09/2022  830600  CO  Complaint   Partial
# 20           20  1.590209e+06  04/13/2022  854910  UT  Complaint   Partial
# ..          ...           ...         ...     ...  ..        ...       ...
# 850         850  3.143333e+08  04/16/2010  627100  AR  Complaint   Partial
# 855         855  3.120076e+08  04/09/2010  552652  MI    Planned  Complete
# 860         860  3.120384e+08  04/01/2010  552652  MI  Complaint   Partial
# 865         865  3.138321e+08  03/15/2010  551800  IN   Accident   Partial
# 870         870  3.131540e+08  02/12/2010  522500  OH  Complaint   Partial
#
#       SIC_x  NAICS_x  Vio  ... Note        Planning Guide  \
# 0       NaN   311812    1  ...  NaN                   NaN
# 5       NaN   445110    1  ...  NaN                   NaN
# 10      NaN   445110    2  ...  NaN                   NaN
# 15      NaN   424410    1  ...  NaN                   NaN
# 20      NaN   493110    1  ...  NaN                   NaN
# ..      ...      ...  ...  ...  ...                   ...
# 850  5411.0   445110    1  ...  NaN                   NaN
# 855  5411.0   445110    9  ...  NaN  Safety-Manufacturing
# 860  5411.0   445110    1  ...  NaN  Safety-Manufacturing
# 865  5411.0   445110    3  ...  NaN  Safety-Manufacturing
# 870  5141.0   424410    1  ...  NaN                   NaN
#
#     Violations/Penalties Serious Willful  Repeat  Other Unclass Total  \
# 0     Initial Violations       1     NaN     NaN    NaN     NaN     1
# 5     Initial Violations       1     NaN     NaN    NaN     NaN     1
# 10    Initial Violations       2     NaN     NaN    NaN     NaN     2
# 15    Initial Violations     NaN     NaN       1    NaN     NaN     1
# 20    Initial Violations       1     NaN     NaN    NaN     NaN     1
# ..                   ...     ...     ...     ...    ...     ...   ...
# 850   Initial Violations       1     NaN     NaN    NaN     NaN     1
# 855   Initial Violations       4     NaN     NaN      5     NaN     9
# 860   Initial Violations       1     NaN     NaN    NaN     NaN     1
# 865   Initial Violations       1     NaN       1      1     NaN     3
# 870   Initial Violations       1     NaN     NaN    NaN     NaN     1
#
#     activity_code_y
# 0      1.633901e+06
# 5      1.621876e+06
# 10     1.614916e+06
# 15     1.613884e+06
# 20     1.590209e+06
# ..              ...
# 850    3.143333e+08
# 855    3.120076e+08
# 860    3.120384e+08
# 865    3.138321e+08
# 870    3.131540e+08
#
# [175 rows x 49 columns]

# %%
Current_Penalty_df.to_csv('3_currentpenaltydrop.csv', index=False)

# %%
Initial_Penalty_df.to_csv('3_initialpenaltydrop.csv', index=False)

# %%
Current_Violations_df.to_csv('3_currentviolationsdrop.csv', index=False)

# %%
Initial_Violations_df.to_csv('3_initialviolationsdrop.csv', index=False)
