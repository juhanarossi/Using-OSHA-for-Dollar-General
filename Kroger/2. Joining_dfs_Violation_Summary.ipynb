# %%
import pandas as pd
pd.options.display.max_colwidth = None
pd.options.display.max_columns = None

# %%
df1 = pd.read_csv("1_activities_df.csv")

# %%
df2 = pd.read_csv("1_details_df.csv")

# %%
df3 = pd.read_csv("1_violation_summary_df.csv")

# %%
df3
# Out:
#     Violations/Penalties Serious Willful Repeat   Other Unclass   Total  \
# 0     Initial Violations       1     NaN    NaN     NaN     NaN       1
# 1     Current Violations       1     NaN    NaN     NaN     NaN       1
# 2        Initial Penalty  $4,500      $0     $0      $0      $0  $4,500
# 3        Current Penalty  $2,250      $0     $0      $0      $0  $2,250
# 4            FTA Penalty      $0      $0     $0      $0      $0      $0
# ..                   ...     ...     ...    ...     ...     ...     ...
# 870   Initial Violations       1     NaN    NaN     NaN     NaN       1
# 871   Current Violations     NaN     NaN    NaN       1     NaN       1
# 872      Initial Penalty  $2,500      $0     $0      $0      $0  $2,500
# 873      Current Penalty      $0      $0     $0  $2,000      $0  $2,000
# 874          FTA Penalty      $0      $0     $0      $0      $0      $0
#
#      activity_code
# 0     1.633901e+06
# 1     1.633901e+06
# 2     1.633901e+06
# 3     1.633901e+06
# ...

# %%
master_df = pd.merge(df1, df2, how='inner', left_on='Activity', right_on='Inspection Nr')

# %%
master_df
# Out:
#          Activity      Opened     RID  St       Type        Sc   SIC_x  \
# 0    1.633901e+06  11/03/2022  854910  UT   Accident   Partial     NaN
# 1    1.621876e+06  09/14/2022  626700  TX    Planned   Partial     NaN
# 2    1.614916e+06  08/16/2022  316400  WV   Referral   Partial     NaN
# 3    1.613884e+06  08/09/2022  830600  CO  Complaint   Partial     NaN
# 4    1.590209e+06  04/13/2022  854910  UT  Complaint   Partial     NaN
# ..            ...         ...     ...  ..        ...       ...     ...
# 170  3.143333e+08  04/16/2010  627100  AR  Complaint   Partial  5411.0
# 171  3.120076e+08  04/09/2010  552652  MI    Planned  Complete  5411.0
# 172  3.120384e+08  04/01/2010  552652  MI  Complaint   Partial  5411.0
# 173  3.138321e+08  03/15/2010  551800  IN   Accident   Partial  5411.0
# 174  3.131540e+08  02/12/2010  522500  OH  Complaint   Partial  5141.0
#
#      NAICS_x  Vio                 Establishment Name   query query_start  \
# ...

# %%
final_df = pd.merge(master_df, df3, how='inner', left_on='Activity', right_on='activity_code')

# %%
final_df
# Out:
#          Activity      Opened     RID  St       Type       Sc   SIC_x  \
# 0    1.633901e+06  11/03/2022  854910  UT   Accident  Partial     NaN
# 1    1.633901e+06  11/03/2022  854910  UT   Accident  Partial     NaN
# 2    1.633901e+06  11/03/2022  854910  UT   Accident  Partial     NaN
# 3    1.633901e+06  11/03/2022  854910  UT   Accident  Partial     NaN
# 4    1.633901e+06  11/03/2022  854910  UT   Accident  Partial     NaN
# ..            ...         ...     ...  ..        ...      ...     ...
# 870  3.131540e+08  02/12/2010  522500  OH  Complaint  Partial  5141.0
# 871  3.131540e+08  02/12/2010  522500  OH  Complaint  Partial  5141.0
# 872  3.131540e+08  02/12/2010  522500  OH  Complaint  Partial  5141.0
# 873  3.131540e+08  02/12/2010  522500  OH  Complaint  Partial  5141.0
# 874  3.131540e+08  02/12/2010  522500  OH  Complaint  Partial  5141.0
#
#      NAICS_x  Vio          Establishment Name   query query_start   query_end  \
# ...

# %%
final_df.to_csv('2_final_df.csv')

# %%
# !ls
# Out:
# 1. Final-Scrape-Kroger.ipynb           1_violation_summary_df.csv
# 1_activities_df.csv                    2. Joining_dfs_Violation_Summary.ipynb
# 1_details_df.csv                       2_final_df.csv
# 1_investigated_inspections_df.csv      3. Work2_MoreWork_Fines.ipynb
# 1_related_activity_df.csv              4. Work2_MoreWork_Violations.ipynb
# 1_violation_items_df.csv
