# %%
import pandas as pd

# %%
# !ls
# Out:
# Dec22DG_toDropDuplicatesVIOLATIONS.csv
# Dec22DG_TOTAL_VIOLATIONS_master.csv
# Joining_dfs_DG-FinalViolations.ipynb
# Violations_DG-AfterDropDuplicatestoEnd.ipynb
# Violations_DG-toDropDuplicates.ipynb

# %%
df = pd.read_csv("Dec22DG_toDropDuplicatesVIOLATIONS.csv")

# %%
df
# Out:
#      Unnamed: 0      Activity      Opened     RID  St       Type        Sc  \
# 0             0  1.619753e+06  09/06/2022  452110  KY  Complaint   Partial
# 1             1  1.617010e+06  08/25/2022  552652  MI  Complaint   Partial
# 2             2  1.609906e+06  07/25/2022  454716  TN  Complaint   Partial
# 3             3  1.607451e+06  07/13/2022  418100  GA  Complaint   Partial
# 4             4  1.601808e+06  06/14/2022  418400  GA  Complaint   Partial
# ..          ...           ...         ...     ...  ..        ...       ...
# 233         387  1.079844e+06  07/23/2015  419700  FL  Complaint   Partial
# 234         388  1.083884e+06  07/20/2015  418300  AL   Referral   Partial
# 235         389  1.062209e+06  05/11/2015  729300  MO  Complaint   Partial
# 236         390  3.167852e+08  08/14/2013  453710  NC  Complaint   Partial
# 237         391  3.140213e+08  01/14/2010  453730  NC    Planned  Complete
#
#       SIC_x  NAICS_x  Vio  ... Keywords        Planning Guide  \
# ...

# %%
df['year'] = pd.to_datetime(df['Open Date'], format='%m/%d/%Y')

# %%
df['simple_year'] = df['year'].dt.year

# %%
df.Total = df.Total.astype(str)

# %%
df.Total = df.Total.str.replace("$", "")
# Out:
# C:\Users\Juhana\AppData\Local\Temp\ipykernel_6212\1384840350.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.Total = df.Total.str.replace("$", "")

# %%
df.Total = df.Total.str.replace(",", "")

# %%
df.Total = df.Total.astype(int)

# %%
dgfines_df = df.groupby('simple_year')['Total'].sum()

# %%
dgfines_df
# Out:
# simple_year
# 2010     29
# 2011     25
# 2012     12
# 2013     24
# 2014     52
# 2015     51
# 2016     55
# 2017     21
# 2018     15
# 2019     48
# 2020     45
# 2021     64
# 2022    114
# Name: Total, dtype: int32

# %%
new_df = dgfines_df.to_frame(name='violations')

# %%
new_df
# Out:
#              violations
# simple_year
# 2010                 29
# 2011                 25
# 2012                 12
# 2013                 24
# 2014                 52
# 2015                 51
# 2016                 55
# 2017                 21
# 2018                 15
# 2019                 48
# 2020                 45
# 2021                 64
# 2022                114

# %%
new_df.to_csv('Dec22DG_Final_CurrentViolations.csv', index=False)

# %%
# !ls
# Out:
# Dec22DG_Final_CurrentViolations.csv
# Dec22DG_toDropDuplicatesVIOLATIONS.csv
# Dec22DG_TOTAL_VIOLATIONS_master.csv
# Joining_dfs_DG-FinalViolations.ipynb
# Violations_DG-AfterDropDuplicatestoEnd.ipynb
# Violations_DG-toDropDuplicates.ipynb
