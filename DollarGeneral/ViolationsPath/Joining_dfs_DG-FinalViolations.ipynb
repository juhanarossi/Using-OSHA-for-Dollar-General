# %%
# !ls
# Out:
# Dec22DG_activities_df.csv
# Dec22DG_details_df.csv
# Dec22DG_investigated_inspections_df.csv
# Dec22DG_related_activity_df.csv
# Dec22DG_TOTAL_master.csv
# Dec22DG_violation_items_df.csv
# Dec22DG_violation_summary_df.csv
# Final-Scrape-DollarGeneral.ipynb
# FinesPath
# Joining_dfs_DG-FinalViolations.ipynb
# Violations_DG-AfterDropDuplicatestoEnd.ipynb
# Violations_DG-toDropDuplicates.ipynb
# ViolationsPath

# %%
import pandas as pd
pd.options.display.max_colwidth = None
pd.options.display.max_columns = None

# %%
df1 = pd.read_csv("Dec22DG_activities_df.csv")

# %%
df2 = pd.read_csv("Dec22DG_details_df.csv")

# %%
df3 = pd.read_csv("Dec22DG_violation_summary_df.csv")
df3
# Out:
#      Violations/Penalties Serious   Willful Repeat Other Unclass     Total  \
# 0      Initial Violations     NaN         2    NaN   NaN     NaN         2
# 1      Current Violations     NaN         2    NaN   NaN     NaN         2
# 2         Initial Penalty      $0  $140,000     $0    $0      $0  $140,000
# 3         Current Penalty      $0  $140,000     $0    $0      $0  $140,000
# 4             FTA Penalty      $0        $0     $0    $0      $0        $0
# ...                   ...     ...       ...    ...   ...     ...       ...
# 1295   Initial Violations       1       NaN    NaN     5     NaN         6
# 1296   Current Violations     NaN       NaN    NaN     6     NaN         6
# 1297      Initial Penalty  $2,750        $0     $0    $0      $0    $2,750
# 1298      Current Penalty      $0        $0     $0  $975      $0      $975
# 1299          FTA Penalty      $0        $0     $0    $0      $0        $0
#
#       activity_code
# 0      1.619753e+06
# 1      1.619753e+06
# ...

# %%
df3 = df3[df3['Violations/Penalties'] == 'Current Violations']
df3
# Out:
#      Violations/Penalties Serious Willful Repeat Other Unclass Total  \
# 1      Current Violations     NaN       2    NaN   NaN     NaN     2
# 6      Current Violations     NaN     NaN    NaN     1     NaN     1
# 11     Current Violations     NaN     NaN      2   NaN     NaN     2
# 16     Current Violations     NaN     NaN    NaN     1     NaN     1
# 21     Current Violations     NaN     NaN      2   NaN     NaN     2
# ...                   ...     ...     ...    ...   ...     ...   ...
# 1276   Current Violations       1     NaN    NaN     2     NaN     3
# 1281   Current Violations       1     NaN    NaN   NaN     NaN     1
# 1286   Current Violations     NaN     NaN    NaN     1     NaN     1
# 1291   Current Violations     NaN     NaN    NaN     3     NaN     3
# 1296   Current Violations     NaN     NaN    NaN     6     NaN     6
#
#       activity_code
# 1      1.619753e+06
# 6      1.617010e+06
# 11     1.609906e+06
# 16     1.607451e+06
# 21     1.601808e+06
# ...

# %%
master_df = pd.merge(df1, df2, how='inner', left_on='Activity', right_on='Inspection Nr')

# %%
master_df
# Out:
#          Activity      Opened     RID  St       Type        Sc   SIC_x  \
# 0    1.619753e+06  09/06/2022  452110  KY  Complaint   Partial  4225.0
# 1    1.617010e+06  08/25/2022  552652  MI  Complaint   Partial     NaN
# 2    1.609906e+06  07/25/2022  454716  TN  Complaint   Partial     NaN
# 3    1.607451e+06  07/13/2022  418100  GA  Complaint   Partial     NaN
# 4    1.601808e+06  06/14/2022  418400  GA  Complaint   Partial     NaN
# ..            ...         ...     ...  ..        ...       ...     ...
# 299  1.079844e+06  07/23/2015  419700  FL  Complaint   Partial     NaN
# 300  1.083884e+06  07/20/2015  418300  AL   Referral   Partial     NaN
# 301  1.062209e+06  05/11/2015  729300  MO  Complaint   Partial     NaN
# 302  3.167852e+08  08/14/2013  453710  NC  Complaint   Partial  5331.0
# 303  3.140213e+08  01/14/2010  453730  NC    Planned  Complete  5311.0
#
#      NAICS_x  Vio                                Establishment Name  \
# ...

# %%
final_df = pd.merge(master_df, df3, how='inner', left_on='Activity', right_on='activity_code')

# %%
final_df
# Out:
#          Activity      Opened     RID  St       Type        Sc   SIC_x  \
# 0    1.619753e+06  09/06/2022  452110  KY  Complaint   Partial  4225.0
# 1    1.617010e+06  08/25/2022  552652  MI  Complaint   Partial     NaN
# 2    1.609906e+06  07/25/2022  454716  TN  Complaint   Partial     NaN
# 3    1.607451e+06  07/13/2022  418100  GA  Complaint   Partial     NaN
# 4    1.601808e+06  06/14/2022  418400  GA  Complaint   Partial     NaN
# ..            ...         ...     ...  ..        ...       ...     ...
# 387  1.079844e+06  07/23/2015  419700  FL  Complaint   Partial     NaN
# 388  1.083884e+06  07/20/2015  418300  AL   Referral   Partial     NaN
# 389  1.062209e+06  05/11/2015  729300  MO  Complaint   Partial     NaN
# 390  3.167852e+08  08/14/2013  453710  NC  Complaint   Partial  5331.0
# 391  3.140213e+08  01/14/2010  453730  NC    Planned  Complete  5311.0
#
#      NAICS_x  Vio                                Establishment Name  \
# ...

# %%
final_df.to_csv('Dec22DG_TOTAL_VIOLATIONS_master.csv')

# %%
# !ls
# Out:
# Dec22DG_activities_df.csv
# Dec22DG_details_df.csv
# Dec22DG_investigated_inspections_df.csv
# Dec22DG_related_activity_df.csv
# Dec22DG_TOTAL_master.csv
# Dec22DG_TOTAL_VIOLATIONS_master.csv
# Dec22DG_violation_items_df.csv
# Dec22DG_violation_summary_df.csv
# Final-Scrape-DollarGeneral.ipynb
# FinesPath
# Joining_dfs_DG-FinalViolations.ipynb
# Violations_DG-AfterDropDuplicatestoEnd.ipynb
# Violations_DG-toDropDuplicates.ipynb
# ViolationsPath
