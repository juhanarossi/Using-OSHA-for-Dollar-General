# %%
import pandas as pd

# %%
pd.options.display.max_colwidth = None
pd.options.display.max_columns = None

# %%
# !ls
# Out:
# 1. Final-Scrape-Walmart.ipynb          3_CurrentFines.csv
# 1_activities_df.csv                    3_InitialFines.csv
# 1_details_df.csv                       3_currentpenaltydrop.csv
# 1_investigated_inspections_df.csv      3_currentviolationsdrop.csv
# 1_related_activity_df.csv              3_initialpenaltydrop.csv
# 1_violation_items_df.csv               3_initialviolationsdrop.csv
# 1_violation_summary_df.csv             4. Work2_MoreWork_Fines.ipynb
# 2. Joining_dfs_Violation_Summary.ipynb 4. Work2_MoreWork_Violations.ipynb
# 2_final_df.csv                         4_CurrentViolations.csv
# 3. Drop duplicates copy.ipynb          4_InitialViolations.csv
# 3. Work2_MoreWork_Fines.ipynb          5. Work2_MoreWork_Violations.ipynb

# %% [markdown]
# ### 1. For Current Penalty

# %%
df = pd.read_csv("3_currentpenaltydrop.csv")

# %%
df
# Out:
#      Unnamed: 0      Activity      Opened     RID  St        Type        Sc  \
# 0             3  1.617962e+06  08/29/2022  552652  MI   Complaint   Partial
# 1             8  1.617558e+06  08/25/2022  951510  HI  Prog Other  Complete
# 2            13  1.618144e+06  08/24/2022  452110  KY     Planned   Records
# 3            18  1.616220e+06  08/22/2022  552652  MI   Complaint   Partial
# 4            23  1.608665e+06  07/18/2022  950624  CA   Complaint   Partial
# ..          ...           ...         ...     ...  ..         ...       ...
# 326        1633  3.129146e+08  04/06/2010  950625  CA   Complaint   Partial
# 327        1638  3.134090e+08  03/10/2010  728500  MO     Planned  Complete
# 328        1643  3.134539e+08  02/16/2010  257220  PR    Referral   Partial
# 329        1648  3.139923e+08  01/11/2010  214200  NJ   Complaint   Partial
# 330        1653  3.131530e+08  01/06/2010  522500  OH   Complaint   Partial
#
# ...

# %%
df['year'] = pd.to_datetime(df['Open Date'], format='%m/%d/%Y')

# %%
df['simple_year'] = df['year'].dt.year

# %%
df.head(20)
# Out:
#     Unnamed: 0     Activity      Opened     RID  St        Type        Sc  \
# 0            3  1617962.015  08/29/2022  552652  MI   Complaint   Partial
# 1            8  1617558.015  08/25/2022  951510  HI  Prog Other  Complete
# 2           13  1618144.015  08/24/2022  452110  KY     Planned   Records
# 3           18  1616220.015  08/22/2022  552652  MI   Complaint   Partial
# 4           23  1608665.015  07/18/2022  950624  CA   Complaint   Partial
# 5           28  1606171.015  07/06/2022  213400  NJ    Referral   Partial
# 6           33  1605577.015  07/01/2022  627500  TX   Complaint   Partial
# 7           38  1605398.015  06/30/2022  213100  NY   Complaint   Partial
# 8           43  1604505.015  06/28/2022  522300  OH    Referral   Partial
# 9           48  1602840.015  06/16/2022  453720  NC   Complaint   Partial
# 10          53  1602445.015  06/15/2022  950615  CA   Complaint   Partial
# 11          58  1600312.015  06/07/2022  953210  NV    Referral   Partial
# ...

# %%
df['Total']=df['Total'].str.replace(',','')

# %%
df['Total']=df['Total'].str.replace('$','')
# Out:
# /var/folders/tn/ddzd66z517378n9c45psbsb00000gn/T/ipykernel_79235/266217449.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Total']=df['Total'].str.replace('$','')

# %%
df['Total'] = df['Total'].astype(int)

# %%
df
# Out:
#      Unnamed: 0      Activity      Opened     RID  St        Type        Sc  \
# 0             3  1.617962e+06  08/29/2022  552652  MI   Complaint   Partial
# 1             8  1.617558e+06  08/25/2022  951510  HI  Prog Other  Complete
# 2            13  1.618144e+06  08/24/2022  452110  KY     Planned   Records
# 3            18  1.616220e+06  08/22/2022  552652  MI   Complaint   Partial
# 4            23  1.608665e+06  07/18/2022  950624  CA   Complaint   Partial
# ..          ...           ...         ...     ...  ..         ...       ...
# 326        1633  3.129146e+08  04/06/2010  950625  CA   Complaint   Partial
# 327        1638  3.134090e+08  03/10/2010  728500  MO     Planned  Complete
# 328        1643  3.134539e+08  02/16/2010  257220  PR    Referral   Partial
# 329        1648  3.139923e+08  01/11/2010  214200  NJ   Complaint   Partial
# 330        1653  3.131530e+08  01/06/2010  522500  OH   Complaint   Partial
#
# ...

# %%
current_fines_df = df.groupby('simple_year')['Total'].sum()

# %%
current_fines_df
# Out:
# simple_year
# 2010     44576
# 2011    263470
# 2012     27864
# 2013     70638
# 2014     79690
# 2015     77770
# 2016     53893
# 2017     93358
# 2018    127494
# 2019    158938
# 2020    172625
# 2021    234857
# 2022    182791
# Name: Total, dtype: int64

# %%
new_df = current_fines_df.to_frame(name='fines')

# %%
new_df
# Out:
#               fines
# simple_year
# 2010          44576
# 2011         263470
# 2012          27864
# 2013          70638
# 2014          79690
# 2015          77770
# 2016          53893
# 2017          93358
# 2018         127494
# 2019         158938
# 2020         172625
# 2021         234857
# 2022         182791

# %%
new_df.to_csv('4_CurrentFines.csv')

# %% [markdown]
# ### 2. For Initial Penalty

# %%
df = pd.read_csv("3_initialpenaltydrop.csv")

# %%
df['year'] = pd.to_datetime(df['Open Date'], format='%m/%d/%Y')

# %%
df['simple_year'] = df['year'].dt.year

# %%
df['Total']=df['Total'].str.replace(',','')

# %%
df['Total']=df['Total'].str.replace('$','')
# Out:
# /var/folders/tn/ddzd66z517378n9c45psbsb00000gn/T/ipykernel_79235/266217449.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Total']=df['Total'].str.replace('$','')

# %%
df['Total'] = df['Total'].astype(int)

# %%
initial_fines_df = df.groupby('simple_year')['Total'].sum()

# %%
initial_fines_df
# Out:
# simple_year
# 2010     92128
# 2011    518709
# 2012     49963
# 2013    158950
# 2014    147695
# 2015    104608
# 2016     83968
# 2017    158135
# 2018    190213
# 2019    242581
# 2020    255847
# 2021    323464
# 2022    236471
# Name: Total, dtype: int64

# %%
new_df = initial_fines_df.to_frame(name='fines')

# %%
new_df
# Out:
#               fines
# simple_year
# 2010          92128
# 2011         518709
# 2012          49963
# 2013         158950
# 2014         147695
# 2015         104608
# 2016          83968
# 2017         158135
# 2018         190213
# 2019         242581
# 2020         255847
# 2021         323464
# 2022         236471

# %%
new_df.to_csv('4_InitialFines.csv')
