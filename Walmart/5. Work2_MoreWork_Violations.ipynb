# %%
import pandas as pd

# %%
pd.options.display.max_colwidth = None
pd.options.display.max_columns = None

# %%
# !ls
# Out:
# 1. Final-Scrape-Walmart.ipynb          3_InitialFines.csv
# 1_activities_df.csv                    3_currentpenaltydrop.csv
# 1_details_df.csv                       3_currentviolationsdrop.csv
# 1_investigated_inspections_df.csv      3_initialpenaltydrop.csv
# 1_related_activity_df.csv              3_initialviolationsdrop.csv
# 1_violation_items_df.csv               4. Work2_MoreWork_Fines.ipynb
# 1_violation_summary_df.csv             4. Work2_MoreWork_Violations.ipynb
# 2. Joining_dfs_Violation_Summary.ipynb 4_CurrentFines.csv
# 2_final_df.csv                         4_CurrentViolations.csv
# 3. Drop duplicates copy.ipynb          4_InitialFines.csv
# 3. Work2_MoreWork_Fines.ipynb          4_InitialViolations.csv
# 3_CurrentFines.csv                     5. Work2_MoreWork_Violations.ipynb

# %% [markdown]
# ### 1. For Current Violations

# %%
df = pd.read_csv("3_currentviolationsdrop.csv")

# %%
df
# Out:
#      Unnamed: 0      Activity      Opened     RID  St        Type        Sc  \
# 0             1  1.617962e+06  08/29/2022  552652  MI   Complaint   Partial
# 1             6  1.617558e+06  08/25/2022  951510  HI  Prog Other  Complete
# 2            11  1.618144e+06  08/24/2022  452110  KY     Planned   Records
# 3            16  1.616220e+06  08/22/2022  552652  MI   Complaint   Partial
# 4            21  1.608665e+06  07/18/2022  950624  CA   Complaint   Partial
# ..          ...           ...         ...     ...  ..         ...       ...
# 326        1631  3.129146e+08  04/06/2010  950625  CA   Complaint   Partial
# 327        1636  3.134090e+08  03/10/2010  728500  MO     Planned  Complete
# 328        1641  3.134539e+08  02/16/2010  257220  PR    Referral   Partial
# 329        1646  3.139923e+08  01/11/2010  214200  NJ   Complaint   Partial
# 330        1651  3.131530e+08  01/06/2010  522500  OH   Complaint   Partial
#
# ...

# %%
df['year'] = pd.to_datetime(df['Open Date'], format='%m/%d/%Y')

# %%
df['simple_year'] = df['year'].dt.year

# %%
df.head(20)
# Out:
#     Unnamed: 0     Activity      Opened     RID  St        Type        Sc  \
# 0            1  1617962.015  08/29/2022  552652  MI   Complaint   Partial
# 1            6  1617558.015  08/25/2022  951510  HI  Prog Other  Complete
# 2           11  1618144.015  08/24/2022  452110  KY     Planned   Records
# 3           16  1616220.015  08/22/2022  552652  MI   Complaint   Partial
# 4           21  1608665.015  07/18/2022  950624  CA   Complaint   Partial
# 5           26  1606171.015  07/06/2022  213400  NJ    Referral   Partial
# 6           31  1605577.015  07/01/2022  627500  TX   Complaint   Partial
# 7           36  1605398.015  06/30/2022  213100  NY   Complaint   Partial
# 8           41  1604505.015  06/28/2022  522300  OH    Referral   Partial
# 9           46  1602840.015  06/16/2022  453720  NC   Complaint   Partial
# 10          51  1602445.015  06/15/2022  950615  CA   Complaint   Partial
# 11          56  1600312.015  06/07/2022  953210  NV    Referral   Partial
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                                  int64
# Activity                                  float64
# Opened                                     object
# RID                                         int64
# St                                         object
# Type                                       object
# Sc                                         object
# SIC_x                                     float64
# NAICS_x                                     int64
# Vio                                         int64
# Establishment Name                         object
# query                                      object
# query_start                                object
# query_end                                  object
# Case Status                                object
# Inspection Nr                             float64
# Report ID                                   int64
# Open Date                                  object
# Site Address                               object
# ...

# %%
df['Total'] = df['Total'].astype(int)

# %%
violations_df = df.groupby('simple_year')['Total'].sum()

# %%
violations_df
# Out:
# simple_year
# 2010    66
# 2011    73
# 2012    40
# 2013    42
# 2014    38
# 2015    39
# 2016    25
# 2017    20
# 2018    41
# 2019    48
# 2020    33
# 2021    60
# 2022    47
# Name: Total, dtype: int64

# %%
new2_df = violations_df.to_frame(name='violations')

# %%
new2_df
# Out:
#              violations
# simple_year
# 2010                 66
# 2011                 73
# 2012                 40
# 2013                 42
# 2014                 38
# 2015                 39
# 2016                 25
# 2017                 20
# 2018                 41
# 2019                 48
# 2020                 33
# 2021                 60
# 2022                 47

# %%
new2_df.to_csv('5_CurrentViolations.csv')

# %% [markdown]
# ### 2. For Initial Violations

# %%
df = pd.read_csv("3_initialviolationsdrop.csv")

# %%
df['year'] = pd.to_datetime(df['Open Date'], format='%m/%d/%Y')

# %%
df['simple_year'] = df['year'].dt.year

# %%
df['Total'] = df['Total'].astype(int)

# %%
violations_df = df.groupby('simple_year')['Total'].sum()

# %%
violations_df
# Out:
# simple_year
# 2010    78
# 2011    83
# 2012    42
# 2013    53
# 2014    42
# 2015    41
# 2016    27
# 2017    22
# 2018    44
# 2019    52
# 2020    35
# 2021    74
# 2022    52
# Name: Total, dtype: int64

# %%
new2_df = violations_df.to_frame(name='violations')

# %%
new2_df
# Out:
#              violations
# simple_year
# 2010                 78
# 2011                 83
# 2012                 42
# 2013                 53
# 2014                 42
# 2015                 41
# 2016                 27
# 2017                 22
# 2018                 44
# 2019                 52
# 2020                 35
# 2021                 74
# 2022                 52

# %%
new2_df.to_csv('5_InitialViolations.csv')
