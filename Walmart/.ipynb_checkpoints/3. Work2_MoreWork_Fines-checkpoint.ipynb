# %%
import pandas as pd

# %%
pd.options.display.max_colwidth = None
pd.options.display.max_columns = None

# %%
# !ls
# Out:
# 1. Final-Scrape-Walmart.ipynb          1_violation_summary_df.csv
# 1_activities_df.csv                    2. Joining_dfs_Violation_Summary.ipynb
# 1_details_df.csv                       2_final_df.csv
# 1_investigated_inspections_df.csv      3. Work2_MoreWork_Fines.ipynb
# 1_related_activity_df.csv              4. Work2_MoreWork_Violations.ipynb
# 1_violation_items_df.csv

# %%
df = pd.read_csv("2_final_df.csv")

# %%
df
# Out:
#       Unnamed: 0      Activity      Opened     RID  St       Type       Sc  \
# 0              0  1.617962e+06  08/29/2022  552652  MI  Complaint  Partial
# 1              1  1.617962e+06  08/29/2022  552652  MI  Complaint  Partial
# 2              2  1.617962e+06  08/29/2022  552652  MI  Complaint  Partial
# 3              3  1.617962e+06  08/29/2022  552652  MI  Complaint  Partial
# 4              4  1.617962e+06  08/29/2022  552652  MI  Complaint  Partial
# ...          ...           ...         ...     ...  ..        ...      ...
# 1650        1650  3.131530e+08  01/06/2010  522500  OH  Complaint  Partial
# 1651        1651  3.131530e+08  01/06/2010  522500  OH  Complaint  Partial
# 1652        1652  3.131530e+08  01/06/2010  522500  OH  Complaint  Partial
# 1653        1653  3.131530e+08  01/06/2010  522500  OH  Complaint  Partial
# 1654        1654  3.131530e+08  01/06/2010  522500  OH  Complaint  Partial
#
# ...

# %%
df['year'] = pd.to_datetime(df['Open Date'], format='%m/%d/%Y')

# %%
df['simple_year'] = df['year'].dt.year

# %%
df.head(20)
# Out:
#     Unnamed: 0     Activity      Opened     RID  St        Type        Sc  \
# 0            0  1617962.015  08/29/2022  552652  MI   Complaint   Partial
# 1            1  1617962.015  08/29/2022  552652  MI   Complaint   Partial
# 2            2  1617962.015  08/29/2022  552652  MI   Complaint   Partial
# 3            3  1617962.015  08/29/2022  552652  MI   Complaint   Partial
# 4            4  1617962.015  08/29/2022  552652  MI   Complaint   Partial
# 5            5  1617558.015  08/25/2022  951510  HI  Prog Other  Complete
# 6            6  1617558.015  08/25/2022  951510  HI  Prog Other  Complete
# 7            7  1617558.015  08/25/2022  951510  HI  Prog Other  Complete
# 8            8  1617558.015  08/25/2022  951510  HI  Prog Other  Complete
# 9            9  1617558.015  08/25/2022  951510  HI  Prog Other  Complete
# 10          10  1618144.015  08/24/2022  452110  KY     Planned   Records
# 11          11  1618144.015  08/24/2022  452110  KY     Planned   Records
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                                  int64
# Activity                                  float64
# Opened                                     object
# RID                                         int64
# St                                         object
# Type                                       object
# Sc                                         object
# SIC_x                                     float64
# NAICS_x                                     int64
# Vio                                         int64
# Establishment Name                         object
# query                                      object
# query_start                                object
# query_end                                  object
# Case Status                                object
# Inspection Nr                             float64
# Report ID                                   int64
# Open Date                                  object
# Site Address                               object
# ...

# %% [markdown]
# ### 1. For Current Penalty

# %%
Current_Penalty_df = df[df['Violations/Penalties'] == 'Current Penalty']

# %%
Current_Penalty_df.sample(20)
# Out:
#       Unnamed: 0      Activity      Opened      RID  St        Type        Sc  \
# 483          483  1.425251e+06  08/20/2019   950662  CA     Planned  Complete
# 998          998  1.040560e+06  02/17/2015   257250  PR  Prog Other   Partial
# 1058        1058  9.969990e+05  09/25/2014   418300  AL   Complaint   Partial
# 988          988  1.047346e+06  03/18/2015   213100  NY     Planned   Partial
# 148          148  1.569555e+06  12/20/2021   854910  UT   Complaint   Partial
# 933          933  1.094176e+06  09/24/2015   729700  KS   Complaint   Partial
# 278          278  1.533954e+06  05/26/2021   950621  CA    Accident   Partial
# 143          143  1.570673e+06  12/31/2021   950624  CA   Complaint   Partial
# 1508        1508  3.152814e+08  02/17/2011   453730  NC     Planned  Complete
# 1438        1438  9.835601e+04  09/01/2011   830600  CO   Complaint   Partial
# 1208        1208  3.119979e+08  07/18/2013   552652  MI     Planned  Complete
# ...

# %%
Current_Penalty_df['Total']=Current_Penalty_df['Total'].str.replace(',','')
# Out:
# /var/folders/tn/ddzd66z517378n9c45psbsb00000gn/T/ipykernel_31995/1813916620.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Current_Penalty_df['Total']=Current_Penalty_df['Total'].str.replace(',','')

# %%
Current_Penalty_df['Total']=Current_Penalty_df['Total'].str.replace('$','')
# Out:
# /var/folders/tn/ddzd66z517378n9c45psbsb00000gn/T/ipykernel_31995/2687917197.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Current_Penalty_df['Total']=Current_Penalty_df['Total'].str.replace('$','')
# /var/folders/tn/ddzd66z517378n9c45psbsb00000gn/T/ipykernel_31995/2687917197.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Current_Penalty_df['Total']=Current_Penalty_df['Total'].str.replace('$','')

# %%
Current_Penalty_df['Total'] = Current_Penalty_df['Total'].astype(int)
# Out:
# /var/folders/tn/ddzd66z517378n9c45psbsb00000gn/T/ipykernel_31995/808023915.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Current_Penalty_df['Total'] = Current_Penalty_df['Total'].astype(int)

# %%
Current_Penalty_df
# Out:
#       Unnamed: 0      Activity      Opened     RID  St        Type        Sc  \
# 3              3  1.617962e+06  08/29/2022  552652  MI   Complaint   Partial
# 8              8  1.617558e+06  08/25/2022  951510  HI  Prog Other  Complete
# 13            13  1.618144e+06  08/24/2022  452110  KY     Planned   Records
# 18            18  1.616220e+06  08/22/2022  552652  MI   Complaint   Partial
# 23            23  1.608665e+06  07/18/2022  950624  CA   Complaint   Partial
# ...          ...           ...         ...     ...  ..         ...       ...
# 1633        1633  3.129146e+08  04/06/2010  950625  CA   Complaint   Partial
# 1638        1638  3.134090e+08  03/10/2010  728500  MO     Planned  Complete
# 1643        1643  3.134539e+08  02/16/2010  257220  PR    Referral   Partial
# 1648        1648  3.139923e+08  01/11/2010  214200  NJ   Complaint   Partial
# 1653        1653  3.131530e+08  01/06/2010  522500  OH   Complaint   Partial
#
# ...

# %%
fines_df = Current_Penalty_df.groupby('simple_year')['Total'].sum()

# %%
fines_df
# Out:
# simple_year
# 2010     44576
# 2011    263470
# 2012     27864
# 2013     70638
# 2014     79690
# 2015     77770
# 2016     53893
# 2017     93358
# 2018    127494
# 2019    158938
# 2020    172625
# 2021    234857
# 2022    182791
# Name: Total, dtype: int64

# %%
new_df = fines_df.to_frame(name='fines')

# %%
new_df
# Out:
#               fines
# simple_year
# 2010          44576
# 2011         263470
# 2012          27864
# 2013          70638
# 2014          79690
# 2015          77770
# 2016          53893
# 2017          93358
# 2018         127494
# 2019         158938
# 2020         172625
# 2021         234857
# 2022         182791

# %%
new_df.to_csv('3_CurrentFines.csv')

# %% [markdown]
# ### 2. For Initial Penalty

# %%
Initial_Penalty_df = df[df['Violations/Penalties'] == 'Initial Penalty']

# %%
Initial_Penalty_df['Total']=Initial_Penalty_df['Total'].str.replace(',','')
# Out:
# /var/folders/tn/ddzd66z517378n9c45psbsb00000gn/T/ipykernel_31995/2220904101.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Initial_Penalty_df['Total']=Initial_Penalty_df['Total'].str.replace(',','')

# %%
Initial_Penalty_df['Total']=Initial_Penalty_df['Total'].str.replace('$','')
# Out:
# /var/folders/tn/ddzd66z517378n9c45psbsb00000gn/T/ipykernel_31995/2250080056.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Initial_Penalty_df['Total']=Initial_Penalty_df['Total'].str.replace('$','')
# /var/folders/tn/ddzd66z517378n9c45psbsb00000gn/T/ipykernel_31995/2250080056.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Initial_Penalty_df['Total']=Initial_Penalty_df['Total'].str.replace('$','')

# %%
Initial_Penalty_df['Total'] = Initial_Penalty_df['Total'].astype(int)
# Out:
# /var/folders/tn/ddzd66z517378n9c45psbsb00000gn/T/ipykernel_31995/1875070573.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Initial_Penalty_df['Total'] = Initial_Penalty_df['Total'].astype(int)

# %%
Initial_Penalty_df
# Out:
#       Unnamed: 0      Activity      Opened     RID  St        Type        Sc  \
# 2              2  1.617962e+06  08/29/2022  552652  MI   Complaint   Partial
# 7              7  1.617558e+06  08/25/2022  951510  HI  Prog Other  Complete
# 12            12  1.618144e+06  08/24/2022  452110  KY     Planned   Records
# 17            17  1.616220e+06  08/22/2022  552652  MI   Complaint   Partial
# 22            22  1.608665e+06  07/18/2022  950624  CA   Complaint   Partial
# ...          ...           ...         ...     ...  ..         ...       ...
# 1632        1632  3.129146e+08  04/06/2010  950625  CA   Complaint   Partial
# 1637        1637  3.134090e+08  03/10/2010  728500  MO     Planned  Complete
# 1642        1642  3.134539e+08  02/16/2010  257220  PR    Referral   Partial
# 1647        1647  3.139923e+08  01/11/2010  214200  NJ   Complaint   Partial
# 1652        1652  3.131530e+08  01/06/2010  522500  OH   Complaint   Partial
#
# ...

# %%
fines_df = Initial_Penalty_df.groupby('simple_year')['Total'].sum()

# %%
fines_df
# Out:
# simple_year
# 2010     92128
# 2011    518709
# 2012     49963
# 2013    158950
# 2014    147695
# 2015    104608
# 2016     83968
# 2017    158135
# 2018    190213
# 2019    242581
# 2020    255847
# 2021    323464
# 2022    236471
# Name: Total, dtype: int64

# %%
new_df = fines_df.to_frame(name='fines')

# %%
new_df
# Out:
#               fines
# simple_year
# 2010          92128
# 2011         518709
# 2012          49963
# 2013         158950
# 2014         147695
# 2015         104608
# 2016          83968
# 2017         158135
# 2018         190213
# 2019         242581
# 2020         255847
# 2021         323464
# 2022         236471

# %%
new_df.to_csv('3_InitialFines.csv')
