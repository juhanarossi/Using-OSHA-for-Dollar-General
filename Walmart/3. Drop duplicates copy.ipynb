# %%
import pandas as pd

# %%
# !ls
# Out:
# 1. Final-Scrape-Walmart.ipynb          3. Drop duplicates copy.ipynb
# 1_activities_df.csv                    3. Work2_MoreWork_Fines.ipynb
# 1_details_df.csv                       3_CurrentFines.csv
# 1_investigated_inspections_df.csv      3_InitialFines.csv
# 1_related_activity_df.csv              4. Work2_MoreWork_Fines.ipynb
# 1_violation_items_df.csv               4. Work2_MoreWork_Violations.ipynb
# 1_violation_summary_df.csv             4_CurrentViolations.csv
# 2. Joining_dfs_Violation_Summary.ipynb 4_InitialViolations.csv
# 2_final_df.csv                         5. Work2_MoreWork_Violations.ipynb

# %%
df = pd.read_csv("2_final_df.csv")
df
# Out:
#       Unnamed: 0      Activity      Opened     RID  St       Type       Sc  \
# 0              0  1.617962e+06  08/29/2022  552652  MI  Complaint  Partial
# 1              1  1.617962e+06  08/29/2022  552652  MI  Complaint  Partial
# 2              2  1.617962e+06  08/29/2022  552652  MI  Complaint  Partial
# 3              3  1.617962e+06  08/29/2022  552652  MI  Complaint  Partial
# 4              4  1.617962e+06  08/29/2022  552652  MI  Complaint  Partial
# ...          ...           ...         ...     ...  ..        ...      ...
# 1650        1650  3.131530e+08  01/06/2010  522500  OH  Complaint  Partial
# 1651        1651  3.131530e+08  01/06/2010  522500  OH  Complaint  Partial
# 1652        1652  3.131530e+08  01/06/2010  522500  OH  Complaint  Partial
# 1653        1653  3.131530e+08  01/06/2010  522500  OH  Complaint  Partial
# 1654        1654  3.131530e+08  01/06/2010  522500  OH  Complaint  Partial
#
# ...

# %%
Current_Penalty_df = df[df['Violations/Penalties'] == 'Current Penalty']
Current_Penalty_df = Current_Penalty_df.drop_duplicates(['Activity'])
Current_Penalty_df
# Out:
#       Unnamed: 0      Activity      Opened     RID  St        Type        Sc  \
# 3              3  1.617962e+06  08/29/2022  552652  MI   Complaint   Partial
# 8              8  1.617558e+06  08/25/2022  951510  HI  Prog Other  Complete
# 13            13  1.618144e+06  08/24/2022  452110  KY     Planned   Records
# 18            18  1.616220e+06  08/22/2022  552652  MI   Complaint   Partial
# 23            23  1.608665e+06  07/18/2022  950624  CA   Complaint   Partial
# ...          ...           ...         ...     ...  ..         ...       ...
# 1633        1633  3.129146e+08  04/06/2010  950625  CA   Complaint   Partial
# 1638        1638  3.134090e+08  03/10/2010  728500  MO     Planned  Complete
# 1643        1643  3.134539e+08  02/16/2010  257220  PR    Referral   Partial
# 1648        1648  3.139923e+08  01/11/2010  214200  NJ   Complaint   Partial
# 1653        1653  3.131530e+08  01/06/2010  522500  OH   Complaint   Partial
#
# ...

# %%
Initial_Penalty_df = df[df['Violations/Penalties'] == 'Initial Penalty']
Initial_Penalty_df = Initial_Penalty_df.drop_duplicates(['Activity'])
Initial_Penalty_df
# Out:
#       Unnamed: 0      Activity      Opened     RID  St        Type        Sc  \
# 2              2  1.617962e+06  08/29/2022  552652  MI   Complaint   Partial
# 7              7  1.617558e+06  08/25/2022  951510  HI  Prog Other  Complete
# 12            12  1.618144e+06  08/24/2022  452110  KY     Planned   Records
# 17            17  1.616220e+06  08/22/2022  552652  MI   Complaint   Partial
# 22            22  1.608665e+06  07/18/2022  950624  CA   Complaint   Partial
# ...          ...           ...         ...     ...  ..         ...       ...
# 1632        1632  3.129146e+08  04/06/2010  950625  CA   Complaint   Partial
# 1637        1637  3.134090e+08  03/10/2010  728500  MO     Planned  Complete
# 1642        1642  3.134539e+08  02/16/2010  257220  PR    Referral   Partial
# 1647        1647  3.139923e+08  01/11/2010  214200  NJ   Complaint   Partial
# 1652        1652  3.131530e+08  01/06/2010  522500  OH   Complaint   Partial
#
# ...

# %%
Current_Violations_df = df[df['Violations/Penalties'] == 'Current Violations']
Current_Violations_df = Current_Violations_df.drop_duplicates(['Activity'])
Current_Violations_df
# Out:
#       Unnamed: 0      Activity      Opened     RID  St        Type        Sc  \
# 1              1  1.617962e+06  08/29/2022  552652  MI   Complaint   Partial
# 6              6  1.617558e+06  08/25/2022  951510  HI  Prog Other  Complete
# 11            11  1.618144e+06  08/24/2022  452110  KY     Planned   Records
# 16            16  1.616220e+06  08/22/2022  552652  MI   Complaint   Partial
# 21            21  1.608665e+06  07/18/2022  950624  CA   Complaint   Partial
# ...          ...           ...         ...     ...  ..         ...       ...
# 1631        1631  3.129146e+08  04/06/2010  950625  CA   Complaint   Partial
# 1636        1636  3.134090e+08  03/10/2010  728500  MO     Planned  Complete
# 1641        1641  3.134539e+08  02/16/2010  257220  PR    Referral   Partial
# 1646        1646  3.139923e+08  01/11/2010  214200  NJ   Complaint   Partial
# 1651        1651  3.131530e+08  01/06/2010  522500  OH   Complaint   Partial
#
# ...

# %%
Initial_Violations_df = df[df['Violations/Penalties'] == 'Initial Violations']
Initial_Violations_df = Initial_Violations_df.drop_duplicates(['Activity'])
Initial_Violations_df
# Out:
#       Unnamed: 0      Activity      Opened     RID  St        Type        Sc  \
# 0              0  1.617962e+06  08/29/2022  552652  MI   Complaint   Partial
# 5              5  1.617558e+06  08/25/2022  951510  HI  Prog Other  Complete
# 10            10  1.618144e+06  08/24/2022  452110  KY     Planned   Records
# 15            15  1.616220e+06  08/22/2022  552652  MI   Complaint   Partial
# 20            20  1.608665e+06  07/18/2022  950624  CA   Complaint   Partial
# ...          ...           ...         ...     ...  ..         ...       ...
# 1630        1630  3.129146e+08  04/06/2010  950625  CA   Complaint   Partial
# 1635        1635  3.134090e+08  03/10/2010  728500  MO     Planned  Complete
# 1640        1640  3.134539e+08  02/16/2010  257220  PR    Referral   Partial
# 1645        1645  3.139923e+08  01/11/2010  214200  NJ   Complaint   Partial
# 1650        1650  3.131530e+08  01/06/2010  522500  OH   Complaint   Partial
#
# ...

# %%
Current_Penalty_df.to_csv('3_currentpenaltydrop.csv', index=False)

# %%
Initial_Penalty_df.to_csv('3_initialpenaltydrop.csv', index=False)

# %%
Current_Violations_df.to_csv('3_currentviolationsdrop.csv', index=False)

# %%
Initial_Violations_df.to_csv('3_initialviolationsdrop.csv', index=False)
