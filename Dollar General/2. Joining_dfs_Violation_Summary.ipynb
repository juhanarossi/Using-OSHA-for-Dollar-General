# %%
import pandas as pd
pd.options.display.max_colwidth = None
pd.options.display.max_columns = None

# %%
df1 = pd.read_csv("1_activities_df.csv")

# %%
df2 = pd.read_csv("1_details_df.csv")

# %%
df3 = pd.read_csv("1_violation_summary_df.csv")

# %%
df3
# Out:
#      Violations/Penalties Serious   Willful Repeat Other Unclass     Total  \
# 0      Initial Violations     NaN         2    NaN   NaN     NaN         2
# 1      Current Violations     NaN         2    NaN   NaN     NaN         2
# 2         Initial Penalty      $0  $140,000     $0    $0      $0  $140,000
# 3         Current Penalty      $0  $140,000     $0    $0      $0  $140,000
# 4             FTA Penalty      $0        $0     $0    $0      $0        $0
# ...                   ...     ...       ...    ...   ...     ...       ...
# 1300   Initial Violations       1       NaN    NaN     5     NaN         6
# 1301   Current Violations     NaN       NaN    NaN     6     NaN         6
# 1302      Initial Penalty  $2,750        $0     $0    $0      $0    $2,750
# 1303      Current Penalty      $0        $0     $0  $975      $0      $975
# 1304          FTA Penalty      $0        $0     $0    $0      $0        $0
#
#       activity_code
# 0      1.619753e+06
# 1      1.619753e+06
# 2      1.619753e+06
# 3      1.619753e+06
# 4      1.619753e+06
# ...             ...
# 1300   3.140213e+08
# 1301   3.140213e+08
# 1302   3.140213e+08
# 1303   3.140213e+08
# 1304   3.140213e+08
#
# [1305 rows x 8 columns]

# %%
master_df = pd.merge(df1, df2, how='inner', left_on='Activity', right_on='Inspection Nr')

# %%
master_df
# Out:
#          Activity      Opened     RID  St       Type        Sc   SIC_x  \
# 0    1.619753e+06  09/06/2022  452110  KY  Complaint   Partial  4225.0
# 1    1.617010e+06  08/25/2022  552652  MI  Complaint   Partial     NaN
# 2    1.609906e+06  07/25/2022  454716  TN  Complaint   Partial     NaN
# 3    1.607451e+06  07/13/2022  418100  GA  Complaint   Partial     NaN
# 4    1.601808e+06  06/14/2022  418400  GA  Complaint   Partial     NaN
# ..            ...         ...     ...  ..        ...       ...     ...
# 300  1.079844e+06  07/23/2015  419700  FL  Complaint   Partial     NaN
# 301  1.083884e+06  07/20/2015  418300  AL   Referral   Partial     NaN
# 302  1.062209e+06  05/11/2015  729300  MO  Complaint   Partial     NaN
# 303  3.167852e+08  08/14/2013  453710  NC  Complaint   Partial  5331.0
# 304  3.140213e+08  01/14/2010  453730  NC    Planned  Complete  5311.0
#
#      NAICS_x  Vio                                Establishment Name  \
# 0     493110    2                65337 - Dollar General Corporation
# 1     452319    1                             Dollar General #17771
# 2     452319    2                        Dollar General Corporation
# 3     445110    1  Dollar General Atlanta Fresh Distribution Center
# 4     452319    2       Dollar General Corporation/ Dolgencorp, Llc
# ..       ...  ...                                               ...
# 300   452990    2                                   Dolgencorp, Llc
# 301   452910    1                                   Dolgencorp, Llc
# 302   452112    2                                   Dolgencorp, Llc
# 303   452990    2                                   Dolgencorp, Llc
# 304   452112    6                                   Dolgencorp, Llc
#
#               query query_start   query_end Case Status  Inspection Nr  \
# 0    Dollar General  2012-12-31  2022-12-31        OPEN   1.619753e+06
# 1    Dollar General  2012-12-31  2022-12-31      CLOSED   1.617010e+06
# 2    Dollar General  2012-12-31  2022-12-31        OPEN   1.609906e+06
# 3    Dollar General  2012-12-31  2022-12-31        OPEN   1.607451e+06
# 4    Dollar General  2012-12-31  2022-12-31        OPEN   1.601808e+06
# ..              ...         ...         ...         ...            ...
# 300      dolgencorp  2012-12-31  2022-12-31      CLOSED   1.079844e+06
# 301      dolgencorp  2012-12-31  2022-12-31      CLOSED   1.083884e+06
# 302      dolgencorp  2012-12-31  2022-12-31      CLOSED   1.062209e+06
# 303      dolgencorp  2012-12-31  2022-12-31       ERROR   3.167852e+08
# 304      dolgencorp  2010-01-01  2012-12-30       ERROR   3.140213e+08
#
#      Report ID   Open Date  \
# 0       452110  09/06/2022
# 1       552652  08/25/2022
# 2       454716  07/25/2022
# 3       418100  07/13/2022
# 4       418400  06/14/2022
# ..         ...         ...
# 300     419700  07/23/2015
# 301     418300  07/20/2015
# 302     729300  05/11/2015
# 303     453710  08/14/2013
# 304     453730  01/14/2010
#
#                                                                                                        Site Address  \
# 0                                    65337 - Dollar General Corporation\n\t\t\t   950 Wenstrup LaneWalton, KY 41094
# 1                                                     Dollar General #17771\n\t\t\t   10600 East RoadBurt, MI 48417
# 2                                     Dollar General Corporation\n\t\t\t   4809 North Roan StJohnson City, TN 37615
# 3    Dollar General Atlanta Fresh Distribution Center\n\t\t\t   3569  International Park Drive, SeAtlanta, GA 30316
# 4                    Dollar General Corporation/ Dolgencorp, Llc\n\t\t\t   1106 W. Jackson St.Thomasville, GA 31792
# ..                                                                                                              ...
# 300                                                     Dolgencorp, Llc\n\t\t\t   306 8th Avenue NwJasper, FL 32052
# 301                                              Dolgencorp, Llc\n\t\t\t   4101 Lakeshore ParkwayBessemer, AL 35022
# 302                                                Dolgencorp, Llc\n\t\t\t   9465 Lewis And ClarkJennings, MO 63136
# 303                                                Dolgencorp, Llc\n\t\t\t   3427 Hillsborough RoadDurham, NC 27705
# 304                                               Dolgencorp, Llc\n\t\t\t   3864 W Franklin Blvd.Gastonia, NC 28052
#
#                                            Mailing Address Union Status  \
# 0              100 Mission Ridge, Goodlettsville, TN 37072     NonUnion
# 1                          10600 East Road, Burt, MI 48417     NonUnion
# 2               4809 North Roan St, Johnson City, TN 37615     NonUnion
# 3    3569  International Park Drive, Se, Atlanta, GA 30316     NonUnion
# 4               1106 W. Jackson St., Thomasville, GA 31792     NonUnion
# ..                                                     ...          ...
# 300            100 Mission Ridge, Goodlettsville, TN 37072     NonUnion
# 301             4101 Lakeshore Parkway, Bessemer, AL 35022     NonUnion
# 302                                        Adam Zager Attn     NonUnion
# 303                                             , ,  00000     NonUnion
# 304           3870 Kings Mountain Hwy., Gastonia, NC 28052     NonUnion
#
#       SIC_y  \
# 0    4225.0
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 300     NaN
# 301     NaN
# 302     NaN
# 303  5331.0
# 304  5311.0
#
#                                                                NAICS_y  \
# 0                               493110/General Warehousing and Storage
# 1                                                               452319
# 2                                                               452319
# 3    445110/Supermarkets and Other Grocery (except Convenience) Stores
# 4                                                               452319
# ..                                                                 ...
# 300                        452990/All Other General Merchandise Stores
# 301                            452910/Warehouse Clubs and Supercenters
# 302                                  452112/Discount Department Stores
# 303                        452990/All Other General Merchandise Stores
# 304                                  452112/Discount Department Stores
#
#     Inspection Type     Scope Advanced Notice  Ownership Safety/Health  \
# 0         Complaint   Partial               N    Private        Safety
# 1         Complaint   Partial               N    Private        Safety
# 2         Complaint   Partial               N    Private        Safety
# 3         Complaint   Partial               N  LocalGovt        Safety
# 4         Complaint   Partial               N    Private        Safety
# ..              ...       ...             ...        ...           ...
# 300       Complaint   Partial               N    Private        Safety
# 301        Referral   Partial               N    Private        Safety
# 302       Complaint   Partial               N    Private        Safety
# 303       Complaint   Partial               N    Private        Health
# 304         Planned  Complete               N    Private        Safety
#
#     Close Conference Emphasis  Close Case  activity_code  Investigation Nr  \
# 0         09/16/2022      NaN         NaN   1.619753e+06               NaN
# 1         09/14/2022      NaN  10/17/2022   1.617010e+06               NaN
# 2         07/25/2022      NaN         NaN   1.609906e+06               NaN
# 3         07/13/2022        L         NaN   1.607451e+06               NaN
# 4         06/14/2022      NaN         NaN   1.601808e+06               NaN
# ..               ...      ...         ...            ...               ...
# 300       07/23/2015      NaN  09/29/2015   1.079844e+06               NaN
# 301       07/20/2015        L  01/11/2016   1.083884e+06               NaN
# 302       05/11/2015      NaN  11/10/2015   1.062209e+06               NaN
# 303       08/14/2013      NaN  09/05/2013   3.167852e+08               NaN
# 304       01/14/2010        S  03/24/2010   3.140213e+08               NaN
#
#     Event investigation_summary_notes_1 Inspection Information - Office  \
# 0     NaN                           NaN                             NaN
# 1     NaN                           NaN                             NaN
# 2     NaN                           NaN                             NaN
# 3     NaN                           NaN                             NaN
# 4     NaN                           NaN                             NaN
# ..    ...                           ...                             ...
# 300   NaN                           NaN                             NaN
# 301   NaN                           NaN                             NaN
# 302   NaN                           NaN                             NaN
# 303   NaN                           NaN                             NaN
# 304   NaN                           NaN                             NaN
#
#     investigation_summary_notes_2 investigation_summary_notes_3 Keywords  \
# 0                             NaN                           NaN      NaN
# 1                             NaN                           NaN      NaN
# 2                             NaN                           NaN      NaN
# 3                             NaN                           NaN      NaN
# 4                             NaN                           NaN      NaN
# ..                            ...                           ...      ...
# 300                           NaN                           NaN      NaN
# 301                           NaN                           NaN      NaN
# 302                           NaN                           NaN      NaN
# 303                           NaN                           NaN      NaN
# 304                           NaN                           NaN      NaN
#
#            Planning Guide
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ..                    ...
# 300                   NaN
# 301                   NaN
# 302                   NaN
# 303  Health-Manufacturing
# 304  Safety-Manufacturing
#
# [305 rows x 39 columns]

# %%
final_df = pd.merge(master_df, df3, how='inner', left_on='Activity', right_on='activity_code')

# %%
final_df
# Out:
#           Activity      Opened     RID  St       Type        Sc   SIC_x  \
# 0     1.619753e+06  09/06/2022  452110  KY  Complaint   Partial  4225.0
# 1     1.619753e+06  09/06/2022  452110  KY  Complaint   Partial  4225.0
# 2     1.619753e+06  09/06/2022  452110  KY  Complaint   Partial  4225.0
# 3     1.619753e+06  09/06/2022  452110  KY  Complaint   Partial  4225.0
# 4     1.619753e+06  09/06/2022  452110  KY  Complaint   Partial  4225.0
# ...            ...         ...     ...  ..        ...       ...     ...
# 1960  3.140213e+08  01/14/2010  453730  NC    Planned  Complete  5311.0
# 1961  3.140213e+08  01/14/2010  453730  NC    Planned  Complete  5311.0
# 1962  3.140213e+08  01/14/2010  453730  NC    Planned  Complete  5311.0
# 1963  3.140213e+08  01/14/2010  453730  NC    Planned  Complete  5311.0
# 1964  3.140213e+08  01/14/2010  453730  NC    Planned  Complete  5311.0
#
#       NAICS_x  Vio                  Establishment Name           query  \
# 0      493110    2  65337 - Dollar General Corporation  Dollar General
# 1      493110    2  65337 - Dollar General Corporation  Dollar General
# 2      493110    2  65337 - Dollar General Corporation  Dollar General
# 3      493110    2  65337 - Dollar General Corporation  Dollar General
# 4      493110    2  65337 - Dollar General Corporation  Dollar General
# ...       ...  ...                                 ...             ...
# 1960   452112    6                     Dolgencorp, Llc      dolgencorp
# 1961   452112    6                     Dolgencorp, Llc      dolgencorp
# 1962   452112    6                     Dolgencorp, Llc      dolgencorp
# 1963   452112    6                     Dolgencorp, Llc      dolgencorp
# 1964   452112    6                     Dolgencorp, Llc      dolgencorp
#
#      query_start   query_end Case Status  Inspection Nr  Report ID  \
# 0     2012-12-31  2022-12-31        OPEN   1.619753e+06     452110
# 1     2012-12-31  2022-12-31        OPEN   1.619753e+06     452110
# 2     2012-12-31  2022-12-31        OPEN   1.619753e+06     452110
# 3     2012-12-31  2022-12-31        OPEN   1.619753e+06     452110
# 4     2012-12-31  2022-12-31        OPEN   1.619753e+06     452110
# ...          ...         ...         ...            ...        ...
# 1960  2010-01-01  2012-12-30       ERROR   3.140213e+08     453730
# 1961  2010-01-01  2012-12-30       ERROR   3.140213e+08     453730
# 1962  2010-01-01  2012-12-30       ERROR   3.140213e+08     453730
# 1963  2010-01-01  2012-12-30       ERROR   3.140213e+08     453730
# 1964  2010-01-01  2012-12-30       ERROR   3.140213e+08     453730
#
#        Open Date  \
# 0     09/06/2022
# 1     09/06/2022
# 2     09/06/2022
# 3     09/06/2022
# 4     09/06/2022
# ...          ...
# 1960  01/14/2010
# 1961  01/14/2010
# 1962  01/14/2010
# 1963  01/14/2010
# 1964  01/14/2010
#
#                                                                         Site Address  \
# 0     65337 - Dollar General Corporation\n\t\t\t   950 Wenstrup LaneWalton, KY 41094
# 1     65337 - Dollar General Corporation\n\t\t\t   950 Wenstrup LaneWalton, KY 41094
# 2     65337 - Dollar General Corporation\n\t\t\t   950 Wenstrup LaneWalton, KY 41094
# 3     65337 - Dollar General Corporation\n\t\t\t   950 Wenstrup LaneWalton, KY 41094
# 4     65337 - Dollar General Corporation\n\t\t\t   950 Wenstrup LaneWalton, KY 41094
# ...                                                                              ...
# 1960               Dolgencorp, Llc\n\t\t\t   3864 W Franklin Blvd.Gastonia, NC 28052
# 1961               Dolgencorp, Llc\n\t\t\t   3864 W Franklin Blvd.Gastonia, NC 28052
# 1962               Dolgencorp, Llc\n\t\t\t   3864 W Franklin Blvd.Gastonia, NC 28052
# 1963               Dolgencorp, Llc\n\t\t\t   3864 W Franklin Blvd.Gastonia, NC 28052
# 1964               Dolgencorp, Llc\n\t\t\t   3864 W Franklin Blvd.Gastonia, NC 28052
#
#                                    Mailing Address Union Status   SIC_y  \
# 0      100 Mission Ridge, Goodlettsville, TN 37072     NonUnion  4225.0
# 1      100 Mission Ridge, Goodlettsville, TN 37072     NonUnion  4225.0
# 2      100 Mission Ridge, Goodlettsville, TN 37072     NonUnion  4225.0
# 3      100 Mission Ridge, Goodlettsville, TN 37072     NonUnion  4225.0
# 4      100 Mission Ridge, Goodlettsville, TN 37072     NonUnion  4225.0
# ...                                            ...          ...     ...
# 1960  3870 Kings Mountain Hwy., Gastonia, NC 28052     NonUnion  5311.0
# 1961  3870 Kings Mountain Hwy., Gastonia, NC 28052     NonUnion  5311.0
# 1962  3870 Kings Mountain Hwy., Gastonia, NC 28052     NonUnion  5311.0
# 1963  3870 Kings Mountain Hwy., Gastonia, NC 28052     NonUnion  5311.0
# 1964  3870 Kings Mountain Hwy., Gastonia, NC 28052     NonUnion  5311.0
#
#                                      NAICS_y Inspection Type     Scope  \
# 0     493110/General Warehousing and Storage       Complaint   Partial
# 1     493110/General Warehousing and Storage       Complaint   Partial
# 2     493110/General Warehousing and Storage       Complaint   Partial
# 3     493110/General Warehousing and Storage       Complaint   Partial
# 4     493110/General Warehousing and Storage       Complaint   Partial
# ...                                      ...             ...       ...
# 1960       452112/Discount Department Stores         Planned  Complete
# 1961       452112/Discount Department Stores         Planned  Complete
# 1962       452112/Discount Department Stores         Planned  Complete
# 1963       452112/Discount Department Stores         Planned  Complete
# 1964       452112/Discount Department Stores         Planned  Complete
#
#      Advanced Notice Ownership Safety/Health Close Conference Emphasis  \
# 0                  N   Private        Safety       09/16/2022      NaN
# 1                  N   Private        Safety       09/16/2022      NaN
# 2                  N   Private        Safety       09/16/2022      NaN
# 3                  N   Private        Safety       09/16/2022      NaN
# 4                  N   Private        Safety       09/16/2022      NaN
# ...              ...       ...           ...              ...      ...
# 1960               N   Private        Safety       01/14/2010        S
# 1961               N   Private        Safety       01/14/2010        S
# 1962               N   Private        Safety       01/14/2010        S
# 1963               N   Private        Safety       01/14/2010        S
# 1964               N   Private        Safety       01/14/2010        S
#
#       Close Case  activity_code_x  Investigation Nr Event  \
# 0            NaN     1.619753e+06               NaN   NaN
# 1            NaN     1.619753e+06               NaN   NaN
# 2            NaN     1.619753e+06               NaN   NaN
# 3            NaN     1.619753e+06               NaN   NaN
# 4            NaN     1.619753e+06               NaN   NaN
# ...          ...              ...               ...   ...
# 1960  03/24/2010     3.140213e+08               NaN   NaN
# 1961  03/24/2010     3.140213e+08               NaN   NaN
# 1962  03/24/2010     3.140213e+08               NaN   NaN
# 1963  03/24/2010     3.140213e+08               NaN   NaN
# 1964  03/24/2010     3.140213e+08               NaN   NaN
#
#      investigation_summary_notes_1 Inspection Information - Office  \
# 0                              NaN                             NaN
# 1                              NaN                             NaN
# 2                              NaN                             NaN
# 3                              NaN                             NaN
# 4                              NaN                             NaN
# ...                            ...                             ...
# 1960                           NaN                             NaN
# 1961                           NaN                             NaN
# 1962                           NaN                             NaN
# 1963                           NaN                             NaN
# 1964                           NaN                             NaN
#
#      investigation_summary_notes_2 investigation_summary_notes_3 Keywords  \
# 0                              NaN                           NaN      NaN
# 1                              NaN                           NaN      NaN
# 2                              NaN                           NaN      NaN
# 3                              NaN                           NaN      NaN
# 4                              NaN                           NaN      NaN
# ...                            ...                           ...      ...
# 1960                           NaN                           NaN      NaN
# 1961                           NaN                           NaN      NaN
# 1962                           NaN                           NaN      NaN
# 1963                           NaN                           NaN      NaN
# 1964                           NaN                           NaN      NaN
#
#             Planning Guide Violations/Penalties Serious   Willful Repeat  \
# 0                      NaN   Initial Violations     NaN         2    NaN
# 1                      NaN   Current Violations     NaN         2    NaN
# 2                      NaN      Initial Penalty      $0  $140,000     $0
# 3                      NaN      Current Penalty      $0  $140,000     $0
# 4                      NaN          FTA Penalty      $0        $0     $0
# ...                    ...                  ...     ...       ...    ...
# 1960  Safety-Manufacturing   Initial Violations       1       NaN    NaN
# 1961  Safety-Manufacturing   Current Violations     NaN       NaN    NaN
# 1962  Safety-Manufacturing      Initial Penalty  $2,750        $0     $0
# 1963  Safety-Manufacturing      Current Penalty      $0        $0     $0
# 1964  Safety-Manufacturing          FTA Penalty      $0        $0     $0
#
#      Other Unclass     Total  activity_code_y
# 0      NaN     NaN         2     1.619753e+06
# 1      NaN     NaN         2     1.619753e+06
# 2       $0      $0  $140,000     1.619753e+06
# 3       $0      $0  $140,000     1.619753e+06
# 4       $0      $0        $0     1.619753e+06
# ...    ...     ...       ...              ...
# 1960     5     NaN         6     3.140213e+08
# 1961     6     NaN         6     3.140213e+08
# 1962    $0      $0    $2,750     3.140213e+08
# 1963  $975      $0      $975     3.140213e+08
# 1964    $0      $0        $0     3.140213e+08
#
# [1965 rows x 47 columns]

# %%
final_df.to_csv('2_final_df.csv')

# %%
# !ls
# Out:
# 1. Final-Scrape-DollarGeneral.ipynb    4. Work2_MoreWork_Fines.ipynb
# 1_DG_activities_df.csv                 5. Work2_MoreWork_Violations.ipynb
# 1_DG_details_df.csv                    Jan16DG_CurrentFines.csv
# 1_DG_investigated_inspections_df.csv   Jan16DG_Fines.csv
# 1_DG_related_activity_df.csv           Jan16DG_InitialFines.csv
# 1_DG_violation_items_df.csv            Jan16DG_Violations.csv
# 1_DG_violation_summary_df.csv          Jan16DG_currentdropduplicates.csv
# 2. Joining_dfs_Violation_Summary.ipynb Jan16DG_initialdropduplicates.csv
# 2_DG_final_df.csv                      Jan16DG_toDropDuplicates.csv
# 3. Drop duplicates.ipynb
