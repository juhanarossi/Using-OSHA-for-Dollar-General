# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlencode
import urllib.parse
from copy import copy

# %% [markdown]
# # Scrape index

# %%
# Define some functions to help scrape the index

def get_osha_url(query, start_date_str, end_date_str):
    
    results_per_page = 1000
    start_date = pd.to_datetime(start_date_str)
    end_date = pd.to_datetime(end_date_str)

    # make params dictionary
    base_url = f"https://www.osha.gov/ords/imis/establishment.search"
    params = {
        'establishment': '+'.join(query.split()),
        'state': "all",
        'officetype': "all",
        'office': "all",
        'sitezip': 100000,
        'startmonth': start_date.month,
        'startday': start_date.day,
        'startyear': start_date.year,
        'endmonth': end_date.month,
        'endday': end_date.day,
        'endyear': end_date.year,
        'p_case': "all",
        'p_sort': 12,
        'p_desc': "DESC",
        'p_direction': "Prev",
        'p_show': results_per_page,
        'p_violations_exist': "yes"
    }

    return base_url + '?' + urlencode(params)

def get_index_table(osha_url):
    return pd.read_html(osha_url)[2]

# %%
queries = [
    ('Dollar General', '2012-12-31', '2022-12-31'),
    ('Dollar General', '2010-01-01', '2012-12-30'),
    ('DG Retail', '2012-12-31', '2022-12-31'),
    ('dolgen', '2012-12-31', '2022-12-31'),
    ('dolgencorp', '2012-12-31', '2022-12-31'),
    ('dolgencorp', '2010-01-01', '2012-12-30')
]

# %%
activities_df = []
for query in queries:
    
    # break the query into 3 variables, and pass those to get_osha_url
    establishment, start, end = query   
    osha_url = get_osha_url(establishment, start, end)
    print(osha_url)
    
    # get the index table from the osha url, drop a junk column    
    index_df_for_this_query = get_index_table(osha_url)
    index_df_for_this_query = index_df_for_this_query.drop(columns=['Unnamed: 0', '#'])
    
    # tack on the query parameters to the table
    index_df_for_this_query['query'] = establishment
    index_df_for_this_query['query_start'] = start
    index_df_for_this_query['query_end'] = end
    
    # print to verify that pagination isn't a problem 
    # IMPORTANT: 👀 look at these values to make sure we don't need to paginate     
    print(f"found {len(index_df_for_this_query)} results for {query}\n")

    # append to dataframe
    activities_df.append(index_df_for_this_query)
    
# combine the queries
activities_df = pd.concat(activities_df)
activities_df.to_csv('1_activities_df.csv', index=False)
activities_df
# Out:
# https://www.osha.gov/ords/imis/establishment.search?establishment=Dollar%2BGeneral&state=all&officetype=all&office=all&sitezip=100000&startmonth=12&startday=31&startyear=2012&endmonth=12&endday=31&endyear=2022&p_case=all&p_sort=12&p_desc=DESC&p_direction=Prev&p_show=1000&p_violations_exist=yes
# found 140 results for ('Dollar General', '2012-12-31', '2022-12-31')
#
# https://www.osha.gov/ords/imis/establishment.search?establishment=Dollar%2BGeneral&state=all&officetype=all&office=all&sitezip=100000&startmonth=1&startday=1&startyear=2010&endmonth=12&endday=30&endyear=2012&p_case=all&p_sort=12&p_desc=DESC&p_direction=Prev&p_show=1000&p_violations_exist=yes
# found 25 results for ('Dollar General', '2010-01-01', '2012-12-30')
#
# https://www.osha.gov/ords/imis/establishment.search?establishment=DG%2BRetail&state=all&officetype=all&office=all&sitezip=100000&startmonth=12&startday=31&startyear=2012&endmonth=12&endday=31&endyear=2022&p_case=all&p_sort=12&p_desc=DESC&p_direction=Prev&p_show=1000&p_violations_exist=yes
# found 17 results for ('DG Retail', '2012-12-31', '2022-12-31')
#
# https://www.osha.gov/ords/imis/establishment.search?establishment=dolgen&state=all&officetype=all&office=all&sitezip=100000&startmonth=12&startday=31&startyear=2012&endmonth=12&endday=31&endyear=2022&p_case=all&p_sort=12&p_desc=DESC&p_direction=Prev&p_show=1000&p_violations_exist=yes
# found 15 results for ('dolgen', '2012-12-31', '2022-12-31')
#
# https://www.osha.gov/ords/imis/establishment.search?establishment=dolgencorp&state=all&officetype=all&office=all&sitezip=100000&startmonth=12&startday=31&startyear=2012&endmonth=12&endday=31&endyear=2022&p_case=all&p_sort=12&p_desc=DESC&p_direction=Prev&p_show=1000&p_violations_exist=yes
# found 60 results for ('dolgencorp', '2012-12-31', '2022-12-31')
#
# https://www.osha.gov/ords/imis/establishment.search?establishment=dolgencorp&state=all&officetype=all&office=all&sitezip=100000&startmonth=1&startday=1&startyear=2010&endmonth=12&endday=30&endyear=2012&p_case=all&p_sort=12&p_desc=DESC&p_direction=Prev&p_show=1000&p_violations_exist=yes
# found 4 results for ('dolgencorp', '2010-01-01', '2012-12-30')
#         Activity      Opened     RID  St       Type        Sc     SIC   NAICS  \
# 0   1.619753e+06  09/06/2022  452110  KY  Complaint   Partial  4225.0  493110
# 1   1.617010e+06  08/25/2022  552652  MI  Complaint   Partial     NaN  452319
# 2   1.609906e+06  07/25/2022  454716  TN  Complaint   Partial     NaN  452319
# 3   1.607451e+06  07/13/2022  418100  GA  Complaint   Partial     NaN  445110
# 4   1.601808e+06  06/14/2022  418400  GA  Complaint   Partial     NaN  452319
# ..           ...         ...     ...  ..        ...       ...     ...     ...
# 59  3.172754e+08  07/22/2013  453710  NC   Referral   Partial  5331.0  452990
# 0   3.165476e+08  11/14/2012  551800  IN  Complaint   Partial  5331.0  452990
# 1   3.167543e+08  10/10/2012  453710  NC  Complaint   Partial  5331.0  452990
# 2   3.138262e+08  03/15/2011  453710  NC  Complaint   Partial  5331.0  452990
# 3   3.140213e+08  01/14/2010  453730  NC    Planned  Complete  5311.0  452112
#
#     Vio                                Establishment Name           query  \
# 0     2                65337 - Dollar General Corporation  Dollar General
# 1     1                             Dollar General #17771  Dollar General
# 2     2                        Dollar General Corporation  Dollar General
# 3     1  Dollar General Atlanta Fresh Distribution Center  Dollar General
# 4     2       Dollar General Corporation/ Dolgencorp, Llc  Dollar General
# ..  ...                                               ...             ...
# 59    3   Dolgencorp, Llc Dba Dollar General Store # 1832      dolgencorp
# 0     1           Dolgencorp Llc Dba Dollar General #1598      dolgencorp
# 1     1                Dolgencorp, Llc Dba Dollar General      dolgencorp
# 2     3   Dolgencorp, Llc Dba Dollar General Store #10220      dolgencorp
# 3     6                                   Dolgencorp, Llc      dolgencorp
#
#    query_start   query_end
# 0   2012-12-31  2022-12-31
# 1   2012-12-31  2022-12-31
# 2   2012-12-31  2022-12-31
# 3   2012-12-31  2022-12-31
# 4   2012-12-31  2022-12-31
# ..         ...         ...
# 59  2012-12-31  2022-12-31
# 0   2010-01-01  2012-12-30
# 1   2010-01-01  2012-12-30
# 2   2010-01-01  2012-12-30
# 3   2010-01-01  2012-12-30
#
# [261 rows x 13 columns]

# %% [markdown]
# # Scrape individual activity pages

# %%
# Figure out how to scrape individual activity
def get_related_activity_table(url):
    tables = pd.read_html(url, match="Related Activity")
    return tables[0]

def get_violation_summary_table(url):
    tables = pd.read_html(url, match="Violation Summary")
    return tables[0]

def get_violation_items_table(url):
    tables = pd.read_html(url, match="Violation Items")
    return tables[0]

def get_investigated_inspection_table(url):
    tables = pd.read_html(url, match="Investigated Inspection")
    return tables[0]

def extract_key_value(tag):
    assert ':' in tag.text
    assert tag.find('strong')
    
    key = tag.text.split(':')[0].strip()
    value = tag.text.split(':')[1].strip()
    return key, value

def get_main_container(inspection_url):
    # get HTML from inspection page
    response = requests.get(inspection_url)
    html_doc = response.text
    soup = BeautifulSoup(html_doc, 'html.parser')

    # get main container (ignore footer/header/etc...)
    html_main_container = soup.find(id="maincontain")
    
    return html_main_container

def has_investigation_summary(html_main_container):
    h4s = html_main_container.find_all('h4')
    for h4 in h4s:
        if h4.text.strip() == "Investigation Summary":
            return True
    return False

def get_details(html_main_container):

    # Delete anything after "Investigation Summary H4"
    # we will scrape that stuff in a separate function
    h4s = html_main_container.find_all('h4')
    for h4 in h4s:
        if h4.text == "Investigation Summary":
            for e in h4.find_all_next():
                e.clear()
    
    # get details
    details = {}
    
    # get case status
    html_wells = html_main_container.find_all("div", class_="well")
    try:
        assert len(html_wells) == 2
        assert html_wells[0] == html_wells[1]
        case_status = html_wells[0]
        key, value = extract_key_value(case_status)                
    except:
        key = 'Case Status'
        value = 'ERROR'
        print("ERROR - couldn't scrape case status")
    details[key] = value
    
    # get remaining details
    html_spans = html_main_container.find_all("div", class_="span4")
    for span in html_spans:
        html_p_tags = span.find_all('p')
        if len(html_p_tags) == 0:
            columns_without_colon = 0
            key, value = extract_key_value(span)                
            details[key] = value
        else:
            for p_tag in html_p_tags:
                key, value = extract_key_value(p_tag)
                details[key] = value
    
    return details
    
def get_investigation_summary_details(html_main_container):
    # Delete anything after "Investigation Summary H4"
    # we will scrape that stuff in a separate function
    h4s = copy(html_main_container).find_all('h4')
    for h4 in h4s:
        if h4.text == "Investigation Summary":
            for e in h4.find_previous_siblings():
                e.decompose()

    details = {}

    spans = html_main_container.find_all('div', class_='span4')
    p_tags = html_main_container.find_all('p')
    spans_and_ptags = spans + p_tags
    
    details = {}
    notes_columns = 0
    for tag in spans_and_ptags:
        if ':' in tag.text and tag.find('strong'):
            key, value = extract_key_value(tag)
        else:
            notes_columns += 1
            key = f"investigation_summary_notes_{notes_columns}"
            value = tag.text
        details[key] = value
    
    return(details)

# %%
violation_summary_tables = []
violation_items_tables = []
related_activity_tables = []
details_dictionaries = []
investigated_inspections_table = []

for index, row in activities_df.reset_index(drop=True).iterrows():
    activity_code = row['Activity']
    url = f"https://www.osha.gov/ords/imis/establishment.inspection_detail?id={activity_code}"
    print(f"{index} of {len(activities_df)} - scraping {url}")

    violation_summary = get_violation_summary_table(url)
    violation_summary['activity_code'] = activity_code
    violation_summary_tables.append(violation_summary)
    
    violation_items = get_violation_items_table(url)
    violation_items['activity_code'] = activity_code
    violation_items_tables.append(violation_items)

    try:
        related_activity = get_related_activity_table(url)
        related_activity['activity_code'] = activity_code
        related_activity_tables.append(related_activity)
    except:
        print("ERROR - related activity table wasn't scraped")
        
    
    html = get_main_container(url)
    details = {}
    
    if has_investigation_summary(html):
        print("Has investigation summary")
        investigation_summary_details = get_investigation_summary_details(html)
        details.update(investigation_summary_details)
        
        investigated_inspections = get_investigated_inspection_table(url)
        investigated_inspections['activity_code'] = activity_code
        investigated_inspections_table.append(investigated_inspections)
        

    details.update(get_details(html))
    details['activity_code'] = activity_code    
    details_dictionaries.append(details)
# Out:
# 0 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1619753.015
# 1 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1617010.015
# 2 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1609906.015
# 3 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1607451.015
# 4 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1601808.015
# 5 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1599864.015
# 6 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1599901.015
# 7 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1598544.015
# 8 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1597335.015
# 9 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1596914.015
# 10 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1597065.015
# 11 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1596336.015
# 12 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1593249.015
# 13 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1592570.015
# 14 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1592900.015
# 15 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1592340.015
# 16 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1590827.015
# 17 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1590571.015
# 18 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1590051.015
# 19 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1589448.015
# 20 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1588719.015
# 21 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1586442.015
# 22 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1585314.015
# ERROR - related activity table wasn't scraped
# 23 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1585315.015
# 24 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1582871.015
# 25 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1580600.015
# 26 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1578203.015
# 27 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1575910.015
# 28 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1571838.015
# 29 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1572077.015
# 30 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1570337.015
# ERROR - related activity table wasn't scraped
# 31 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1568259.015
# 32 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1567718.015
# 33 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1565322.015
# 34 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1564582.015
# 35 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1565904.015
# 36 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1560126.015
# 37 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1559982.015
# 38 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1551005.015
# 39 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1550140.015
# 40 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1545894.015
# 41 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1466752.015
# 42 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1535655.015
# 43 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1524910.015
# 44 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1522252.015
# 45 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1517332.015
# 46 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1516101.015
# 47 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1510662.015
# 48 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1511904.015
# 49 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1509745.015
# 50 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1500289.015
# 51 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1498759.015
# 52 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1492446.015
# 53 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1487770.015
# 54 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1487012.015
# Has investigation summary
# 55 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1483184.015
# 56 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1469985.015
# 57 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1467642.015
# 58 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1461290.015
# 59 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1459326.015
# 60 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1455352.015
# 61 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1455290.015
# 62 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1453100.015
# 63 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1451004.015
# 64 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1450479.015
# 65 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1439273.015
# 66 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1436276.015
# 67 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1427131.015
# ERROR - related activity table wasn't scraped
# 68 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1422645.015
# 69 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1421761.015
# 70 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1417285.015
# 71 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1403214.015
# 72 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1395846.015
# 73 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1390605.015
# 74 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1381030.015
# 75 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1375565.015
# 76 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1352167.015
# 77 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1348061.015
# 78 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1336307.015
# Has investigation summary
# 79 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1329056.015
# Has investigation summary
# 80 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1323162.015
# 81 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1301615.015
# 82 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1283802.015
# 83 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1280975.015
# 84 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1265352.015
# 85 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1225250.015
# 86 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1226089.015
# 87 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1203374.015
# 88 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1201133.015
# 89 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1200685.015
# 90 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1195208.015
# 91 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1192554.015
# 92 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1184028.015
# 93 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1181678.015
# 94 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1180314.015
# 95 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1175610.015
# 96 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1172115.015
# 97 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1170666.015
# 98 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1167738.015
# 99 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1158861.015
# 100 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1153779.015
# 101 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1141463.015
# 102 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1122251.015
# 103 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1121762.015
# 104 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1105836.015
# 105 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1092862.015
# 106 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1079401.015
# 107 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1077466.015
# 108 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1076134.015
# 109 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1075508.015
# 110 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1059564.015
# 111 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1057017.015
# 112 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1057045.015
# 113 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1048760.015
# 114 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1047625.015
# 115 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1047652.015
# 116 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=317945020.0
# ERROR - related activity table wasn't scraped
# ERROR - couldn't scrape case status
# 117 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1016430.015
# 118 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1012465.015
# 119 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1008065.015
# 120 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1003589.015
# 121 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=317843498.0
# ERROR - related activity table wasn't scraped
# ERROR - couldn't scrape case status
# 122 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=316983402.0
# ERROR - couldn't scrape case status
# 123 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=992417.015
# 124 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=317730505.0
# ERROR - couldn't scrape case status
# 125 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=990109.015
# 126 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=989776.015
# 127 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=989056.015
# 128 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=985177.015
# 129 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=317692705.0
# ERROR - couldn't scrape case status
# 130 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=317724094.0
# ERROR - couldn't scrape case status
# 131 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=317403848.0
# ERROR - couldn't scrape case status
# 132 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=317313856.0
# ERROR - couldn't scrape case status
# 133 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=317275378.0
# Has investigation summary
# ERROR - couldn't scrape case status
# 134 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=317155430.0
# ERROR - couldn't scrape case status
# 135 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=907752.015
# 136 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=905396.015
# ERROR - related activity table wasn't scraped
# 137 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=892872.015
# 138 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=892646.015
# 139 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=316624287.0
# ERROR - couldn't scrape case status
# 140 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=765542.015
# Has investigation summary
# 141 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=316547587.0
# ERROR - couldn't scrape case status
# 142 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=728361.015
# 143 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=316754340.0
# ERROR - couldn't scrape case status
# 144 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=588783.015
# 145 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=315386185.0
# ERROR - couldn't scrape case status
# 146 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=316614528.0
# ERROR - couldn't scrape case status
# 147 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=316553668.0
# ERROR - couldn't scrape case status
# 148 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=315978684.0
# ERROR - couldn't scrape case status
# 149 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=316034271.0
# ERROR - couldn't scrape case status
# 150 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=315884858.0
# ERROR - couldn't scrape case status
# 151 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=97358.015
# 152 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=315637421.0
# ERROR - couldn't scrape case status
# 153 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=315651430.0
# ERROR - couldn't scrape case status
# 154 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=314307455.0
# ERROR - couldn't scrape case status
# 155 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=313826208.0
# ERROR - couldn't scrape case status
# 156 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=314910894.0
# ERROR - couldn't scrape case status
# 157 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=314276445.0
# ERROR - couldn't scrape case status
# 158 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=311879084.0
# ERROR - couldn't scrape case status
# 159 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=314380197.0
# ERROR - couldn't scrape case status
# 160 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=311809008.0
# ERROR - couldn't scrape case status
# 161 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=314300492.0
# ERROR - couldn't scrape case status
# 162 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=314418914.0
# ERROR - couldn't scrape case status
# 163 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=314337262.0
# ERROR - couldn't scrape case status
# 164 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=313407330.0
# ERROR - couldn't scrape case status
# 165 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1595340.015
# Has investigation summary
# 166 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1595364.015
# 167 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1593531.015
# 168 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1588930.015
# 169 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1572839.015
# 170 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1571816.015
# 171 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1555839.015
# 172 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1468409.015
# 173 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1450479.015
# 174 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1439273.015
# 175 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1436276.015
# 176 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1437320.015
# 177 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1263467.015
# 178 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1274821.015
# 179 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1192300.015
# 180 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1158939.015
# 181 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1134983.015
# 182 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1611456.015
# 183 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1602924.015
# 184 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1600211.015
# 185 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1598433.015
# 186 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1552837.015
# Has investigation summary
# 187 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1543340.015
# 188 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1540895.015
# 189 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1446226.015
# 190 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1444187.015
# 191 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1442594.015
# 192 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1442747.015
# 193 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1414696.015
# 194 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1277097.015
# 195 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1278507.015
# Has investigation summary
# 196 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1133331.015
# 197 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1626408.015
# 198 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1611042.015
# 199 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1605438.015
# 200 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1601808.015
# 201 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1599901.015
# 202 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1598544.015
# 203 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1597620.015
# 204 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1597065.015
# 205 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1596914.015
# 206 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1594459.015
# 207 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1593249.015
# 208 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1592570.015
# 209 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1590571.015
# 210 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1590827.015
# 211 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1589448.015
# 212 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1588719.015
# 213 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1571861.015
# 214 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1566292.015
# 215 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1550484.015
# 216 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1550619.015
# 217 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1550627.015
# 218 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1535419.015
# 219 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1522853.015
# 220 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1518325.015
# 221 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1510926.015
# 222 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1509783.015
# 223 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1507692.015
# 224 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1492118.015
# 225 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1489749.015
# 226 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1455672.015
# 227 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1453868.015
# 228 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1451004.015
# 229 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1446881.015
# 230 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1446325.015
# 231 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1401913.015
# 232 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1393851.015
# 233 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1376785.015
# 234 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1372897.015
# 235 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1333332.015
# 236 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1332824.015
# 237 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1333021.015
# 238 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1316798.015
# 239 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1279451.015
# 240 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1263006.015
# 241 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1200610.015
# 242 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1198147.015
# 243 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1188854.015
# 244 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1167163.015
# 245 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1132286.015
# 246 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1123994.015
# 247 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1121762.015
# 248 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1114508.015
# 249 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1082459.015
# 250 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1079844.015
# 251 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1083884.015
# 252 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1062209.015
# 253 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=317843498.0
# ERROR - related activity table wasn't scraped
# ERROR - couldn't scrape case status
# 254 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=317403848.0
# ERROR - couldn't scrape case status
# 255 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=316785211.0
# ERROR - couldn't scrape case status
# 256 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=317275378.0
# Has investigation summary
# ERROR - couldn't scrape case status
# 257 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=316547587.0
# ERROR - couldn't scrape case status
# 258 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=316754340.0
# ERROR - couldn't scrape case status
# 259 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=313826208.0
# ERROR - couldn't scrape case status
# 260 of 261 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=314021304.0
# ERROR - related activity table wasn't scraped
# ERROR - couldn't scrape case status

# %%
violation_summary_df = pd.concat(violation_summary_tables)
violation_items_df = pd.concat(violation_items_tables)
related_activity_df = pd.concat(related_activity_tables)
investigated_inspections_df = pd.concat(investigated_inspections_table)
details_df = pd.DataFrame(details_dictionaries)

# %%
# !mkdir
# Out:
# usage: mkdir [-pv] [-m mode] directory_name ...

# %%
violation_summary_df.to_csv('1_violation_summary_df.csv', index=False)
violation_items_df.to_csv('1_violation_items_df.csv', index=False)
related_activity_df.to_csv('1_related_activity_df.csv', index=False)
investigated_inspections_df.to_csv('1_investigated_inspections_df.csv', index=False)
details_df.to_csv('1_details_df.csv', index=False)
