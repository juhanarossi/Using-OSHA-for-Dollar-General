# %%
import pandas as pd

# %%
# !ls
# Out:
# 1. Final-Scrape-DollarGeneral.ipynb    3. Drop duplicates.ipynb
# 1_DG_activities_df.csv                 4. Work2_MoreWork_Fines.ipynb
# 1_DG_details_df.csv                    5. Work2_MoreWork_Violations.ipynb
# 1_DG_investigated_inspections_df.csv   Jan16DG_CurrentFines.csv
# 1_DG_related_activity_df.csv           Jan16DG_Fines.csv
# 1_DG_violation_items_df.csv            Jan16DG_InitialFines.csv
# 1_DG_violation_summary_df.csv          Jan16DG_Violations.csv
# 2. Joining_dfs_Violation_Summary.ipynb Jan16DG_toDropDuplicates.csv
# 2_DG_final_df.csv

# %%
df = pd.read_csv("2_final_df.csv")
df
# Out:
#       Unnamed: 0      Activity      Opened     RID  St       Type        Sc  \
# 0              0  1.619753e+06  09/06/2022  452110  KY  Complaint   Partial
# 1              1  1.619753e+06  09/06/2022  452110  KY  Complaint   Partial
# 2              2  1.619753e+06  09/06/2022  452110  KY  Complaint   Partial
# 3              3  1.619753e+06  09/06/2022  452110  KY  Complaint   Partial
# 4              4  1.619753e+06  09/06/2022  452110  KY  Complaint   Partial
# ...          ...           ...         ...     ...  ..        ...       ...
# 1960        1960  3.140213e+08  01/14/2010  453730  NC    Planned  Complete
# 1961        1961  3.140213e+08  01/14/2010  453730  NC    Planned  Complete
# 1962        1962  3.140213e+08  01/14/2010  453730  NC    Planned  Complete
# 1963        1963  3.140213e+08  01/14/2010  453730  NC    Planned  Complete
# 1964        1964  3.140213e+08  01/14/2010  453730  NC    Planned  Complete
#
#        SIC_x  NAICS_x  Vio  ... Keywords        Planning Guide  \
# 0     4225.0   493110    2  ...      NaN                   NaN
# 1     4225.0   493110    2  ...      NaN                   NaN
# 2     4225.0   493110    2  ...      NaN                   NaN
# 3     4225.0   493110    2  ...      NaN                   NaN
# 4     4225.0   493110    2  ...      NaN                   NaN
# ...      ...      ...  ...  ...      ...                   ...
# 1960  5311.0   452112    6  ...      NaN  Safety-Manufacturing
# 1961  5311.0   452112    6  ...      NaN  Safety-Manufacturing
# 1962  5311.0   452112    6  ...      NaN  Safety-Manufacturing
# 1963  5311.0   452112    6  ...      NaN  Safety-Manufacturing
# 1964  5311.0   452112    6  ...      NaN  Safety-Manufacturing
#
#      Violations/Penalties Serious   Willful  Repeat  Other Unclass     Total  \
# 0      Initial Violations     NaN         2     NaN    NaN     NaN         2
# 1      Current Violations     NaN         2     NaN    NaN     NaN         2
# 2         Initial Penalty      $0  $140,000      $0     $0      $0  $140,000
# 3         Current Penalty      $0  $140,000      $0     $0      $0  $140,000
# 4             FTA Penalty      $0        $0      $0     $0      $0        $0
# ...                   ...     ...       ...     ...    ...     ...       ...
# 1960   Initial Violations       1       NaN     NaN      5     NaN         6
# 1961   Current Violations     NaN       NaN     NaN      6     NaN         6
# 1962      Initial Penalty  $2,750        $0      $0     $0      $0    $2,750
# 1963      Current Penalty      $0        $0      $0   $975      $0      $975
# 1964          FTA Penalty      $0        $0      $0     $0      $0        $0
#
#      activity_code_y
# 0       1.619753e+06
# 1       1.619753e+06
# 2       1.619753e+06
# 3       1.619753e+06
# 4       1.619753e+06
# ...              ...
# 1960    3.140213e+08
# 1961    3.140213e+08
# 1962    3.140213e+08
# 1963    3.140213e+08
# 1964    3.140213e+08
#
# [1965 rows x 48 columns]

# %%
Current_Penalty_df = df[df['Violations/Penalties'] == 'Current Penalty']
Current_Penalty_df = Current_Penalty_df.drop_duplicates(['Activity'])
Current_Penalty_df
# Out:
#       Unnamed: 0      Activity      Opened     RID  St       Type        Sc  \
# 3              3  1.619753e+06  09/06/2022  452110  KY  Complaint   Partial
# 8              8  1.617010e+06  08/25/2022  552652  MI  Complaint   Partial
# 13            13  1.609906e+06  07/25/2022  454716  TN  Complaint   Partial
# 18            18  1.607451e+06  07/13/2022  418100  GA  Complaint   Partial
# 23            23  1.601808e+06  06/14/2022  418400  GA  Complaint   Partial
# ...          ...           ...         ...     ...  ..        ...       ...
# 1943        1943  1.079844e+06  07/23/2015  419700  FL  Complaint   Partial
# 1948        1948  1.083884e+06  07/20/2015  418300  AL   Referral   Partial
# 1953        1953  1.062209e+06  05/11/2015  729300  MO  Complaint   Partial
# 1958        1958  3.167852e+08  08/14/2013  453710  NC  Complaint   Partial
# 1963        1963  3.140213e+08  01/14/2010  453730  NC    Planned  Complete
#
#        SIC_x  NAICS_x  Vio  ... Keywords        Planning Guide  \
# 3     4225.0   493110    2  ...      NaN                   NaN
# 8        NaN   452319    1  ...      NaN                   NaN
# 13       NaN   452319    2  ...      NaN                   NaN
# 18       NaN   445110    1  ...      NaN                   NaN
# 23       NaN   452319    2  ...      NaN                   NaN
# ...      ...      ...  ...  ...      ...                   ...
# 1943     NaN   452990    2  ...      NaN                   NaN
# 1948     NaN   452910    1  ...      NaN                   NaN
# 1953     NaN   452112    2  ...      NaN                   NaN
# 1958  5331.0   452990    2  ...      NaN  Health-Manufacturing
# 1963  5311.0   452112    6  ...      NaN  Safety-Manufacturing
#
#      Violations/Penalties Serious   Willful    Repeat   Other Unclass  \
# 3         Current Penalty      $0  $140,000        $0      $0      $0
# 8         Current Penalty      $0        $0        $0      $0      $0
# 13        Current Penalty      $0        $0    $6,750      $0      $0
# 18        Current Penalty      $0        $0        $0  $5,283      $0
# 23        Current Penalty      $0        $0  $290,054      $0      $0
# ...                   ...     ...       ...       ...     ...     ...
# 1943      Current Penalty  $3,600        $0        $0      $0      $0
# 1948      Current Penalty      $0        $0        $0  $4,200      $0
# 1953      Current Penalty      $0        $0   $27,500    $550      $0
# 1958      Current Penalty      $0        $0        $0      $0      $0
# 1963      Current Penalty      $0        $0        $0    $975      $0
#
#          Total activity_code_y
# 3     $140,000    1.619753e+06
# 8           $0    1.617010e+06
# 13      $6,750    1.609906e+06
# 18      $5,283    1.607451e+06
# 23    $290,054    1.601808e+06
# ...        ...             ...
# 1943    $3,600    1.079844e+06
# 1948    $4,200    1.083884e+06
# 1953   $28,050    1.062209e+06
# 1958        $0    3.167852e+08
# 1963      $975    3.140213e+08
#
# [239 rows x 48 columns]

# %%
Initial_Penalty_df = df[df['Violations/Penalties'] == 'Initial Penalty']
Initial_Penalty_df = Initial_Penalty_df.drop_duplicates(['Activity'])
Initial_Penalty_df
# Out:
#       Unnamed: 0      Activity      Opened     RID  St       Type        Sc  \
# 2              2  1.619753e+06  09/06/2022  452110  KY  Complaint   Partial
# 7              7  1.617010e+06  08/25/2022  552652  MI  Complaint   Partial
# 12            12  1.609906e+06  07/25/2022  454716  TN  Complaint   Partial
# 17            17  1.607451e+06  07/13/2022  418100  GA  Complaint   Partial
# 22            22  1.601808e+06  06/14/2022  418400  GA  Complaint   Partial
# ...          ...           ...         ...     ...  ..        ...       ...
# 1942        1942  1.079844e+06  07/23/2015  419700  FL  Complaint   Partial
# 1947        1947  1.083884e+06  07/20/2015  418300  AL   Referral   Partial
# 1952        1952  1.062209e+06  05/11/2015  729300  MO  Complaint   Partial
# 1957        1957  3.167852e+08  08/14/2013  453710  NC  Complaint   Partial
# 1962        1962  3.140213e+08  01/14/2010  453730  NC    Planned  Complete
#
#        SIC_x  NAICS_x  Vio  ... Keywords        Planning Guide  \
# 2     4225.0   493110    2  ...      NaN                   NaN
# 7        NaN   452319    1  ...      NaN                   NaN
# 12       NaN   452319    2  ...      NaN                   NaN
# 17       NaN   445110    1  ...      NaN                   NaN
# 22       NaN   452319    2  ...      NaN                   NaN
# ...      ...      ...  ...  ...      ...                   ...
# 1942     NaN   452990    2  ...      NaN                   NaN
# 1947     NaN   452910    1  ...      NaN                   NaN
# 1952     NaN   452112    2  ...      NaN                   NaN
# 1957  5331.0   452990    2  ...      NaN  Health-Manufacturing
# 1962  5311.0   452112    6  ...      NaN  Safety-Manufacturing
#
#      Violations/Penalties Serious   Willful    Repeat   Other Unclass  \
# 2         Initial Penalty      $0  $140,000        $0      $0      $0
# 7         Initial Penalty      $0        $0        $0      $0      $0
# 12        Initial Penalty      $0        $0    $7,500      $0      $0
# 17        Initial Penalty  $5,283        $0        $0      $0      $0
# 22        Initial Penalty      $0        $0  $290,054      $0      $0
# ...                   ...     ...       ...       ...     ...     ...
# 1942      Initial Penalty  $6,000        $0        $0      $0      $0
# 1947      Initial Penalty  $6,000        $0        $0      $0      $0
# 1952      Initial Penalty      $0        $0   $55,000  $1,100      $0
# 1957      Initial Penalty      $0        $0        $0      $0      $0
# 1962      Initial Penalty  $2,750        $0        $0      $0      $0
#
#          Total activity_code_y
# 2     $140,000    1.619753e+06
# 7           $0    1.617010e+06
# 12      $7,500    1.609906e+06
# 17      $5,283    1.607451e+06
# 22    $290,054    1.601808e+06
# ...        ...             ...
# 1942    $6,000    1.079844e+06
# 1947    $6,000    1.083884e+06
# 1952   $56,100    1.062209e+06
# 1957        $0    3.167852e+08
# 1962    $2,750    3.140213e+08
#
# [239 rows x 48 columns]

# %%
Current_Violations_df = df[df['Violations/Penalties'] == 'Current Violations']
Current_Violations_df = Current_Violations_df.drop_duplicates(['Activity'])
Current_Violations_df
# Out:
#       Unnamed: 0      Activity      Opened     RID  St       Type        Sc  \
# 1              1  1.619753e+06  09/06/2022  452110  KY  Complaint   Partial
# 6              6  1.617010e+06  08/25/2022  552652  MI  Complaint   Partial
# 11            11  1.609906e+06  07/25/2022  454716  TN  Complaint   Partial
# 16            16  1.607451e+06  07/13/2022  418100  GA  Complaint   Partial
# 21            21  1.601808e+06  06/14/2022  418400  GA  Complaint   Partial
# ...          ...           ...         ...     ...  ..        ...       ...
# 1941        1941  1.079844e+06  07/23/2015  419700  FL  Complaint   Partial
# 1946        1946  1.083884e+06  07/20/2015  418300  AL   Referral   Partial
# 1951        1951  1.062209e+06  05/11/2015  729300  MO  Complaint   Partial
# 1956        1956  3.167852e+08  08/14/2013  453710  NC  Complaint   Partial
# 1961        1961  3.140213e+08  01/14/2010  453730  NC    Planned  Complete
#
#        SIC_x  NAICS_x  Vio  ... Keywords        Planning Guide  \
# 1     4225.0   493110    2  ...      NaN                   NaN
# 6        NaN   452319    1  ...      NaN                   NaN
# 11       NaN   452319    2  ...      NaN                   NaN
# 16       NaN   445110    1  ...      NaN                   NaN
# 21       NaN   452319    2  ...      NaN                   NaN
# ...      ...      ...  ...  ...      ...                   ...
# 1941     NaN   452990    2  ...      NaN                   NaN
# 1946     NaN   452910    1  ...      NaN                   NaN
# 1951     NaN   452112    2  ...      NaN                   NaN
# 1956  5331.0   452990    2  ...      NaN  Health-Manufacturing
# 1961  5311.0   452112    6  ...      NaN  Safety-Manufacturing
#
#      Violations/Penalties Serious Willful  Repeat  Other Unclass Total  \
# 1      Current Violations     NaN       2     NaN    NaN     NaN     2
# 6      Current Violations     NaN     NaN     NaN      1     NaN     1
# 11     Current Violations     NaN     NaN       2    NaN     NaN     2
# 16     Current Violations     NaN     NaN     NaN      1     NaN     1
# 21     Current Violations     NaN     NaN       2    NaN     NaN     2
# ...                   ...     ...     ...     ...    ...     ...   ...
# 1941   Current Violations       2     NaN     NaN    NaN     NaN     2
# 1946   Current Violations     NaN     NaN     NaN      1     NaN     1
# 1951   Current Violations     NaN     NaN       1      1     NaN     2
# 1956   Current Violations     NaN     NaN     NaN      2     NaN     2
# 1961   Current Violations     NaN     NaN     NaN      6     NaN     6
#
#      activity_code_y
# 1       1.619753e+06
# 6       1.617010e+06
# 11      1.609906e+06
# 16      1.607451e+06
# 21      1.601808e+06
# ...              ...
# 1941    1.079844e+06
# 1946    1.083884e+06
# 1951    1.062209e+06
# 1956    3.167852e+08
# 1961    3.140213e+08
#
# [239 rows x 48 columns]

# %%
Initial_Violations_df = df[df['Violations/Penalties'] == 'Initial Violations']
Initial_Violations_df = Initial_Violations_df.drop_duplicates(['Activity'])
Initial_Violations_df
# Out:
#       Unnamed: 0      Activity      Opened     RID  St       Type        Sc  \
# 0              0  1.619753e+06  09/06/2022  452110  KY  Complaint   Partial
# 5              5  1.617010e+06  08/25/2022  552652  MI  Complaint   Partial
# 10            10  1.609906e+06  07/25/2022  454716  TN  Complaint   Partial
# 15            15  1.607451e+06  07/13/2022  418100  GA  Complaint   Partial
# 20            20  1.601808e+06  06/14/2022  418400  GA  Complaint   Partial
# ...          ...           ...         ...     ...  ..        ...       ...
# 1940        1940  1.079844e+06  07/23/2015  419700  FL  Complaint   Partial
# 1945        1945  1.083884e+06  07/20/2015  418300  AL   Referral   Partial
# 1950        1950  1.062209e+06  05/11/2015  729300  MO  Complaint   Partial
# 1955        1955  3.167852e+08  08/14/2013  453710  NC  Complaint   Partial
# 1960        1960  3.140213e+08  01/14/2010  453730  NC    Planned  Complete
#
#        SIC_x  NAICS_x  Vio  ... Keywords        Planning Guide  \
# 0     4225.0   493110    2  ...      NaN                   NaN
# 5        NaN   452319    1  ...      NaN                   NaN
# 10       NaN   452319    2  ...      NaN                   NaN
# 15       NaN   445110    1  ...      NaN                   NaN
# 20       NaN   452319    2  ...      NaN                   NaN
# ...      ...      ...  ...  ...      ...                   ...
# 1940     NaN   452990    2  ...      NaN                   NaN
# 1945     NaN   452910    1  ...      NaN                   NaN
# 1950     NaN   452112    2  ...      NaN                   NaN
# 1955  5331.0   452990    2  ...      NaN  Health-Manufacturing
# 1960  5311.0   452112    6  ...      NaN  Safety-Manufacturing
#
#      Violations/Penalties Serious Willful  Repeat  Other Unclass Total  \
# 0      Initial Violations     NaN       2     NaN    NaN     NaN     2
# 5      Initial Violations     NaN     NaN     NaN      1     NaN     1
# 10     Initial Violations     NaN     NaN       2    NaN     NaN     2
# 15     Initial Violations       1     NaN     NaN    NaN     NaN     1
# 20     Initial Violations     NaN     NaN       2    NaN     NaN     2
# ...                   ...     ...     ...     ...    ...     ...   ...
# 1940   Initial Violations       2     NaN     NaN    NaN     NaN     2
# 1945   Initial Violations       1     NaN     NaN    NaN     NaN     1
# 1950   Initial Violations     NaN     NaN       1      1     NaN     2
# 1955   Initial Violations     NaN     NaN     NaN      2     NaN     2
# 1960   Initial Violations       1     NaN     NaN      5     NaN     6
#
#      activity_code_y
# 0       1.619753e+06
# 5       1.617010e+06
# 10      1.609906e+06
# 15      1.607451e+06
# 20      1.601808e+06
# ...              ...
# 1940    1.079844e+06
# 1945    1.083884e+06
# 1950    1.062209e+06
# 1955    3.167852e+08
# 1960    3.140213e+08
#
# [239 rows x 48 columns]

# %%
Current_Penalty_df.to_csv('3_currentpenaltydrop.csv', index=False)

# %%
Initial_Penalty_df.to_csv('3_initialpenaltydrop.csv', index=False)

# %%
Current_Violations_df.to_csv('3_currentviolationsdrop.csv', index=False)

# %%
Initial_Violations_df.to_csv('3_initialviolationsdrop.csv', index=False)
