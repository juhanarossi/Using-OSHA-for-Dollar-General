# %%
import pandas as pd

# %%
# !ls
# Out:
# 1. Final-Scrape-DollarTree.ipynb       2_final_df.csv
# 1_activities_df.csv                    3. Drop duplicates copy.ipynb
# 1_details_df.csv                       3. Work2_MoreWork_Fines.ipynb
# 1_investigated_inspections_df.csv      3_CurrentFines.csv
# 1_related_activity_df.csv              3_InitialFines.csv
# 1_violation_items_df.csv               4. Work2_MoreWork_Violations.ipynb
# 1_violation_summary_df.csv             4_CurrentViolations.csv
# 2. Joining_dfs_Violation_Summary.ipynb 4_InitialViolations.csv

# %%
df = pd.read_csv("2_final_df.csv")
df
# Out:
#       Unnamed: 0     Activity      Opened     RID  St       Type       Sc  \
# 0              0  1630373.015  10/25/2022  352450  MD  Complaint  Partial
# 1              1  1630373.015  10/25/2022  352450  MD  Complaint  Partial
# 2              2  1630373.015  10/25/2022  352450  MD  Complaint  Partial
# 3              3  1630373.015  10/25/2022  352450  MD  Complaint  Partial
# 4              4  1630373.015  10/25/2022  352450  MD  Complaint  Partial
# ...          ...          ...         ...     ...  ..        ...      ...
# 2795        2795  1133313.015  03/16/2016  112300  RI  Complaint  Partial
# 2796        2796  1133313.015  03/16/2016  112300  RI  Complaint  Partial
# 2797        2797  1133313.015  03/16/2016  112300  RI  Complaint  Partial
# 2798        2798  1133313.015  03/16/2016  112300  RI  Complaint  Partial
# 2799        2799  1133313.015  03/16/2016  112300  RI  Complaint  Partial
#
#       SIC_x  NAICS_x  Vio  ... Keywords Planning Guide Violations/Penalties  \
# 0       NaN   452319    3  ...      NaN            NaN   Initial Violations
# 1       NaN   452319    3  ...      NaN            NaN   Current Violations
# 2       NaN   452319    3  ...      NaN            NaN      Initial Penalty
# 3       NaN   452319    3  ...      NaN            NaN      Current Penalty
# 4       NaN   452319    3  ...      NaN            NaN          FTA Penalty
# ...     ...      ...  ...  ...      ...            ...                  ...
# 2795    NaN   452990    3  ...      NaN            NaN   Initial Violations
# 2796    NaN   452990    3  ...      NaN            NaN   Current Violations
# 2797    NaN   452990    3  ...      NaN            NaN      Initial Penalty
# 2798    NaN   452990    3  ...      NaN            NaN      Current Penalty
# 2799    NaN   452990    3  ...      NaN            NaN          FTA Penalty
#
#       Serious Willful  Repeat   Other Unclass    Total activity_code_y
# 0           1     NaN     NaN       2     NaN        3     1630373.015
# 1           1     NaN     NaN       2     NaN        3     1630373.015
# 2      $3,400      $0      $0      $0      $0   $3,400     1630373.015
# 3      $3,400      $0      $0      $0      $0   $3,400     1630373.015
# 4          $0      $0      $0      $0      $0       $0     1630373.015
# ...       ...     ...     ...     ...     ...      ...             ...
# 2795        3     NaN     NaN     NaN     NaN        3     1133313.015
# 2796        2     NaN     NaN       1     NaN        3     1133313.015
# 2797  $16,150      $0      $0      $0      $0  $16,150     1133313.015
# 2798   $6,545      $0      $0  $2,380      $0   $8,925     1133313.015
# 2799       $0      $0      $0      $0      $0       $0     1133313.015
#
# [2800 rows x 49 columns]

# %%
Current_Penalty_df = df[df['Violations/Penalties'] == 'Current Penalty']
Current_Penalty_df = Current_Penalty_df.drop_duplicates(['Activity'])
Current_Penalty_df
# Out:
#       Unnamed: 0     Activity      Opened     RID  St       Type        Sc  \
# 3              3  1630373.015  10/25/2022  352450  MD  Complaint   Partial
# 8              8  1618004.015  08/30/2022  317700  PA  Complaint   Partial
# 13            13  1616331.015  08/22/2022  453720  NC  Complaint   Partial
# 18            18  1618010.015  08/10/2022  316400  WV  Complaint   Partial
# 23            23  1612868.015  08/05/2022  953210  NV   Referral   Partial
# ...          ...          ...         ...     ...  ..        ...       ...
# 2778        2778  1184357.015  10/18/2016  355124  VA  Complaint   Partial
# 2783        2783  1173557.015  08/24/2016  627100  AR  Complaint   Partial
# 2788        2788  1168125.015  08/05/2016  419400  MS  Complaint   Partial
# 2793        2793  1144592.015  04/29/2016  215800  NY   Referral  Complete
# 2798        2798  1133313.015  03/16/2016  112300  RI  Complaint   Partial
#
#        SIC_x  NAICS_x  Vio  ... Keywords Planning Guide Violations/Penalties  \
# 3        NaN   452319    3  ...      NaN            NaN      Current Penalty
# 8        NaN   452319    2  ...      NaN            NaN      Current Penalty
# 13    5331.0   452990    6  ...      NaN            NaN      Current Penalty
# 18       NaN   452319    1  ...      NaN            NaN      Current Penalty
# 23       NaN   452319    1  ...      NaN            NaN      Current Penalty
# ...      ...      ...  ...  ...      ...            ...                  ...
# 2778     NaN   452990    1  ...      NaN            NaN      Current Penalty
# 2783     NaN   493110    1  ...      NaN            NaN      Current Penalty
# 2788     NaN   452112    1  ...      NaN            NaN      Current Penalty
# 2793     NaN   493110    4  ...      NaN            NaN      Current Penalty
# 2798     NaN   452990    3  ...      NaN            NaN      Current Penalty
#
#       Serious Willful   Repeat   Other Unclass    Total activity_code_y
# 3      $3,400      $0       $0      $0      $0   $3,400     1630373.015
# 8          $0      $0       $0      $0      $0       $0     1618004.015
# 13         $0      $0  $42,000      $0      $0  $42,000     1616331.015
# 18     $6,215      $0       $0      $0      $0   $6,215     1618010.015
# 23     $2,245      $0       $0      $0      $0   $2,245     1612868.015
# ...       ...     ...      ...     ...     ...      ...             ...
# 2778       $0      $0       $0      $0      $0       $0     1184357.015
# 2783  $12,471      $0       $0      $0      $0  $12,471     1173557.015
# 2788   $2,526      $0       $0      $0      $0   $2,526     1168125.015
# 2793  $18,707      $0       $0      $0      $0  $18,707     1144592.015
# 2798   $6,545      $0       $0  $2,380      $0   $8,925     1133313.015
#
# [525 rows x 49 columns]

# %%
Initial_Penalty_df = df[df['Violations/Penalties'] == 'Initial Penalty']
Initial_Penalty_df = Initial_Penalty_df.drop_duplicates(['Activity'])
Initial_Penalty_df
# Out:
#       Unnamed: 0     Activity      Opened     RID  St       Type        Sc  \
# 2              2  1630373.015  10/25/2022  352450  MD  Complaint   Partial
# 7              7  1618004.015  08/30/2022  317700  PA  Complaint   Partial
# 12            12  1616331.015  08/22/2022  453720  NC  Complaint   Partial
# 17            17  1618010.015  08/10/2022  316400  WV  Complaint   Partial
# 22            22  1612868.015  08/05/2022  953210  NV   Referral   Partial
# ...          ...          ...         ...     ...  ..        ...       ...
# 2777        2777  1184357.015  10/18/2016  355124  VA  Complaint   Partial
# 2782        2782  1173557.015  08/24/2016  627100  AR  Complaint   Partial
# 2787        2787  1168125.015  08/05/2016  419400  MS  Complaint   Partial
# 2792        2792  1144592.015  04/29/2016  215800  NY   Referral  Complete
# 2797        2797  1133313.015  03/16/2016  112300  RI  Complaint   Partial
#
#        SIC_x  NAICS_x  Vio  ... Keywords Planning Guide Violations/Penalties  \
# 2        NaN   452319    3  ...      NaN            NaN      Initial Penalty
# 7        NaN   452319    2  ...      NaN            NaN      Initial Penalty
# 12    5331.0   452990    6  ...      NaN            NaN      Initial Penalty
# 17       NaN   452319    1  ...      NaN            NaN      Initial Penalty
# 22       NaN   452319    1  ...      NaN            NaN      Initial Penalty
# ...      ...      ...  ...  ...      ...            ...                  ...
# 2777     NaN   452990    1  ...      NaN            NaN      Initial Penalty
# 2782     NaN   493110    1  ...      NaN            NaN      Initial Penalty
# 2787     NaN   452112    1  ...      NaN            NaN      Initial Penalty
# 2792     NaN   493110    4  ...      NaN            NaN      Initial Penalty
# 2797     NaN   452990    3  ...      NaN            NaN      Initial Penalty
#
#       Serious Willful   Repeat  Other Unclass    Total activity_code_y
# 2      $3,400      $0       $0     $0      $0   $3,400     1630373.015
# 7          $0      $0       $0     $0      $0       $0     1618004.015
# 12         $0      $0  $42,000     $0      $0  $42,000     1616331.015
# 17     $6,215      $0       $0     $0      $0   $6,215     1618010.015
# 22     $4,490      $0       $0     $0      $0   $4,490     1612868.015
# ...       ...     ...      ...    ...     ...      ...             ...
# 2777       $0      $0       $0     $0      $0       $0     1184357.015
# 2782  $12,471      $0       $0     $0      $0  $12,471     1173557.015
# 2787   $2,526      $0       $0     $0      $0   $2,526     1168125.015
# 2792  $35,632      $0       $0     $0      $0  $35,632     1144592.015
# 2797  $16,150      $0       $0     $0      $0  $16,150     1133313.015
#
# [525 rows x 49 columns]

# %%
Current_Violations_df = df[df['Violations/Penalties'] == 'Current Violations']
Current_Violations_df = Current_Violations_df.drop_duplicates(['Activity'])
Current_Violations_df
# Out:
#       Unnamed: 0     Activity      Opened     RID  St       Type        Sc  \
# 1              1  1630373.015  10/25/2022  352450  MD  Complaint   Partial
# 6              6  1618004.015  08/30/2022  317700  PA  Complaint   Partial
# 11            11  1616331.015  08/22/2022  453720  NC  Complaint   Partial
# 16            16  1618010.015  08/10/2022  316400  WV  Complaint   Partial
# 21            21  1612868.015  08/05/2022  953210  NV   Referral   Partial
# ...          ...          ...         ...     ...  ..        ...       ...
# 2776        2776  1184357.015  10/18/2016  355124  VA  Complaint   Partial
# 2781        2781  1173557.015  08/24/2016  627100  AR  Complaint   Partial
# 2786        2786  1168125.015  08/05/2016  419400  MS  Complaint   Partial
# 2791        2791  1144592.015  04/29/2016  215800  NY   Referral  Complete
# 2796        2796  1133313.015  03/16/2016  112300  RI  Complaint   Partial
#
#        SIC_x  NAICS_x  Vio  ... Keywords Planning Guide Violations/Penalties  \
# 1        NaN   452319    3  ...      NaN            NaN   Current Violations
# 6        NaN   452319    2  ...      NaN            NaN   Current Violations
# 11    5331.0   452990    6  ...      NaN            NaN   Current Violations
# 16       NaN   452319    1  ...      NaN            NaN   Current Violations
# 21       NaN   452319    1  ...      NaN            NaN   Current Violations
# ...      ...      ...  ...  ...      ...            ...                  ...
# 2776     NaN   452990    1  ...      NaN            NaN   Current Violations
# 2781     NaN   493110    1  ...      NaN            NaN   Current Violations
# 2786     NaN   452112    1  ...      NaN            NaN   Current Violations
# 2791     NaN   493110    4  ...      NaN            NaN   Current Violations
# 2796     NaN   452990    3  ...      NaN            NaN   Current Violations
#
#      Serious Willful  Repeat  Other Unclass Total activity_code_y
# 1          1     NaN     NaN      2     NaN     3     1630373.015
# 6        NaN     NaN     NaN      2     NaN     2     1618004.015
# 11       NaN     NaN       4      2     NaN     6     1616331.015
# 16         1     NaN     NaN    NaN     NaN     1     1618010.015
# 21         1     NaN     NaN    NaN     NaN     1     1612868.015
# ...      ...     ...     ...    ...     ...   ...             ...
# 2776     NaN     NaN     NaN      1     NaN     1     1184357.015
# 2781       1     NaN     NaN    NaN     NaN     1     1173557.015
# 2786       1     NaN     NaN    NaN     NaN     1     1168125.015
# 2791       3     NaN     NaN      1     NaN     4     1144592.015
# 2796       2     NaN     NaN      1     NaN     3     1133313.015
#
# [525 rows x 49 columns]

# %%
Initial_Violations_df = df[df['Violations/Penalties'] == 'Initial Violations']
Initial_Violations_df = Initial_Violations_df.drop_duplicates(['Activity'])
Initial_Violations_df
# Out:
#       Unnamed: 0     Activity      Opened     RID  St       Type        Sc  \
# 0              0  1630373.015  10/25/2022  352450  MD  Complaint   Partial
# 5              5  1618004.015  08/30/2022  317700  PA  Complaint   Partial
# 10            10  1616331.015  08/22/2022  453720  NC  Complaint   Partial
# 15            15  1618010.015  08/10/2022  316400  WV  Complaint   Partial
# 20            20  1612868.015  08/05/2022  953210  NV   Referral   Partial
# ...          ...          ...         ...     ...  ..        ...       ...
# 2775        2775  1184357.015  10/18/2016  355124  VA  Complaint   Partial
# 2780        2780  1173557.015  08/24/2016  627100  AR  Complaint   Partial
# 2785        2785  1168125.015  08/05/2016  419400  MS  Complaint   Partial
# 2790        2790  1144592.015  04/29/2016  215800  NY   Referral  Complete
# 2795        2795  1133313.015  03/16/2016  112300  RI  Complaint   Partial
#
#        SIC_x  NAICS_x  Vio  ... Keywords Planning Guide Violations/Penalties  \
# 0        NaN   452319    3  ...      NaN            NaN   Initial Violations
# 5        NaN   452319    2  ...      NaN            NaN   Initial Violations
# 10    5331.0   452990    6  ...      NaN            NaN   Initial Violations
# 15       NaN   452319    1  ...      NaN            NaN   Initial Violations
# 20       NaN   452319    1  ...      NaN            NaN   Initial Violations
# ...      ...      ...  ...  ...      ...            ...                  ...
# 2775     NaN   452990    1  ...      NaN            NaN   Initial Violations
# 2780     NaN   493110    1  ...      NaN            NaN   Initial Violations
# 2785     NaN   452112    1  ...      NaN            NaN   Initial Violations
# 2790     NaN   493110    4  ...      NaN            NaN   Initial Violations
# 2795     NaN   452990    3  ...      NaN            NaN   Initial Violations
#
#      Serious Willful  Repeat  Other Unclass Total activity_code_y
# 0          1     NaN     NaN      2     NaN     3     1630373.015
# 5        NaN     NaN     NaN      2     NaN     2     1618004.015
# 10       NaN     NaN       4      2     NaN     6     1616331.015
# 15         1     NaN     NaN    NaN     NaN     1     1618010.015
# 20         1     NaN     NaN    NaN     NaN     1     1612868.015
# ...      ...     ...     ...    ...     ...   ...             ...
# 2775     NaN     NaN     NaN      1     NaN     1     1184357.015
# 2780       1     NaN     NaN    NaN     NaN     1     1173557.015
# 2785       1     NaN     NaN    NaN     NaN     1     1168125.015
# 2790       4     NaN     NaN    NaN     NaN     4     1144592.015
# 2795       3     NaN     NaN    NaN     NaN     3     1133313.015
#
# [525 rows x 49 columns]

# %%
Current_Penalty_df.to_csv('3_currentpenaltydrop.csv', index=False)

# %%
Initial_Penalty_df.to_csv('3_initialpenaltydrop.csv', index=False)

# %%
Current_Violations_df.to_csv('3_currentviolationsdrop.csv', index=False)

# %%
Initial_Violations_df.to_csv('3_initialviolationsdrop.csv', index=False)
