# %%
import pandas as pd
pd.options.display.max_colwidth = None
pd.options.display.max_columns = None

# %%
df1 = pd.read_csv("1_activities_df.csv")

# %%
df2 = pd.read_csv("1_details_df.csv")

# %%
df3 = pd.read_csv("1_violation_summary_df.csv")

# %%
df3
# Out:
#      Violations/Penalties  Serious Willful Repeat   Other Unclass    Total  \
# 0      Initial Violations        1     NaN    NaN       2     NaN        3
# 1      Current Violations        1     NaN    NaN       2     NaN        3
# 2         Initial Penalty   $3,400      $0     $0      $0      $0   $3,400
# 3         Current Penalty   $3,400      $0     $0      $0      $0   $3,400
# 4             FTA Penalty       $0      $0     $0      $0      $0       $0
# ...                   ...      ...     ...    ...     ...     ...      ...
# 2645   Initial Violations        3     NaN    NaN     NaN     NaN        3
# 2646   Current Violations        2     NaN    NaN       1     NaN        3
# 2647      Initial Penalty  $16,150      $0     $0      $0      $0  $16,150
# 2648      Current Penalty   $6,545      $0     $0  $2,380      $0   $8,925
# 2649          FTA Penalty       $0      $0     $0      $0      $0       $0
#
#       activity_code
# 0       1630373.015
# 1       1630373.015
# 2       1630373.015
# 3       1630373.015
# 4       1630373.015
# ...             ...
# 2645    1133313.015
# 2646    1133313.015
# 2647    1133313.015
# 2648    1133313.015
# 2649    1133313.015
#
# [2650 rows x 8 columns]

# %%
master_df = pd.merge(df1, df2, how='inner', left_on='Activity', right_on='Inspection Nr')

# %%
master_df
# Out:
#         Activity      Opened     RID  St       Type        Sc   SIC_x  \
# 0    1630373.015  10/25/2022  352450  MD  Complaint   Partial     NaN
# 1    1618004.015  08/30/2022  317700  PA  Complaint   Partial     NaN
# 2    1616331.015  08/22/2022  453720  NC  Complaint   Partial  5331.0
# 3    1618010.015  08/10/2022  316400  WV  Complaint   Partial     NaN
# 4    1612868.015  08/05/2022  953210  NV   Referral   Partial     NaN
# ..           ...         ...     ...  ..        ...       ...     ...
# 535  1184357.015  10/18/2016  355124  VA  Complaint   Partial     NaN
# 536  1173557.015  08/24/2016  627100  AR  Complaint   Partial     NaN
# 537  1168125.015  08/05/2016  419400  MS  Complaint   Partial     NaN
# 538  1144592.015  04/29/2016  215800  NY   Referral  Complete     NaN
# 539  1133313.015  03/16/2016  112300  RI  Complaint   Partial     NaN
#
#      NAICS_x  Vio                          Establishment Name          query  \
# 0     452319    3                    Dollar Tree Stores, Inc.    Dollar Tree
# 1     452319    2                                 Dollar Tree    Dollar Tree
# 2     452990    6           152579 - Dollar Tree Stores, Inc.    Dollar Tree
# 3     452319    1                     Dollar Tree Stores, Inc    Dollar Tree
# 4     452319    1              Dollar Tree Stores, Inc. #1224    Dollar Tree
# ..       ...  ...                                         ...            ...
# 535   452990    1                               Family Dollar  Family Dollar
# 536   493110    1           Family Dollar Distribution Center  Family Dollar
# 537   452112    1                               Family Dollar  Family Dollar
# 538   493110    4                 Family Dollar Services, Inc  Family Dollar
# 539   452990    3  Family Dollar Stores Of Rhode Island, Inc.  Family Dollar
#
#     query_start   query_end Case Status  Inspection Nr  Report ID   Open Date  \
# 0    2012-12-31  2022-12-31      CLOSED    1630373.015     352450  10/25/2022
# 1    2012-12-31  2022-12-31        OPEN    1618004.015     317700  08/30/2022
# 2    2012-12-31  2022-12-31      CLOSED    1616331.015     453720  08/22/2022
# 3    2012-12-31  2022-12-31      CLOSED    1618010.015     316400  08/10/2022
# 4    2012-12-31  2022-12-31      CLOSED    1612868.015     953210  08/05/2022
# ..          ...         ...         ...            ...        ...         ...
# 535  2016-01-01  2022-12-31      CLOSED    1184357.015     355124  10/18/2016
# 536  2016-01-01  2022-12-31      CLOSED    1173557.015     627100  08/24/2016
# 537  2016-01-01  2022-12-31      CLOSED    1168125.015     419400  08/05/2016
# 538  2016-01-01  2022-12-31      CLOSED    1144592.015     215800  04/29/2016
# 539  2016-01-01  2022-12-31      CLOSED    1133313.015     112300  03/16/2016
#
#                                                                                                      Site Address  \
# 0                              Dollar Tree Stores, Inc.\n\t\t\t   8157 Governor Ritchie HighwayPasadena, MD 21122
# 1                                                    Dollar Tree\n\t\t\t   89 Brooklyn StreetCarbondale, PA 18407
# 2                                 152579 - Dollar Tree Stores, Inc.\n\t\t\t   2 Riceville RoadAsheville, NC 28805
# 3                                            Dollar Tree Stores, Inc\n\t\t\t   950 9th AvenueHuntington, WV 25701
# 4                           Dollar Tree Stores, Inc. #1224\n\t\t\t   620 North Mccarran BoulevardSparks, NV 89431
# ..                                                                                                            ...
# 535                                              Family Dollar\n\t\t\t   540 Newtown RoadVirginia Beach, VA 23462
# 536                    Family Dollar Distribution Center\n\t\t\t   1800 Family Dollar DriveWest Memphis, AR 72301
# 537                                            Family Dollar\n\t\t\t   705 East Church StreetBooneville, MS 38829
# 538                                        Family Dollar Services, Inc\n\t\t\t   640 Perimeter RoadRome, NY 13441
# 539  Family Dollar Stores Of Rhode Island, Inc.\n\t\t\t   Store Number 8177, 541 Smith StreetProvidence, RI 02908
#
#                                                       Mailing Address  \
# 0    500 Volvo Parkway Attention Larisa Rapnick, Chesapeake, VA 23320
# 1                             500 Volvo Parkway, Chesapeake, VA 23320
# 2                             500 Volvo Parkway, Chesapeake, VA 23320
# 3                             500 Volvo Parkway, Chesapeake, VA 23320
# 4                                              500 Volvo Parkway Attn
# ..                                                                ...
# 535                           500 Volvo Parkway, Chesapeake, VA 23320
# 536                  1800 Family Dollar Drive, West Memphis, AR 72301
# 537                      705 East Church Street, Booneville, MS 38829
# 538                                640 Perimeter Road, Rome, NY 13441
# 539                                P.O. Box 1017, Charlotte, NC 28201
#
#     Union Status   SIC_y                                      NAICS_y  \
# 0       NonUnion     NaN                                       452319
# 1       NonUnion     NaN                                       452319
# 2       NonUnion  5331.0  452990/All Other General Merchandise Stores
# 3       NonUnion     NaN                                       452319
# 4       NonUnion     NaN                                       452319
# ..           ...     ...                                          ...
# 535     NonUnion     NaN  452990/All Other General Merchandise Stores
# 536     NonUnion     NaN       493110/General Warehousing and Storage
# 537     NonUnion     NaN            452112/Discount Department Stores
# 538     NonUnion     NaN       493110/General Warehousing and Storage
# 539     NonUnion     NaN  452990/All Other General Merchandise Stores
#
#     Inspection Type     Scope Advanced Notice Ownership Safety/Health  \
# 0         Complaint   Partial               N   Private        Safety
# 1         Complaint   Partial               N   Private        Safety
# 2         Complaint   Partial               N   Private        Safety
# 3         Complaint   Partial               N   Private        Health
# 4          Referral   Partial               N   Private        Safety
# ..              ...       ...             ...       ...           ...
# 535       Complaint   Partial               N   Private        Health
# 536       Complaint   Partial               N   Private        Safety
# 537       Complaint   Partial               N   Private        Health
# 538        Referral  Complete               N   Private        Safety
# 539       Complaint   Partial               N   Private        Safety
#
#     Close Conference Emphasis  Close Case  activity_code  Investigation Nr  \
# 0         11/07/2022      NaN  12/30/2022    1630373.015               NaN
# 1                NaN      NaN         NaN    1618004.015               NaN
# 2         08/22/2022      NaN  11/10/2022    1616331.015               NaN
# 3         08/30/2022      NaN  10/31/2022    1618010.015               NaN
# 4         08/12/2022      NaN  10/24/2022    1612868.015               NaN
# ..               ...      ...         ...            ...               ...
# 535       10/31/2016      NaN  12/13/2016    1184357.015               NaN
# 536       08/24/2016      NaN  01/31/2017    1173557.015               NaN
# 537       09/13/2016      NaN  01/31/2017    1168125.015               NaN
# 538       07/22/2016        P  07/17/2017    1144592.015               NaN
# 539       03/16/2016      NaN  08/30/2016    1133313.015               NaN
#
#     Event investigation_summary_notes_1 Note Inspection Information - Office  \
# 0     NaN                           NaN  NaN                             NaN
# 1     NaN                           NaN  NaN                             NaN
# 2     NaN                           NaN  NaN                             NaN
# 3     NaN                           NaN  NaN                             NaN
# 4     NaN                           NaN  NaN                             NaN
# ..    ...                           ...  ...                             ...
# 535   NaN                           NaN  NaN                             NaN
# 536   NaN                           NaN  NaN                             NaN
# 537   NaN                           NaN  NaN                             NaN
# 538   NaN                           NaN  NaN                             NaN
# 539   NaN                           NaN  NaN                             NaN
#
#     investigation_summary_notes_2 investigation_summary_notes_3 Keywords  \
# 0                             NaN                           NaN      NaN
# 1                             NaN                           NaN      NaN
# 2                             NaN                           NaN      NaN
# 3                             NaN                           NaN      NaN
# 4                             NaN                           NaN      NaN
# ..                            ...                           ...      ...
# 535                           NaN                           NaN      NaN
# 536                           NaN                           NaN      NaN
# 537                           NaN                           NaN      NaN
# 538                           NaN                           NaN      NaN
# 539                           NaN                           NaN      NaN
#
#     Planning Guide
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 535            NaN
# 536            NaN
# 537            NaN
# 538            NaN
# 539            NaN
#
# [540 rows x 40 columns]

# %%
final_df = pd.merge(master_df, df3, how='inner', left_on='Activity', right_on='activity_code')

# %%
final_df
# Out:
#          Activity      Opened     RID  St       Type       Sc  SIC_x  NAICS_x  \
# 0     1630373.015  10/25/2022  352450  MD  Complaint  Partial    NaN   452319
# 1     1630373.015  10/25/2022  352450  MD  Complaint  Partial    NaN   452319
# 2     1630373.015  10/25/2022  352450  MD  Complaint  Partial    NaN   452319
# 3     1630373.015  10/25/2022  352450  MD  Complaint  Partial    NaN   452319
# 4     1630373.015  10/25/2022  352450  MD  Complaint  Partial    NaN   452319
# ...           ...         ...     ...  ..        ...      ...    ...      ...
# 2795  1133313.015  03/16/2016  112300  RI  Complaint  Partial    NaN   452990
# 2796  1133313.015  03/16/2016  112300  RI  Complaint  Partial    NaN   452990
# 2797  1133313.015  03/16/2016  112300  RI  Complaint  Partial    NaN   452990
# 2798  1133313.015  03/16/2016  112300  RI  Complaint  Partial    NaN   452990
# 2799  1133313.015  03/16/2016  112300  RI  Complaint  Partial    NaN   452990
#
#       Vio                          Establishment Name          query  \
# 0       3                    Dollar Tree Stores, Inc.    Dollar Tree
# 1       3                    Dollar Tree Stores, Inc.    Dollar Tree
# 2       3                    Dollar Tree Stores, Inc.    Dollar Tree
# 3       3                    Dollar Tree Stores, Inc.    Dollar Tree
# 4       3                    Dollar Tree Stores, Inc.    Dollar Tree
# ...   ...                                         ...            ...
# 2795    3  Family Dollar Stores Of Rhode Island, Inc.  Family Dollar
# 2796    3  Family Dollar Stores Of Rhode Island, Inc.  Family Dollar
# 2797    3  Family Dollar Stores Of Rhode Island, Inc.  Family Dollar
# 2798    3  Family Dollar Stores Of Rhode Island, Inc.  Family Dollar
# 2799    3  Family Dollar Stores Of Rhode Island, Inc.  Family Dollar
#
#      query_start   query_end Case Status  Inspection Nr  Report ID  \
# 0     2012-12-31  2022-12-31      CLOSED    1630373.015     352450
# 1     2012-12-31  2022-12-31      CLOSED    1630373.015     352450
# 2     2012-12-31  2022-12-31      CLOSED    1630373.015     352450
# 3     2012-12-31  2022-12-31      CLOSED    1630373.015     352450
# 4     2012-12-31  2022-12-31      CLOSED    1630373.015     352450
# ...          ...         ...         ...            ...        ...
# 2795  2016-01-01  2022-12-31      CLOSED    1133313.015     112300
# 2796  2016-01-01  2022-12-31      CLOSED    1133313.015     112300
# 2797  2016-01-01  2022-12-31      CLOSED    1133313.015     112300
# 2798  2016-01-01  2022-12-31      CLOSED    1133313.015     112300
# 2799  2016-01-01  2022-12-31      CLOSED    1133313.015     112300
#
#        Open Date  \
# 0     10/25/2022
# 1     10/25/2022
# 2     10/25/2022
# 3     10/25/2022
# 4     10/25/2022
# ...          ...
# 2795  03/16/2016
# 2796  03/16/2016
# 2797  03/16/2016
# 2798  03/16/2016
# 2799  03/16/2016
#
#                                                                                                       Site Address  \
# 0                               Dollar Tree Stores, Inc.\n\t\t\t   8157 Governor Ritchie HighwayPasadena, MD 21122
# 1                               Dollar Tree Stores, Inc.\n\t\t\t   8157 Governor Ritchie HighwayPasadena, MD 21122
# 2                               Dollar Tree Stores, Inc.\n\t\t\t   8157 Governor Ritchie HighwayPasadena, MD 21122
# 3                               Dollar Tree Stores, Inc.\n\t\t\t   8157 Governor Ritchie HighwayPasadena, MD 21122
# 4                               Dollar Tree Stores, Inc.\n\t\t\t   8157 Governor Ritchie HighwayPasadena, MD 21122
# ...                                                                                                            ...
# 2795  Family Dollar Stores Of Rhode Island, Inc.\n\t\t\t   Store Number 8177, 541 Smith StreetProvidence, RI 02908
# 2796  Family Dollar Stores Of Rhode Island, Inc.\n\t\t\t   Store Number 8177, 541 Smith StreetProvidence, RI 02908
# 2797  Family Dollar Stores Of Rhode Island, Inc.\n\t\t\t   Store Number 8177, 541 Smith StreetProvidence, RI 02908
# 2798  Family Dollar Stores Of Rhode Island, Inc.\n\t\t\t   Store Number 8177, 541 Smith StreetProvidence, RI 02908
# 2799  Family Dollar Stores Of Rhode Island, Inc.\n\t\t\t   Store Number 8177, 541 Smith StreetProvidence, RI 02908
#
#                                                        Mailing Address  \
# 0     500 Volvo Parkway Attention Larisa Rapnick, Chesapeake, VA 23320
# 1     500 Volvo Parkway Attention Larisa Rapnick, Chesapeake, VA 23320
# 2     500 Volvo Parkway Attention Larisa Rapnick, Chesapeake, VA 23320
# 3     500 Volvo Parkway Attention Larisa Rapnick, Chesapeake, VA 23320
# 4     500 Volvo Parkway Attention Larisa Rapnick, Chesapeake, VA 23320
# ...                                                                ...
# 2795                                P.O. Box 1017, Charlotte, NC 28201
# 2796                                P.O. Box 1017, Charlotte, NC 28201
# 2797                                P.O. Box 1017, Charlotte, NC 28201
# 2798                                P.O. Box 1017, Charlotte, NC 28201
# 2799                                P.O. Box 1017, Charlotte, NC 28201
#
#      Union Status  SIC_y                                      NAICS_y  \
# 0        NonUnion    NaN                                       452319
# 1        NonUnion    NaN                                       452319
# 2        NonUnion    NaN                                       452319
# 3        NonUnion    NaN                                       452319
# 4        NonUnion    NaN                                       452319
# ...           ...    ...                                          ...
# 2795     NonUnion    NaN  452990/All Other General Merchandise Stores
# 2796     NonUnion    NaN  452990/All Other General Merchandise Stores
# 2797     NonUnion    NaN  452990/All Other General Merchandise Stores
# 2798     NonUnion    NaN  452990/All Other General Merchandise Stores
# 2799     NonUnion    NaN  452990/All Other General Merchandise Stores
#
#      Inspection Type    Scope Advanced Notice Ownership Safety/Health  \
# 0          Complaint  Partial               N   Private        Safety
# 1          Complaint  Partial               N   Private        Safety
# 2          Complaint  Partial               N   Private        Safety
# 3          Complaint  Partial               N   Private        Safety
# 4          Complaint  Partial               N   Private        Safety
# ...              ...      ...             ...       ...           ...
# 2795       Complaint  Partial               N   Private        Safety
# 2796       Complaint  Partial               N   Private        Safety
# 2797       Complaint  Partial               N   Private        Safety
# 2798       Complaint  Partial               N   Private        Safety
# 2799       Complaint  Partial               N   Private        Safety
#
#      Close Conference Emphasis  Close Case  activity_code_x  Investigation Nr  \
# 0          11/07/2022      NaN  12/30/2022      1630373.015               NaN
# 1          11/07/2022      NaN  12/30/2022      1630373.015               NaN
# 2          11/07/2022      NaN  12/30/2022      1630373.015               NaN
# 3          11/07/2022      NaN  12/30/2022      1630373.015               NaN
# 4          11/07/2022      NaN  12/30/2022      1630373.015               NaN
# ...               ...      ...         ...              ...               ...
# 2795       03/16/2016      NaN  08/30/2016      1133313.015               NaN
# 2796       03/16/2016      NaN  08/30/2016      1133313.015               NaN
# 2797       03/16/2016      NaN  08/30/2016      1133313.015               NaN
# 2798       03/16/2016      NaN  08/30/2016      1133313.015               NaN
# 2799       03/16/2016      NaN  08/30/2016      1133313.015               NaN
#
#      Event investigation_summary_notes_1 Note Inspection Information - Office  \
# 0      NaN                           NaN  NaN                             NaN
# 1      NaN                           NaN  NaN                             NaN
# 2      NaN                           NaN  NaN                             NaN
# 3      NaN                           NaN  NaN                             NaN
# 4      NaN                           NaN  NaN                             NaN
# ...    ...                           ...  ...                             ...
# 2795   NaN                           NaN  NaN                             NaN
# 2796   NaN                           NaN  NaN                             NaN
# 2797   NaN                           NaN  NaN                             NaN
# 2798   NaN                           NaN  NaN                             NaN
# 2799   NaN                           NaN  NaN                             NaN
#
#      investigation_summary_notes_2 investigation_summary_notes_3 Keywords  \
# 0                              NaN                           NaN      NaN
# 1                              NaN                           NaN      NaN
# 2                              NaN                           NaN      NaN
# 3                              NaN                           NaN      NaN
# 4                              NaN                           NaN      NaN
# ...                            ...                           ...      ...
# 2795                           NaN                           NaN      NaN
# 2796                           NaN                           NaN      NaN
# 2797                           NaN                           NaN      NaN
# 2798                           NaN                           NaN      NaN
# 2799                           NaN                           NaN      NaN
#
#      Planning Guide Violations/Penalties  Serious Willful Repeat   Other  \
# 0               NaN   Initial Violations        1     NaN    NaN       2
# 1               NaN   Current Violations        1     NaN    NaN       2
# 2               NaN      Initial Penalty   $3,400      $0     $0      $0
# 3               NaN      Current Penalty   $3,400      $0     $0      $0
# 4               NaN          FTA Penalty       $0      $0     $0      $0
# ...             ...                  ...      ...     ...    ...     ...
# 2795            NaN   Initial Violations        3     NaN    NaN     NaN
# 2796            NaN   Current Violations        2     NaN    NaN       1
# 2797            NaN      Initial Penalty  $16,150      $0     $0      $0
# 2798            NaN      Current Penalty   $6,545      $0     $0  $2,380
# 2799            NaN          FTA Penalty       $0      $0     $0      $0
#
#      Unclass    Total  activity_code_y
# 0        NaN        3      1630373.015
# 1        NaN        3      1630373.015
# 2         $0   $3,400      1630373.015
# 3         $0   $3,400      1630373.015
# 4         $0       $0      1630373.015
# ...      ...      ...              ...
# 2795     NaN        3      1133313.015
# 2796     NaN        3      1133313.015
# 2797      $0  $16,150      1133313.015
# 2798      $0   $8,925      1133313.015
# 2799      $0       $0      1133313.015
#
# [2800 rows x 48 columns]

# %%
final_df.to_csv('2_final_df.csv')

# %%
# !ls
# Out:
# 1. Final-Scrape-DollarTree.ipynb       2. Joining_dfs_Violation_Summary.ipynb
# 1_activities_df.csv                    2_final_df.csv
# 1_details_df.csv                       3. Work2_MoreWork_Fines.ipynb
# 1_investigated_inspections_df.csv      4. Work2_MoreWork_Violations.ipynb
# 1_related_activity_df.csv              Jan16DT_Fines.csv
# 1_violation_items_df.csv               Jan16DT_Violations.csv
# 1_violation_summary_df.csv             Jan16DT_final_df.csv
