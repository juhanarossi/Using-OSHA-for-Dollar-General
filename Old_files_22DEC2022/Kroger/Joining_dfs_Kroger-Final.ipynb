# %%
# !ls
# Out:
# Dec22Kro_activities_df.csv
# Dec22Kro_details_df.csv
# Dec22Kro_investigated_inspections_df.csv
# Dec22Kro_related_activity_df.csv
# Dec22Kro_violation_items_df.csv
# Dec22Kro_violation_summary_df.csv
# Final-Scrape-Kroger.ipynb
# Fines_Kroger-AfterDropDuplicatestoEnd.ipynb
# Fines_Kroger-toDropDuplicates.ipynb
# Joining_dfs_Kroger-Final.ipynb

# %%
import pandas as pd
pd.options.display.max_colwidth = None
pd.options.display.max_columns = None

# %%
df1 = pd.read_csv("Dec22Kro_activities_df.csv")

# %%
df2 = pd.read_csv("Dec22Kro_details_df.csv")

# %%
df3 = pd.read_csv("Dec22Kro_violation_summary_df.csv")

# %%
df3 = df3[df3['Violations/Penalties'] == 'Current Penalty']
df3
# Out:
#     Violations/Penalties  Serious Willful Repeat   Other Unclass    Total  \
# 3        Current Penalty       $0      $0     $0  $2,796      $0   $2,796
# 8        Current Penalty  $24,862      $0     $0      $0      $0  $24,862
# 13       Current Penalty       $0      $0   $414      $0      $0     $414
# 18       Current Penalty   $2,250      $0     $0      $0      $0   $2,250
# 23       Current Penalty   $7,000      $0     $0      $0      $0   $7,000
# ..                   ...      ...     ...    ...     ...     ...      ...
# 848      Current Penalty     $840      $0     $0      $0      $0     $840
# 853      Current Penalty   $1,300      $0     $0      $0      $0   $1,300
# 858      Current Penalty     $450      $0     $0      $0      $0     $450
# 863      Current Penalty   $7,000      $0     $0  $1,000      $0   $8,000
# 868      Current Penalty       $0      $0     $0  $2,000      $0   $2,000
#
#      activity_code
# 3     1.621876e+06
# 8     1.614916e+06
# ...

# %%
master_df = pd.merge(df1, df2, how='inner', left_on='Activity', right_on='Inspection Nr')

# %%
master_df
# Out:
#          Activity      Opened     RID  St       Type        Sc   SIC_x  \
# 0    1.621876e+06  09/14/2022  626700  TX    Planned   Partial     NaN
# 1    1.614916e+06  08/16/2022  316400  WV   Referral   Partial     NaN
# 2    1.613884e+06  08/09/2022  830600  CO  Complaint   Partial     NaN
# 3    1.590209e+06  04/13/2022  854910  UT  Complaint   Partial     NaN
# 4    1.589516e+06  04/12/2022  452110  KY  Complaint   Partial  5411.0
# ..            ...         ...     ...  ..        ...       ...     ...
# 169  3.143333e+08  04/16/2010  627100  AR  Complaint   Partial  5411.0
# 170  3.120076e+08  04/09/2010  552652  MI    Planned  Complete  5411.0
# 171  3.120384e+08  04/01/2010  552652  MI  Complaint   Partial  5411.0
# 172  3.138321e+08  03/15/2010  551800  IN   Accident   Partial  5411.0
# 173  3.131540e+08  02/12/2010  522500  OH  Complaint   Partial  5141.0
#
#      NAICS_x  Vio                 Establishment Name   query query_start  \
# ...

# %%
final_df = pd.merge(master_df, df3, how='inner', left_on='Activity', right_on='activity_code')

# %%
final_df
# Out:
#          Activity      Opened     RID  St       Type        Sc   SIC_x  \
# 0    1.621876e+06  09/14/2022  626700  TX    Planned   Partial     NaN
# 1    1.614916e+06  08/16/2022  316400  WV   Referral   Partial     NaN
# 2    1.613884e+06  08/09/2022  830600  CO  Complaint   Partial     NaN
# 3    1.590209e+06  04/13/2022  854910  UT  Complaint   Partial     NaN
# 4    1.589516e+06  04/12/2022  452110  KY  Complaint   Partial  5411.0
# ..            ...         ...     ...  ..        ...       ...     ...
# 169  3.143333e+08  04/16/2010  627100  AR  Complaint   Partial  5411.0
# 170  3.120076e+08  04/09/2010  552652  MI    Planned  Complete  5411.0
# 171  3.120384e+08  04/01/2010  552652  MI  Complaint   Partial  5411.0
# 172  3.138321e+08  03/15/2010  551800  IN   Accident   Partial  5411.0
# 173  3.131540e+08  02/12/2010  522500  OH  Complaint   Partial  5141.0
#
#      NAICS_x  Vio                 Establishment Name   query query_start  \
# ...

# %%
final_df.to_csv('Dec22Kro_TOTAL_CurrentPenalty.csv')

# %%
# !ls
# Out:
# Dec22Kro_activities_df.csv
# Dec22Kro_details_df.csv
# Dec22Kro_investigated_inspections_df.csv
# Dec22Kro_related_activity_df.csv
# Dec22Kro_TOTAL_CurrentPenalty.csv
# Dec22Kro_violation_items_df.csv
# Dec22Kro_violation_summary_df.csv
# Final-Scrape-Kroger.ipynb
# Fines_Kroger-AfterDropDuplicatestoEnd.ipynb
# Fines_Kroger-toDropDuplicates.ipynb
# Joining_dfs_Kroger-Final.ipynb
