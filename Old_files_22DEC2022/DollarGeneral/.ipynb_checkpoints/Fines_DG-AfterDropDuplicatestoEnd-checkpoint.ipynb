# %%
import pandas as pd

# %%
# !ls
# Out:
# Dec22DG_activities_df.csv
# Dec22DG_details_df.csv
# Dec22DG_investigated_inspections_df.csv
# Dec22DG_related_activity_df.csv
# Dec22DG_toDropDuplicates.csv
# Dec22DG_TOTAL_master.csv
# Dec22DG_violation_items_df.csv
# Dec22DG_violation_summary_df.csv
# Final-Scrape-DollarGeneral.ipynb
# Fines_DG-AfterDropDuplicatestoEnd.ipynb
# Fines_DG-toDropDuplicates.ipynb
# Joining_dfs_DG-Final.ipynb

# %%
df = pd.read_csv("Dec22DG_toDropDuplicates.csv")

# %%
df
# Out:
#      Unnamed: 0      Activity      Opened     RID  St       Type        Sc  \
# 0             0  1.619753e+06  09/06/2022  452110  KY  Complaint   Partial
# 1             1  1.617010e+06  08/25/2022  552652  MI  Complaint   Partial
# 2             2  1.609906e+06  07/25/2022  454716  TN  Complaint   Partial
# 3             3  1.607451e+06  07/13/2022  418100  GA  Complaint   Partial
# 4             4  1.601808e+06  06/14/2022  418400  GA  Complaint   Partial
# ..          ...           ...         ...     ...  ..        ...       ...
# 233         387  1.079844e+06  07/23/2015  419700  FL  Complaint   Partial
# 234         388  1.083884e+06  07/20/2015  418300  AL   Referral   Partial
# 235         389  1.062209e+06  05/11/2015  729300  MO  Complaint   Partial
# 236         390  3.167852e+08  08/14/2013  453710  NC  Complaint   Partial
# 237         391  3.140213e+08  01/14/2010  453730  NC    Planned  Complete
#
#       SIC_x  NAICS_x  Vio  ... Keywords        Planning Guide  \
# 0    4225.0   493110    2  ...      NaN                   NaN
# 1       NaN   452319    1  ...      NaN                   NaN
# 2       NaN   452319    2  ...      NaN                   NaN
# 3       NaN   445110    1  ...      NaN                   NaN
# 4       NaN   452319    2  ...      NaN                   NaN
# ..      ...      ...  ...  ...      ...                   ...
# 233     NaN   452990    2  ...      NaN                   NaN
# 234     NaN   452910    1  ...      NaN                   NaN
# 235     NaN   452112    2  ...      NaN                   NaN
# 236  5331.0   452990    2  ...      NaN  Health-Manufacturing
# 237  5311.0   452112    6  ...      NaN  Safety-Manufacturing
#
#     Violations/Penalties Serious   Willful    Repeat   Other Unclass  \
# 0        Current Penalty      $0  $140,000        $0      $0      $0
# 1        Current Penalty      $0        $0        $0      $0      $0
# 2        Current Penalty      $0        $0    $6,750      $0      $0
# 3        Current Penalty      $0        $0        $0  $5,283      $0
# 4        Current Penalty      $0        $0  $290,054      $0      $0
# ..                   ...     ...       ...       ...     ...     ...
# 233      Current Penalty  $3,600        $0        $0      $0      $0
# 234      Current Penalty      $0        $0        $0  $4,200      $0
# 235      Current Penalty      $0        $0   $27,500    $550      $0
# 236      Current Penalty      $0        $0        $0      $0      $0
# 237      Current Penalty      $0        $0        $0    $975      $0
#
#         Total activity_code_y
# 0    $140,000    1.619753e+06
# 1          $0    1.617010e+06
# 2      $6,750    1.609906e+06
# 3      $5,283    1.607451e+06
# 4    $290,054    1.601808e+06
# ..        ...             ...
# 233    $3,600    1.079844e+06
# 234    $4,200    1.083884e+06
# 235   $28,050    1.062209e+06
# 236        $0    3.167852e+08
# 237      $975    3.140213e+08
#
# [238 rows x 48 columns]

# %%
df['year'] = pd.to_datetime(df['Open Date'], format='%m/%d/%Y')

# %%
df['simple_year'] = df['year'].dt.year

# %%
df.Total = df.Total.astype(str)

# %%
df.Total = df.Total.str.replace("$", "")
# Out:
# C:\Users\Juhana\AppData\Local\Temp\ipykernel_6584\1384840350.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.Total = df.Total.str.replace("$", "")

# %%
df.Total = df.Total.str.replace(",", "")

# %%
df.Total = df.Total.astype(int)

# %%
dgfines_df = df.groupby('simple_year')['Total'].sum()

# %%
dgfines_df
# Out:
# simple_year
# 2010      33667
# 2011      62625
# 2012      29034
# 2013      71255
# 2014     254609
# 2015     600071
# 2016    1165991
# 2017     220504
# 2018     166821
# 2019     287830
# 2020    1074248
# 2021    2231134
# 2022    7071681
# Name: Total, dtype: int32

# %%
new_df = dgfines_df.to_frame(name='fines')

# %%
new_df
# Out:
#                fines
# simple_year
# 2010           33667
# 2011           62625
# 2012           29034
# 2013           71255
# 2014          254609
# 2015          600071
# 2016         1165991
# 2017          220504
# 2018          166821
# 2019          287830
# 2020         1074248
# 2021         2231134
# 2022         7071681

# %%
new_df.to_csv('7-eleven-FinesFinal.csv', index=False)

# %%
# !ls
# Out:
# 7-eleven_activities_df.csv
# 7-eleven_details_df.csv
# 7-eleven_investigated_inspections_df.csv
# 7-eleven_related_activity_df.csv
# 7-eleven_violation_items_df.csv
# 7-eleven_violation_summary_df.csv
# 7-elevenAfterDropDuplicates.csv
# 7-eleven-FinesFinal.csv
# Final_7-eleven_df.csv
# Fines_7-eleven-AfterDropDuplicates.ipynb
# Fines_7-Eleven-DropDuplicates.ipynb
# Joining_dfs_7-eleven.ipynb
