# %%
import pandas as pd

# %%
# !ls
# Out:
# Dec22DT_TOTAL_CurrentPenalty_master.csv
# Fines_DollarTree-AfterDropDuplicatestoEnd.ipynb
# Fines_DollarTree-toDropDuplicates.ipynb
# Joining_dfs_DollarTree-Final.ipynb

# %%
df = pd.read_csv("Dec22DT_TOTAL_CurrentPenalty_master.csv")
df
# Out:
#      Unnamed: 0      Activity      Opened      RID  St       Type        Sc  \
# 0             0  1.616331e+06  08/22/2022   453720  NC  Complaint   Partial
# 1             1  1.618010e+06  08/10/2022   316400  WV  Complaint   Partial
# 2             2  1.612868e+06  08/05/2022   953210  NV   Referral   Partial
# 3             3  1.611611e+06  08/01/2022  1054111  OR  Complaint   Partial
# 4             4  1.610668e+06  07/27/2022  1054111  OR  Complaint   Partial
# ..          ...           ...         ...      ...  ..        ...       ...
# 426         426  3.114835e+08  01/29/2010   155010  VT  Complaint   Partial
# 427         427  3.134076e+08  01/29/2010   728500  MO  Complaint   Partial
# 428         428  1.606471e+06  07/01/2022  1055330  WA   Referral   Partial
# 429         429  1.569668e+06  12/17/2021   418800  FL    Fat/Cat  Complete
# 430         430  1.189516e+06  11/07/2016   355112  VA    Planned   Partial
#
# ...

# %%
df = df.drop_duplicates(['Activity'])
df
# Out:
#      Unnamed: 0      Activity      Opened      RID  St       Type        Sc  \
# 0             0  1.616331e+06  08/22/2022   453720  NC  Complaint   Partial
# 1             1  1.618010e+06  08/10/2022   316400  WV  Complaint   Partial
# 2             2  1.612868e+06  08/05/2022   953210  NV   Referral   Partial
# 3             3  1.611611e+06  08/01/2022  1054111  OR  Complaint   Partial
# 4             4  1.610668e+06  07/27/2022  1054111  OR  Complaint   Partial
# ..          ...           ...         ...      ...  ..        ...       ...
# 426         426  3.114835e+08  01/29/2010   155010  VT  Complaint   Partial
# 427         427  3.134076e+08  01/29/2010   728500  MO  Complaint   Partial
# 428         428  1.606471e+06  07/01/2022  1055330  WA   Referral   Partial
# 429         429  1.569668e+06  12/17/2021   418800  FL    Fat/Cat  Complete
# 430         430  1.189516e+06  11/07/2016   355112  VA    Planned   Partial
#
# ...

# %%
df.to_csv('Dec22DT_toDropDuplicates.csv', index=False)
